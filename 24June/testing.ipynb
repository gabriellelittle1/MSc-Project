# %%
from DSL import * 
import numpy as np

# %%
room = Room(10, 5)
room.fixed_objects = [Object('window', 2, 0, (6, 0, 0)), Object('window', 0, 3, (10, 2.5, 0)), Object('door', 0.9, 0.9, (2, 0, 0))]
room.fixed_objects += [Object('window', 1, 0, (3, 5, 0)), Object('window', 1, 0, (7, 5, 0))]              

directions = ['N', 'E', 'S', 'W']
for i in directions: 
    num_windows = room.windows_on_wall(i)
    num_doors = room.doors_on_wall(i)

    print(f"On the {i} wall, there are {num_windows} windows and {num_doors} doors.")

bed = Object('bed', 1.4, 2, (5, 4, np.pi))
room.moving_objects = [bed]
# Out:
# On the N wall, there are 2 windows and 0 doors.
# On the E wall, there are 1 windows and 0 doors.
# On the S wall, there are 1 windows and 1 doors.
# On the W wall, there are 0 windows and 0 doors.

# %%
nightstand1 = Object('nightstand1', 0.5, 0.5, (4, 4.75, np.pi))
nightstand2 = Object('nightstand2', 0.5, 0.5, (6, 4.75, np.pi))
room.add_object(nightstand1)
room.add_object(nightstand2)
room.draw()

# %%
from PairwaiseConstraints import *

print(next_to(nightstand1, nightstand2, threshold = 1.5))
print(next_to(nightstand1, bed, threshold = 1.5))
print(next_to(nightstand2, bed, threshold = 1.5))
print("")
print(next_to_side(nightstand1, bed, 'right'))
print(next_to_side(nightstand1, bed, 'left'))
print(next_to_side(nightstand1, bed, 'top'))
print(next_to_side(nightstand1, bed, 'bottom'))
print("")
print(next_to_side(nightstand2, bed, 'right'))
print(next_to_side(nightstand2, bed, 'left'))
print(next_to_side(nightstand2, bed, 'top'))
print(next_to_side(nightstand2, bed, 'bottom'))
# Out:
# 4.0
# 1.5625
# 1.5625
#
# 0.78125
# 1.28125
# 1.28125
# 2.78125
#
# 1.28125
# 0.78125
# 2.78125
# 5.28125

# %%
from IndividualConstraints import * 
room.draw()

for i in ['N', 'E', 'S', 'W']:
    print(f"___ next to the {i} wall:")
    print(f"bed, {next_to_wall(room, bed, i)}")
    print(f"nighstand1, {next_to_wall(room, bed, i)}")
    print(f"nightstand2, {next_to_wall(room, bed, i)}")

print("")
for i in ['left', 'right', 'top', 'bottom']:
    print(f"The {i} side of ___ next to the North wall:")
    print(f"bed, {side_next_to_wall(room, bed, i, 'N')}")
    print(f"nightstand1, {side_next_to_wall(room, nightstand1, i, 'N')}")
    print(f"nightstand2, {side_next_to_wall(room, nightstand2, i, 'N')}")

print("")
for i in ['left', 'right', 'back', 'front']:
    print(f"The {i} side of ___ next to the East wall:")
    print(f"bed, {side_next_to_wall(room, bed, i, 'E')}")
    print(f"nightstand1, {side_next_to_wall(room, nightstand1, i, 'E')}")
    print(f"nightstand2, {side_next_to_wall(room, nightstand2, i, 'E')}")
# Out:
# ___ next to the N wall:
# bed, 0.0
# nighstand1, 0.0
# nightstand2, 0.0
# ___ next to the E wall:
# bed, 18.49
# nighstand1, 18.49
# nightstand2, 18.49
# ___ next to the S wall:
# bed, 9.0
# nighstand1, 9.0
# nightstand2, 9.0
# ___ next to the W wall:
# bed, 18.49
# nighstand1, 18.49
# nightstand2, 18.49
#
# The left side of ___ next to the North wall:
# bed, 32.0
# nightstand1, 0.125
# nightstand2, 0.125
# The right side of ___ next to the North wall:
# bed, 32.0
# nightstand1, 0.125
# nightstand2, 0.125
# The top side of ___ next to the North wall:
# bed, 0.0
# nightstand1, 0.0
# nightstand2, 0.0
# The bottom side of ___ next to the North wall:
# bed, 96.0
# nightstand1, 0.375
# nightstand2, 0.375
#
# The left side of ___ next to the East wall:
# bed, 683.7601999999999
# nightstand1, 2186.2578125
# nightstand2, 395.5078125
# The right side of ___ next to the East wall:
# bed, 2895.2002000000007
# nightstand1, 3195.7578125
# nightstand2, 716.5078125
# ...

# %%
room = Room(5, 5)
room.fixed_objects = [Object('window', 0, 3, (0, 2.5, 0)), Object('door', 1, 0, (1.3, 5, 0))]
room.moving_objects = [Object('bed', 1.91, 2.33, (3.8, 2.5, np.pi/2)), Object('nighstand', 0.67, 0.47, (4.7, 3.85, np.pi/2))]
room.moving_objects += [Object('nighstand', 0.67, 0.47, (4.7, 1.2, np.pi/2))]
room.moving_objects += [Object('desk', 1.19, 0.6, (0.4, 1.5, 3*np.pi/2)), Object('chair', 0.68, 0.66, (1.2, 1.5, np.pi/2))]
room.moving_objects += [Object('dresser', 1.71, 0.51, (2.8, 4.7, np.pi))]#, Object('rug', 1.53, 2.44, (2.8, 2.5, 0)), ]
room.draw()

# %%
room = Room(5, 3.67)
room.fixed_objects = [Object('window', 0, 2.1, (0, 3.67/2, 0)), Object('door', 0, 0.8, (5, 2.5, 0))]
room.fixed_objects += [Object('window', 2.1, 0, (2.5, 0, 0))]
room.moving_objects = [Object('bed', 2.12, 2.22, (3, 2.5, np.pi)), Object('nightstand', 0.4, 0.4, (4.3, 3.4, np.pi))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (1.7, 3.4, np.pi))]
room.moving_objects += [Object('chair', 0.7, 0.73, (0.6, 0.6, -np.pi/5)), Object('plant', 0.4, 0.4, (1, 3.4, np.pi))]
room.moving_objects += [Object('dresser', 1.3, 0.48, (0.3, 2.55, 3*np.pi/2))]
room.moving_objects += [Object('plant', 0.4, 0.4, (4.5, 0.3, 0))]
room.draw()

# %%
room = Room(5, 4.5)
room.fixed_objects = [ Object('door', 0.8, 0, (1, 0, 0))]
room.fixed_objects += [Object('window', 2.1, 0, (2.5, 4.5, 0))]
room.moving_objects = [Object('bed', 2.12, 2.22, (2.6, 3.4, np.pi/2))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (3.5, 2.1, np.pi/2))]
room.moving_objects += [Object('chair', 0.7, 0.73, (0.6, 1.5, 8*np.pi/7)), Object('plant', 0.4, 0.4, (4.6, 4.2, np.pi))]
room.moving_objects += [Object('mirror', 0.47, 0.43, (0.4, 4, 4*np.pi/3))]
room.moving_objects += [Object('chair', 0.39, 0.32, (2, 0.4, np.pi/3))]
room.moving_objects += [Object('rug', 2.8, 2, (1.3, 2, np.pi/2))]
room.draw()

# %%
room = Room(4.55, 3.95)
room.fixed_objects = [ Object('door', 0, 0.92, (0, 1.5, 0))]
room.fixed_objects += [ Object('window', 0, 2.6, (4.55, 3.95/2, 0))]
room.moving_objects = [Object('bed', 1.84, 2.38, (2.7, 2.7, np.pi))]
room.moving_objects += [Object('nightstand', 0.52, 0.52, (4, 3.6, np.pi))]
room.moving_objects += [Object('plant', 0.83, 0.84, (4, 0.5, 0))]
room.moving_objects += [Object('wardrobe', 1.45, 0.58, (0.75, 0.3, 0))]
room.moving_objects += [Object('vanity', 1.5, 0.27, (0.75, 3.8, np.pi))]
room.moving_objects += [Object('chair', 0.63, 0.55, (0.75, 3.3, 0))]
room.moving_objects += [Object('rug', 2.6, 2, (2.7, 2.2, 0))]
room.draw()

# %%
room = Room(4.3, 6)
room.fixed_objects = [ Object('door', 0.8, 0, (3.8, 6, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (0, 4, 0)), Object('window', 2.1, 0, (4.3/2, 0, 0)) ]
room.moving_objects = [Object('bed', 1.81, 2.1, (1.8, 1.2, 0))]
room.moving_objects += [Object('nightstand', 0.51, 0.42, (0.4, 0.3, 0)), Object('nightstand', 0.51, 0.42, (3.1, 0.3, 0))]
room.moving_objects += [Object('wardrobe', 1.17 + 0.78, 0.53, (4, 1, np.pi/2))]
room.moving_objects += [Object('dresser', 1.27, 0.52, (0.3, 2, 3*np.pi/2))]
room.draw()

# %%
room = Room(5, 4.09)
room.fixed_objects = [ Object('door', 0.8, 0, (1.3, 0, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (0, 4.09/2, 0)), Object('window', 2.1, 0, (1.26 + 1.05, 4.09, 0)) ]
room.moving_objects = [Object('bed', 1.64, 2.18, (1.37 + 1.64/2, 3, np.pi))]
room.moving_objects += [Object('nightstand', 0.54, 0.38, (1.1, 3.9, np.pi)), Object('nightstand', 0.54, 0.38, (3.3, 3.9, np.pi))]
room.moving_objects += [Object('wardrobe', 2, 0.44, (4, 0.25, 0))]
room.moving_objects += [Object('dresser', 1.2, 0.4, (4.8, 1.5 + 1.2/2, np.pi/2))]
room.moving_objects += [Object('plant', 0.56, 0.53, (0.4, 3.7, -3*np.pi/4)), Object('plant', 0.56, 0.53, (0.4, 0.4, 7*np.pi/4))]
room.draw()

# %%
room = Room(4.21, 6)
room.fixed_objects = [ Object('door', 0, 0.8, (4.21, 4, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (0, 4.09/2, 0)), Object('fireplace', 1.5, 0.38, (2.3, 5.8, 0))]
room.moving_objects = [Object('rug', 2, 2.5, (2.5, 4.5, np.pi/2))]
room.moving_objects += [Object('bed', 2, 2.26, (2.6, 1.1, 0))]
room.moving_objects += [Object('nightstand', 0.54, 0.54, (3.9, 0.3, 0)), Object('nightstand', 0.54, 0.54, (1.3, 0.3, 0))]
room.moving_objects += [Object('chair', 0.62, 0.76, (3.5, 5, 3*np.pi/4))]
room.moving_objects += [Object('lamp', 0.32, 0.32, (4, 4.7, np.pi/2))]
room.moving_objects += [Object('wardrobe', 1.6, 0.64, (0.35, 5, 3*np.pi/2))]
room.moving_objects += [Object('plant', 1.06, 0.94, (0.5, 0.5, 0))]
room.moving_objects += [Object('ottoman', 1.52, 0.65, (2.6, 2.6, 0))]
room.draw()

# %%
room = Room(5, 2.62)
room.fixed_objects = [ Object('door', 0, 0.8, (0, 0.63 + 0.4, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (5, 2.62/2, 0))]
room.moving_objects = [Object('rug', 2.2, 2.3, (3.8, 1.4, np.pi/2))]
room.moving_objects += [Object('bed', 1.89, 2.3, (3.8, 1.5, np.pi/2))]
room.moving_objects += [Object('dresser', 1.6, 0.48, (0.9, 0.25, 0))]
room.draw()

# %%
room = Room(6.1, 4.72)
room.fixed_objects = [ Object('door', 0.8, 0, (3.1, 4.72, 0))]
room.fixed_objects += [ Object('window', 0, 2.3, (0, 4.09/2, 0)), Object('window', 0, 2.3, (6.1, 4.72/3, 0))]
room.moving_objects = [Object('bed', 1.9, 2.2,(4, 1.1, 0))]
room.moving_objects += [Object('nightstand', 0.45, 0.42, (5.3, 0.2, 0)), Object('nightstand', 0.45, 0.42, (2.7, 0.2, 0))]
room.moving_objects += [Object('chair', 0.61, 0.63, (0.9, 3.2, np.pi/2))]
room.moving_objects += [Object('desk', 1.7, 0.5, (0.3, 3.2, 3*np.pi/2))]
room.moving_objects += [Object('wardrobe', 1.5, 0.66, (5, 4.4, np.pi))]
room.moving_objects += [Object('mirror', 0.6, 0.14, (6, 3.5, np.pi/2))]
room.moving_objects += [Object('bench', 1.63, 0.41, (4, 2.5, 0))]
room.moving_objects += [Object('plant', 0.56, 0.53, (0.4, 1.8, 3*np.pi/2))]
room.draw()

# %%
room = Room(6.1, 4.72)
room.fixed_objects = [ Object('door', 0.8, 0, (3.1, 4.72, 0))]
room.moving_objects = [Object('bed', 1.9, 2.2,(4, 1.1, 0))]
room.moving_objects += [Object('nightstand', 0.45, 0.42, (5.3, 0.2, 0)), Object('nightstand', 0.45, 0.42, (2.7, 0.2, 0))]
room.moving_objects += [Object('chair', 0.61, 0.63, (0.9, 3.2, np.pi/2))]
room.moving_objects += [Object('desk', 1.7, 0.5, (0.3, 3.2, 3*np.pi/2))]
room.moving_objects += [Object('mirror', 0.6, 0.14, (6, 3.5, np.pi/2))]
room.moving_objects += [Object('bench', 1.63, 0.41, (4, 2.5, 0))]
room.moving_objects += [Object('plant', 0.56, 0.53, (0.4, 1.8, 3*np.pi/2))]
room.draw()

# %%
room = Room(6.1, 4.72)
room.fixed_objects = [ Object('door', 0.8, 0, (3.1, 4.72, 0))]
room.fixed_objects += [ Object('window', 0, 2.3, (0, 4.09/2, 0)), Object('window', 0, 2.3, (6.1, 4.72/3, 0))]
room.moving_objects = [Object('bed', 1.9, 2.2,(4 - 2, 1.1, 0))]
room.moving_objects += [Object('nightstand', 0.45, 0.42, (5.3 - 2, 0.2, 0)), Object('nightstand', 0.45, 0.42, (2.7 - 2, 0.2, 0))]
room.moving_objects += [Object('chair', 0.61, 0.63, (0.9, 3.2, np.pi/2))]
room.moving_objects += [Object('desk', 1.7, 0.5, (0.3, 3.2, 3*np.pi/2))]
room.moving_objects += [Object('wardrobe', 1.5, 0.66, (2, 4.4, np.pi))]
room.moving_objects += [Object('mirror', 0.6, 0.14, (6, 3.5, np.pi/2))]
room.moving_objects += [Object('bench', 1.63, 0.41, (4 - 2, 2.5, 0))]
room.moving_objects += [Object('plant', 0.56, 0.53, (0.4, 1.8, 3*np.pi/2))]
room.draw()

# %%
room = Room(5, 2.62)
room.fixed_objects = [ Object('door', 0, 0.8, (0, 0.63 + 0.42, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (5, 2.62/2, 0))]
room.moving_objects = [Object('rug', 2.5, 2.5, (3.7, 2.62/2, np.pi/2))]
room.moving_objects += [Object('bed', 1.89, 2.3, (4, 1.5, np.pi))]
room.moving_objects += [Object('wardrobe', 1.1, 0.62, (0.3, 2.05, 3*np.pi/2))]
room.moving_objects += [Object('mirror', 0.6, 0.14, (1.8, 2.5, np.pi))]
room.moving_objects += [Object('nightstand', 0.56, 0.46, (2.7, 2.4, np.pi))]
room.moving_objects += [Object('plant', 0.6, 0.6, (0.3, 0.3, 3*np.pi/2))]
room.draw()

# %%
room = Room(4.21, 6)
room.fixed_objects = [ Object('door', 0, 0.8, (4.21, 4, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (0, 4.09/2, 0)), Object('fireplace', 1.5, 0.38, (2.3, 5.8, 0))]
room.moving_objects = [Object('rug', 2, 2.5, (2.5, 4.5, np.pi/2))]
room.moving_objects += [Object('bed', 2, 2.26, (2.6, 1.1, 0))]
room.moving_objects += [Object('nightstand', 0.54, 0.54, (3.9, 0.3, 0)), Object('nightstand', 0.54, 0.54, (1.3, 0.3, 0))]
room.moving_objects += [Object('chair', 0.62, 0.76, (3.5, 5, 3*np.pi/4))]
room.moving_objects += [Object('lamp', 0.32, 0.32, (4, 4.7, np.pi/2))]
room.moving_objects += [Object('ottoman', 1.52, 0.65, (2.6, 2.6, 0))]
room.draw()

# %%
room = Room(5, 5)
room.fixed_objects = [ Object('door', 0.8, 0, (1, 0, 0))]
room.fixed_objects += [ Object('window', 2.1, 0, (2.5, 5, 0))]
room.moving_objects = [Object('rug', 2.8, 2, (2, 3.3, 3*np.pi/2))]
room.moving_objects += [Object('bed', 2.12, 2.22, (1.1, 3.3, 3*np.pi/2))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (0.2, 4.6, 3*np.pi/2)), Object('nightstand', 0.4, 0.4, (0.2, 2, 3*np.pi/2))]
room.moving_objects += [Object('chair', 0.62, 0.76, (5 - 0.76/2, 2.5, np.pi/2))]
# room.moving_objects += [Object('wardrobe', 2, 0.67, (5 - 0.335, 4, np.pi/2))]
room.moving_objects += [Object('wardrobe', 2, 0.67, (2.6, 4, np.pi/2))]
room.moving_objects += [Object('dresser', 1.3, 0.48, (5 - 0.48/2, 1.4, np.pi/2))]
room.moving_objects += [Object('mirror', 0.47, 0.43, (2, 0.24, 0))]
room.moving_objects += [Object('plant', 0.6, 0.6, (0.4, 1.4, 3*np.pi/2)), Object('plant', 0.6, 0.6, (4.5, 0.3, 0))]
room.draw()

# %%
room = Room(6, 4.09)
room.fixed_objects = [Object('door', 0, 0.8, (6, 1.7, 0))]
room.fixed_objects += [ Object('window', 1, 0, (4.5, 4.09, 0)), Object('window', 1, 0, (1.5, 4.09, 0))]
room.moving_objects = [Object('rug', 2.8, 2, (1.8, 1.8, 3*np.pi/2))]
room.moving_objects += [Object('bed', 2.22, 2.12, (1.1, 1.8, 3*np.pi/2))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (0.2, 0.5, 3*np.pi/2)), Object('nightstand', 0.4, 0.4, (0.2, 3.1, 3*np.pi/2))]
#room.moving_objects += [Object('chair', 0.62, 0.76, (4.9, 3, 3*np.pi/2))]
room.moving_objects += [Object('chair', 0.62, 0.76, (4.9, 1.8, np.pi))]
#room.moving_objects += [Object('desk', 1.45, 0.65, (6 - 0.65/2, 3, np.pi/2))]
#room.moving_objects += [Object('desk', 1.45, 0.65, (1.5, 4.09-0.65/2, np.pi))]
room.moving_objects += [Object('desk', 1.45, 0.65, (4.9, 1, 0))]
room.moving_objects += [Object('wardrobe', 2, 0.58, (4.9, 0.58/2, 0))]
#room.moving_objects += [Object('wardrobe', 2, 0.58, (1.5, 0.58/2, 0))]
room.moving_objects += [Object('mirror', 0.47, 0.43, (3.6, 0.43/2, 0))]
room.moving_objects += [Object('plant', 0.6, 0.6, (3.5, 3.7, np.pi))]
room.draw()

# %%
room = Room(5.48, 6)
room.fixed_objects = [Object('door', 0.8, 0, (1.5, 0, 0))]
room.fixed_objects += [ Object('window', 0, 3, (0, 4, 0))]
#room.moving_objects = [Object('rug', 2.8, 2, (3.9, 2, np.pi/2)), Object('rug', 2.5, 1.5, (3.3, 5, np.pi))]
#room.moving_objects += [Object('bed', 2.22, 2.12, (5.48 - 2.12/2, 2, np.pi/2))]
#room.moving_objects += [Object('bed', 2.22, 2.12, (2.12/2, 3.6, np.pi/2))]
#room.moving_objects += [Object('nightstand', 0.4, 0.4, (5.48 - 0.2, 0.6, np.pi/2)), Object('nightstand', 0.4, 0.4, (5.48 - 0.2, 3.4, np.pi/2))]
room.moving_objects = [Object('chair', 0.7, 0.73, (2.1, 5.4,5*np.pi/4)), Object('chair', 0.7, 0.73, (4.5, 5.4, -5*np.pi/4))]
room.moving_objects += [Object('bookshelf', 1.5, 0.4, (3.3, 5.8, np.pi))]
room.moving_objects += [Object('wardrobe', 1.48, 0.62, (0.31, 1.7, -np.pi/2))]
room.moving_objects += [Object('mirror', 1, 0.43, (0.8, 5.4, 8*np.pi/7))]
room.moving_objects += [Object('plant', 0.6, 0.6, (5.48 - 0.3, 4, np.pi/2)), Object('plant', 0.6, 0.6, (0.3, 0.5, -np.pi/2))]

room.moving_objects += [Object('bed', 2.22, 2.12, (3.7, 2.12/2, 0))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (2.4, 0.2, 0)), Object('nightstand', 0.4, 0.4, (5, 0.2, 0))]
room.moving_objects += [Object('rug', 2.8, 2, (3.7, 1.6, 0)), Object('rug', 2.5, 1.5, (3.3, 5, np.pi))]




room.draw()

# %%
room = Room(5, 3.73)
room.fixed_objects = [Object('door', 0.8, 0, (1, 0, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (5, 3.73/2, 0))]
room.moving_objects = [Object('wardrobe', 1, 0.6, (3.6, 0.3, 0))]
room.moving_objects += [Object('dresser', 1.6, 0.48, (3.6, 3.73 - 0.48/2, np.pi))]
room.moving_objects += [Object('bed', 2.22, 2.12, (5 - 2.12/2, 3.73/2, np.pi/2))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (4.8, 3.2, np.pi/2)), Object('nightstand', 0.4, 0.4, (4.8, 0.5, np.pi/2))]


room.draw()

# %%
room = Room(5, 3.73)
room.fixed_objects = [Object('door', 0.8, 0, (1, 0, 0))]
room.fixed_objects += [ Object('window', 0, 2.1, (5, 3.73/2, 0))]
room.moving_objects = [Object('wardrobe', 1, 0.6, (0.3, 2.1, 3*np.pi/2))]
room.moving_objects += [Object('dresser', 1.6, 0.48, (0.48/2, 0.8, 3*np.pi/2))]
room.moving_objects += [Object('bed', 2.22, 2.12, (3.4, 3.73 - 2.12/2, np.pi))]
room.moving_objects += [Object('nightstand', 0.4, 0.4, (2.1, 3.53, np.pi)), Object('nightstand', 0.4, 0.4, (4.7, 3.53, np.pi))]
room.moving_objects += [Object('mirror', 0.8, 0.46, (0.8, 3.2, 5*np.pi/4))]
room.moving_objects += [Object('rug', 2.8, 1.8, (3.4, 2, np.pi))]

room.draw()
