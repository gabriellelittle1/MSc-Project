# %%
import openai
from openai.types import Completion, CompletionChoice, CompletionUsage
import os
import requests
from dotenv import load_dotenv
from scipy.optimize import minimize, Bounds, NonlinearConstraint
from functools import partial 

load_dotenv("/Users/gabriellelittlefair/Documents/GitHub/MSc Project/DSL/hidden.env")
# %reload_ext autoreload
from Setup_Functions import *
from Class_Structures import *
from Region import * 
from Individual import * 
from Pairwise import *

# %%
api_key = os.getenv('OPENAI_API_KEY')
client = openai.Client(api_key=api_key)
# If you're setting the API key directly in your script, uncomment the next line 

def room_setup(scene_descriptor, api_key=api_key):
    url = 'https://api.openai.com/v1/chat/completions'
    headers = {
        'Authorization': f'Bearer {api_key}',
        'Content-Type': 'application/json',
            }
    
    # Read the contents of the .py file
    file_path = '/Users/gabriellelittlefair/Documents/GitHub/MSc Project/DSL/Setup_Functions.py'
    with open(file_path, 'r') as file:
        file_contents = file.read()

    prompt1 = "I am designing the layout for" + scene_descriptor + ". Please give me the dimensions of the room,"
    prompt1 += " as well as the number of windows, doors, and sockets. For each window, door, and socket tell me the dimensions (in meters),"
    prompt1 += " which wall it should be on, as well as where on the wall it should be (this is a value between 0 and 1 determining how far along the wall it should be). Here is an example for a room and window set up: "
    prompt1 += "{Room: width = 5,  length = 6}, {Object type: window, width = 1, length = 0.1, wall = south, position = 3}, etc." 
    prompt1 += "The windows and doors should all have length 0.1. Ensure that every object has dimensions, position, and wall. "
    prompt1 += "No other text please. Just the list with no commentary or explanation."
    response1 = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt1}],
        max_tokens=500
    )
    objects = response1.choices[0].message.content.split("}, {")

    prompt2 = f"I am going to give you a set of functions that are used to create a room and put objects in it. The functions are as follows:"
    prompt2 += "\n\n{file_contents}\n\n"
    prompt2 += f"I now want, for each element in this list: {objects}, with room descriptor:" + scene_descriptor + ", for you to translate it into a function call using the functions I gave you above."
    prompt2 += " For example, given the room descriptor 'a small kitchen' as well as the list: "
    prompt2 += "{Room: width = 5,  length = 6}, {Object type: window, Number: 1,  width = 1, length = 0.1, wall = south, position = 0.3}, the output would be:"
    prompt2 += "kitchen = create_room(5, 6), create_fixed_object(kitchen, 'window', 1, 0.1, 'south', position = 0.3)."#, kitchen.draw()."
    prompt2 += " Return only the python script. No other text. Please ensure the correct number of inputs are given for each function."
    #prompt2 += " The code should end with '.draw()'."
    prompt2 += file_contents

    # Define the request payload
    data = {
        "model": "gpt-4",
        "messages": [
            {"role": "user", "content": prompt2}
        ]
    }
    
    # Make the API call
    response2 = requests.post(url, headers=headers, json=data)  
    # Check the response
    if response2.status_code == 200:
        response_data2 = response2.json()
        if "```python" in response_data2['choices'][0]['message']['content']:
            response2 = (response_data2['choices'][0]['message']['content'].split("```python")[1]).split("```")[0]
        elif "```" in response_data2['choices'][0]['message']['content']:
            response2 = (response_data2['choices'][0]['message']['content'].split("```")[1]).split("```")[0]
        else: 
            response2 = response_data2['choices'][0]['message']['content']
        print(response2)
        exec(response2)
    else:
        print('Failed to get a response')
        print(response2.text)

    return response1, response2

scene_descriptor = "a large bedroom for a young couple"
response1, response2 = room_setup(scene_descriptor)
# Out:
# bedroom = create_room(5, 7)
# create_fixed_object(bedroom, 'door', 0.8, 0.1, 'north', position = 0)
# create_fixed_object(bedroom, 'window', 1.2, 0.1, 'east', position = 0.25)
# create_fixed_object(bedroom, 'window', 1.2, 0.1, 'east', position = 0.75)
# create_fixed_object(bedroom, 'socket', 0.15, 0.1, 'south', position = 0.3)
# create_fixed_object(bedroom, 'socket', 0.15, 0.1, 'south', position = 0.7)
# create_fixed_object(bedroom, 'socket', 0.15, 0.1, 'west', position = 0.5)

# %%
url = 'https://api.openai.com/v1/chat/completions'
headers = {
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json',
        }

# Read the contents of the .py file
file_path = '/Users/gabriellelittlefair/Documents/GitHub/MSc Project/DSL/Setup_Functions.py'
with open(file_path, 'r') as file:
    file_contents = file.read()

prompt3 = "Interior designers suggest that rooms should have distinct regions in them for different functions. Given the description:"
prompt3 += scene_descriptor
prompt3 += ", what regions should this room have? Pick a reasonable number of these for this room (ensure that the most important are included)"
prompt3 += " and return them in a simple list. For example if the scene description was 'An open plan kitchen dining room', the output would be "
prompt3 += "'cooking region, dining region, cleaning region' etc. Please give no other text."

response3 = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt3}],
        max_tokens=500
    )

prompt4 = "For each region in the room described as: " + scene_descriptor + "with regions: " + response3.choices[0].message.content + ", give me all of the constraints/considerations on its position within the room."
prompt4 += " These constraints should depend on the physical features of the room, these are the physical features in the current room:"
prompt4 += response1.choices[0].message.content
prompt4 += ". The constraints should also depend on the other regions. For example, the constraints might be something like"
prompt4 += " 'the cooking region should be near the dining region', 'the sleeping region should have a plug in it'"
prompt4 += " or 'the storage region should be against a wall'. For the final constraint, determine whether there should be a focal point, and which region in the room should be the focal point (and based on the room whether the focal point should be a window or the longest wall in the room). Return a list of these, and keep each"
prompt4 += " constraint/consideration short and simple, but make sure that you include all of the necessary considerations for"
prompt4 += " functionality as well as any design principles you think are important. Give no other text, only the list. Remove any reasoning"
prompt4 += " or explanation for the constraint/consideration. Instead of 'Sleeping region should be near an electrical plug for a bedside lamp or charging devices'"
prompt4 += " just say 'Sleeping region should be near a plug'."

response4 = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt4}],
        max_tokens=500
    )

prompt5 = "Given the room so far: " + response2 + ", and the regions: " + response3.choices[0].message.content
prompt5 += " Using the functions in the script, initialise each region. For example 'eating region' might output 'eating_region = region_setup(kitchen, 'eating', 0)."
#prompt5 += " End with something like kitchen.draw(draw_regions = True)."
prompt5 += " No other text please, only the python script. Don't include the room so far in the output."
prompt5 += file_contents
 # Define the request payload
data = {
    "model": "gpt-4",
    "messages": [
            {"role": "user", "content": prompt5}
            ]
    }
    
# Make the API call
response5 = requests.post(url, headers=headers, json=data)  
# Check the response
if response5.status_code == 200:
    response_data5 = response5.json()
    if "```python" in response_data5['choices'][0]['message']['content']:
        response5 = response2 + "\n" + (response_data5['choices'][0]['message']['content'].split("```python")[1]).split("```")[0]
    else: 
        response5 = response2 + "\n" + response_data5['choices'][0]['message']['content']
    print(response5)
else:
    print('Failed to get a response')
    print(response5.text)
# Out:
# large_bedroom = create_room(6, 7)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.25)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.75)
# create_fixed_object(large_bedroom, 'door', 1, 0.1, 'west', position = 0.2)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'west', position = 0.6)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.3)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.7)
# sleeping_region = region_setup(large_bedroom, 'sleeping', 0)
# dressing_region = region_setup(large_bedroom, 'dressing', 1)
# sitting_reading_region = region_setup(large_bedroom, 'sitting/reading', 2)
# storage_closet_region = region_setup(large_bedroom, 'storage/closet', 3)
# work_study_region = region_setup(large_bedroom, 'work/study', 4)

# %%
url = 'https://api.openai.com/v1/chat/completions'
headers = {
    'Authorization': f'Bearer {api_key}',
    'Content-Type': 'application/json',
         }
# Read the contents of the .py file
file_path2 = '/Users/gabriellelittlefair/Documents/GitHub/MSc Project/BlankConstraints/Region.py'
with open(file_path2, 'r') as file:
    file_contents2 = file.read()


prompt6 = "Given the room set up so far: " + response5
prompt6 += ", and the regions: " + response3.choices[0].message.content + " and the constraints: " + response4.choices[0].message.content
prompt6 += " . Using the script attached, transform each constraint into a function call that will ensure that the regions are set up correctly. Match each constraint"
prompt6 += " to the closest function in the script file by using the docstrings. If you cannot find a function that matches the constraint, leave it out."
prompt6 += file_contents2
prompt6 += ". Then, once each point has been transformed to a function call, I then want the output to begin with (change 'room' to be the room name): "
prompt6 += "positions = np.zeros(2*len(room.regions)) \n for i in range(len(room.regions)): \n positions[2*(room.regions[i].index)] = room.regions[i].x"
prompt6 +=  "\n positions[2*(room.regions[i].index) + 1] = room.regions[i].y"
prompt6 += "\n def optimize_regions(positions, room): \n output = 0, followed by each constraint added to the ouput, and then the output returned."
prompt6 += "Finally, add this at the end (replacing 'room' with the name of the room): "
prompt6 += "bounds = Bounds([0] * 2 * len(room.regions), [room.width, room.length] * len(room.regions)) \n"
prompt6 += "res = minimize(optimize_regions, positions, args = (room), method = 'Nelder-Mead', bounds=bounds) \n"
prompt6 += "for i in range(len(room.regions)): \n room.regions[i].x, room.regions[i].y = res.x[2*(room.regions[i].index):2*(room.regions[i].index) + 2]" 
#prompt6 += " \n room.draw(draw_regions = True)"
prompt6 += ". The functions are all already defined in the script, you just need to call them. Remember that 'door' is NOT a region."
prompt6 += "No extra text please, only the functions and the output. Don't have 'python' at the start of the code."

# Define the request payload
data = {
    "model": "gpt-4o",
    "messages": [
            {"role": "user", "content": prompt6}
            ]
    }
    
# Make the API call
response6 = requests.post(url, headers=headers, json=data)  
# Check the response
if response6.status_code == 200:
    response_data6 = response6.json()
    print(response6.json()['choices'][0]['message']['content'])
    if "```python" in response_data6['choices'][0]['message']['content']:
        response6 = (response_data6['choices'][0]['message']['content'].split("```python")[1]).split("```")[0]
        response6 = response5 + "\n" + response6
    else: 
        response6 = response_data6['choices'][0]['message']['content']
        response6 = response5 + "\n" + response6
    # Create a dictionary to hold the local context
    global_context = globals().copy()
    local_context = {}  
    exec(response6, global_context, local_context)
else:
    print('Failed to get a response')
    print(response6.text)
# Out:
# positions = np.zeros(2*len(large_bedroom.regions))
# for i in range(len(large_bedroom.regions)):
#     positions[2*(large_bedroom.regions[i].index)] = large_bedroom.regions[i].x
#     positions[2*(large_bedroom.regions[i].index) + 1] = large_bedroom.regions[i].y
#
# def optimize_regions(positions, room):
#     output = 0
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'sleeping', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'door')
#     output += reg_close_to_fixed_object(positions, room, 'dressing', 'window')
#     output += reg_close_to_reg(positions, room, 'dressing', 'storage/closet')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'socket')
#     output += reg_away_from_reg(positions, room, 'sitting/reading', 'sleeping')
#     output += reg_close_to_wall(positions, room, 'storage/closet')
#     output += reg_close_to_reg(positions, room, 'storage/closet', 'dressing')
#     output += reg_close_to_fixed_object(positions, room, 'work/study', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'work/study', 'window')
#     output += reg_away_from_reg(positions, room, 'work/study', 'sleeping')
#     output += reg_include_focal_point(positions, room, 'sitting/reading')
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 0)
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 1)
#     return output
#
# bounds = Bounds([0] * 2 * len(large_bedroom.regions), [large_bedroom.width, large_bedroom.length] * len(large_bedroom.regions))
# res = minimize(optimize_regions, positions, args = (large_bedroom), method = 'Nelder-Mead', bounds=bounds)
# for i in range(len(large_bedroom.regions)):
#     large_bedroom.regions[i].x, large_bedroom.regions[i].y = res.x[2*(large_bedroom.regions[i].index):2*(large_bedroom.regions[i].index) + 2]

# %%
room_name = ((response6).split(" =")[0]).split("\n")[-1]

fixed_objects = ""
for i in range(len(local_context[room_name].fixed_objects)):
    if i < len(local_context[room_name].fixed_objects) - 1:
        fixed_objects +=local_context[room_name].fixed_objects[i].name + ", "
    else: 
        fixed_objects += local_context[room_name].fixed_objects[i].name + "."

room_width = local_context[room_name].width
room_length = local_context[room_name].length

region_names = ""
for i in range(len(local_context[room_name].regions)):
    if i < len(local_context[room_name].regions) - 1:
        region_names += local_context[room_name].regions[i].name + ", "
    else: 
        region_names += local_context[room_name].regions[i].name + "."
print(region_names)
# Out:
# sleeping, dressing, sitting/reading, storage/closet, work/study.

# %%
prompt7 = "I am going to give you a description of a room, as well as all the fixed objects inside it (e.g. windows) and the dimensions of the room."
prompt7 += " I am also going to give you the different regions for the room. Based on this information, "#I want returned the objects for each region "
#prompt7 += "(maximum of 3 - but there can be two of the same object, eg. there could be one bed 2 nightstands or 2 sofas and a coffee table),"
prompt7 += "I want returned the most important or biggest object for each region"
prompt7 += " and the dimensions for those object in meters. This should include width (this is the dimension of the back of the object) and length (dimension of the side of the object), not height. The room description is: "
prompt7 += scene_descriptor + ", and the regions are: " + region_names + ". The fixed objects are: " + fixed_objects
prompt7 += " Finally, the room dimensions are, width : " + str(room_width) + " meters, and length : " + str(room_length) + " meters."
prompt7 += "Please return it in the format of {object_name: name, object_width: width, object_length: length, region: region_name}. After the list, I also want you to give me all the constraints for each object"
prompt7 += " that depend ONLY on the items in the room (e.g. walls, windows, doors, plugs), they cannot depend on any other items in this list. For example if an object should have its back against a wall, or if it should be far away from a window, or near a socket."
prompt7 += "I also want for each object an accessibility constraint about its usage (to prevent the sides being blocked), something like 'the bed should be accessible from the left, right, and front' or 'the sofa should be accessible from the front'. Give all of these as simply as possible, in the following format:  "
prompt7 += "{object_name: name, constraints: [constraint1, constraint2, ...]}. Give no other text in the response. Remove any constraints that involve other objects in the list."

response7 = client.chat.completions.create(
        model="gpt-4o",
        messages=[{"role": "user", "content": prompt7}],
        max_tokens=1000
    )

print(response7.choices[0].message.content)
# Out:
# [
#     {object_name: "bed", object_width: 2, object_length: 2, region: "sleeping"},
#     {object_name: "wardrobe", object_width: 1.5, object_length: 0.6, region: "dressing"},
#     {object_name: "sofa", object_width: 1.8, object_length: 0.8, region: "sitting/reading"},
#     {object_name: "closet", object_width: 2, object_length: 1, region: "storage/closet"},
#     {object_name: "desk", object_width: 1.5, object_length: 0.6, region: "work/study"}
# ]
#
# [
#     {object_name: "bed", constraints: ["back against a wall", "accessible from the left, right, and front"]},
#     {object_name: "wardrobe", constraints: ["back against a wall", "accessible from the front"]},
#     {object_name: "sofa", constraints: ["back against a wall", "accessible from the front"]},
#     {object_name: "closet", constraints: ["back against a wall", "accessible from the front"]},
#     {object_name: "desk", constraints: ["near a socket", "back against a wall", "accessible from the front"]}
# ]

# %%
prompt8 = "Given this list of the objects: " + response7.choices[0].message.content.split("]")[0] + "], use the file attached to create the objects with the correct parameters."
prompt8 += "The room code so far is: " + response6 + " The code so far should NOT be included in the output."
prompt8 += "The room is already set up, only add in the objects using the 'create_moving_object' function. The regions are: " + region_names + "."
prompt8 += "The objects should be added in the correct regions."
#prompt8 += " The code should end with 'room.draw(draw_regions = True)', Only with 'room' replaced by the room name."
prompt8 += "This is the file: " + file_contents
prompt8 += "No extra text, only the function calls. Don't have 'python' at the start of the code. Do not define ANY functions, only call them."

# Define the request payload
data = {
    "model": "gpt-4o",
    "messages": [
            {"role": "user", "content": prompt8}
            ]
    }
    
# Make the API call
response8 = requests.post(url, headers=headers, json=data)  
# Check the response
if response8.status_code == 200:
    response_data8 = response8.json()
    if "```python" in response8.json()['choices'][0]['message']['content']:
        response8 = response6 + "\n" + (response8.json()['choices'][0]['message']['content'].split("```python")[1]).split("```")[0]
        exec(response8)
    elif "```" in response8.json()['choices'][0]['message']['content']:
        response8 = response6 + "\n" + (response8.json()['choices'][0]['message']['content'].split("```")[1]).split("```")[0]
        exec(response8)
    else:
        response8 = response6 + "\n" + response8.json()['choices'][0]['message']['content']
        exec(response8)
    print(response8)
else:
    print('Failed to get a response')
    print(response8.text)
# Out:
# large_bedroom = create_room(6, 7)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.25)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.75)
# create_fixed_object(large_bedroom, 'door', 1, 0.1, 'west', position = 0.2)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'west', position = 0.6)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.3)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.7)
# sleeping_region = region_setup(large_bedroom, 'sleeping', 0)
# dressing_region = region_setup(large_bedroom, 'dressing', 1)
# sitting_reading_region = region_setup(large_bedroom, 'sitting/reading', 2)
# storage_closet_region = region_setup(large_bedroom, 'storage/closet', 3)
# work_study_region = region_setup(large_bedroom, 'work/study', 4)
# positions = np.zeros(2*len(large_bedroom.regions))
# for i in range(len(large_bedroom.regions)):
#     positions[2*(large_bedroom.regions[i].index)] = large_bedroom.regions[i].x
#     positions[2*(large_bedroom.regions[i].index) + 1] = large_bedroom.regions[i].y
#
# def optimize_regions(positions, room):
#     output = 0
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'sleeping', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'door')
#     output += reg_close_to_fixed_object(positions, room, 'dressing', 'window')
#     output += reg_close_to_reg(positions, room, 'dressing', 'storage/closet')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'socket')
#     output += reg_away_from_reg(positions, room, 'sitting/reading', 'sleeping')
#     output += reg_close_to_wall(positions, room, 'storage/closet')
#     output += reg_close_to_reg(positions, room, 'storage/closet', 'dressing')
#     output += reg_close_to_fixed_object(positions, room, 'work/study', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'work/study', 'window')
#     output += reg_away_from_reg(positions, room, 'work/study', 'sleeping')
#     output += reg_include_focal_point(positions, room, 'sitting/reading')
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 0)
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 1)
#     return output
#
# bounds = Bounds([0] * 2 * len(large_bedroom.regions), [large_bedroom.width, large_bedroom.length] * len(large_bedroom.regions))
# res = minimize(optimize_regions, positions, args = (large_bedroom), method = 'Nelder-Mead', bounds=bounds)
# for i in range(len(large_bedroom.regions)):
#     large_bedroom.regions[i].x, large_bedroom.regions[i].y = res.x[2*(large_bedroom.regions[i].index):2*(large_bedroom.regions[i].index) + 2]
# create_moving_object(large_bedroom, 'bed', 2, 2, 'sleeping', 0)
# create_moving_object(large_bedroom, 'wardrobe', 1.5, 0.6, 'dressing', 1)
# create_moving_object(large_bedroom, 'sofa', 1.8, 0.8, 'sitting/reading', 2)
# create_moving_object(large_bedroom, 'closet', 2, 1, 'storage/closet', 3)
# create_moving_object(large_bedroom, 'desk', 1.5, 0.6, 'work/study', 4)

# %%
# Read the contents of the .py file
file_path3 = '/Users/gabriellelittlefair/Documents/GitHub/MSc Project/BlankConstraints/Individual.py'
with open(file_path3, 'r') as file:
    file_contents3 = file.read()


prompt9 = "Given the room code so far: " + response8
prompt9 += ", as well as the primary objects and their constraints: " + response7.choices[0].message.content
prompt9 += " . Using the script attached, transform each constraint into function calls that will ensure that the primary objects are set up correctly. Match each constraint"
prompt9 += " to the closest function in the script file by using the docstrings. If you cannot find a function that matches the constraint, leave it out. Ensure each object also has an 'ind_in_region' constraint"
prompt9 += "Here is the script: " + file_contents3
prompt9 += ". I want the output to begin with: "
prompt9 += "positions = np.zeros(3*len(room.moving_objects)) \n for i in range(len(room.moving_objects)): \n positions[3*i] = room.moving_objects[i].position[0]\n"
prompt9 += "positions[3*i + 1] = room.moving_objects[i].position[1] \n positions[3*i + 2] = room.moving_objects[i].position[2] (where 'room' is replaced by whatever the room name is)"
prompt9 += "\n def optimize_primary_objects(positions, room): \n output = 0, followed by each constraint function call added to the ouput, and then the output returned."
prompt9 += "Finally, add this at the end (replacing 'room' with the name of the room): "
prompt9 += "bounds = Bounds([0] * 3 * len(room.moving_objects), [room.width, room.length, 2*np.pi] * len(room.moving_objects))\n"
prompt9 += "\n nonlinear_constraint1 = NonlinearConstraint(partial(ind_no_overlap, room = room), 0, 1e-3)"
prompt9 +="\n nonlinear_constraint2 = NonlinearConstraint(partial(ind_in_bounds, room = room), 0, 1e-3)"
prompt9 +="\n cons = [nonlinear_constraint1, nonlinear_constraint2]"
prompt9 +="\n options = {'maxiter': 5000}"
prompt9 +="\n res = minimize(optimize_primary_objects, positions, args = (room), method = 'SLSQP', bounds=bounds, constraints = cons, options = options)"
prompt9 +="\n print(res.message)"
prompt9 += "\n for i in range(len(room.moving_objects)): \n"
prompt9 += "room.moving_objects[i].position = res.x[3*i:3*i + 3] \n room.draw(draw_regions= True) \n "
prompt9 += "print(res.message)."
prompt9 += "No extra text please, only the functions and the output.  DON'T include any previous code. DON'T have 'python' at the start of the code. Do not define ANY functions, only call them."

# Define the request payload
data = {
    "model": "gpt-4o",
    "messages": [
            {"role": "user", "content": prompt9}
            ]
    }
    
# Make the API call
response9 = requests.post(url, headers=headers, json=data)  
# Check the response
if response9.status_code == 200:
    response_data9 = response9.json()

    print(response9.json()['choices'][0]['message']['content'])
    if "```python" in response9.json()['choices'][0]['message']['content']:
        response9 = response8 + "\n" + (response9.json()['choices'][0]['message']['content'].split("```python")[1]).split("```")[0]
        print(response9)
        exec(response9)

    elif "```" in response9.json()['choices'][0]['message']['content']:
        response9 = response8 + "\n" + (response9.json()['choices'][0]['message']['content'].split("```")[1]).split("```")[0]
        print(response9)
        exec(response9)
    else:
        response9 = response8 + "\n" + response9.json()['choices'][0]['message']['content']
        print(response9)
        exec(response9)
else:
    print('Failed to get a response')
    print(response9.text)
# Out:
# positions = np.zeros(3*len(large_bedroom.moving_objects))
# for i in range(len(large_bedroom.moving_objects)):
#     positions[3*i] = large_bedroom.moving_objects[i].position[0]
#     positions[3*i + 1] = large_bedroom.moving_objects[i].position[1]
#     positions[3*i + 2] = large_bedroom.moving_objects[i].position[2]
#
# def optimize_primary_objects(positions, room):
#     output = 0
#     output += ind_next_to_wall(positions, room, 0, 'back')  # bed
#     output += ind_accessible(positions, room, 0, ['left', 'right', 'front'])  # bed
#     output += ind_in_region(positions, room, 0, 'sleeping')  # bed
#     output += ind_next_to_wall(positions, room, 1, 'back')  # wardrobe
#     output += ind_accessible(positions, room, 1, ['front'])  # wardrobe
#     output += ind_in_region(positions, room, 1, 'dressing')  # wardrobe
#     output += ind_next_to_wall(positions, room, 2, 'back')  # sofa
#     output += ind_accessible(positions, room, 2, ['front'])  # sofa
#     output += ind_in_region(positions, room, 2, 'sitting/reading')  # sofa
#     output += ind_next_to_wall(positions, room, 3, 'back')  # closet
#     output += ind_accessible(positions, room, 3, ['front'])  # closet
#     output += ind_in_region(positions, room, 3, 'storage/closet')  # closet
#     output += ind_close_to_fixed_object(positions, room, 4, 'socket')  # desk
#     output += ind_next_to_wall(positions, room, 4, 'back')  # desk
#     output += ind_accessible(positions, room, 4, ['front'])  # desk
#     output += ind_in_region(positions, room, 4, 'work/study')  # desk
#     return output
#
# bounds = Bounds([0] * 3 * len(large_bedroom.moving_objects), [large_bedroom.width, large_bedroom.length, 2*np.pi] * len(large_bedroom.moving_objects))
# nonlinear_constraint1 = NonlinearConstraint(partial(ind_no_overlap, room = large_bedroom), 0, 1e-3)
# nonlinear_constraint2 = NonlinearConstraint(partial(ind_in_bounds, room = large_bedroom), 0, 1e-3)
# cons = [nonlinear_constraint1, nonlinear_constraint2]
# options = {'maxiter': 5000}
# res = minimize(optimize_primary_objects, positions, args = (large_bedroom), method = 'SLSQP', bounds=bounds, constraints = cons, options = options)
# print(res.message)
# for i in range(len(large_bedroom.moving_objects)):
#     large_bedroom.moving_objects[i].position = res.x[3*i:3*i + 3]
# large_bedroom.draw(draw_regions= True)
# print(res.message)
# large_bedroom = create_room(6, 7)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.25)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.75)
# create_fixed_object(large_bedroom, 'door', 1, 0.1, 'west', position = 0.2)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'west', position = 0.6)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.3)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.7)
# sleeping_region = region_setup(large_bedroom, 'sleeping', 0)
# dressing_region = region_setup(large_bedroom, 'dressing', 1)
# sitting_reading_region = region_setup(large_bedroom, 'sitting/reading', 2)
# storage_closet_region = region_setup(large_bedroom, 'storage/closet', 3)
# work_study_region = region_setup(large_bedroom, 'work/study', 4)
# positions = np.zeros(2*len(large_bedroom.regions))
# for i in range(len(large_bedroom.regions)):
#     positions[2*(large_bedroom.regions[i].index)] = large_bedroom.regions[i].x
#     positions[2*(large_bedroom.regions[i].index) + 1] = large_bedroom.regions[i].y
#
# def optimize_regions(positions, room):
#     output = 0
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'sleeping', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'door')
#     output += reg_close_to_fixed_object(positions, room, 'dressing', 'window')
#     output += reg_close_to_reg(positions, room, 'dressing', 'storage/closet')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'socket')
#     output += reg_away_from_reg(positions, room, 'sitting/reading', 'sleeping')
#     output += reg_close_to_wall(positions, room, 'storage/closet')
#     output += reg_close_to_reg(positions, room, 'storage/closet', 'dressing')
#     output += reg_close_to_fixed_object(positions, room, 'work/study', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'work/study', 'window')
#     output += reg_away_from_reg(positions, room, 'work/study', 'sleeping')
#     output += reg_include_focal_point(positions, room, 'sitting/reading')
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 0)
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 1)
#     return output
#
# bounds = Bounds([0] * 2 * len(large_bedroom.regions), [large_bedroom.width, large_bedroom.length] * len(large_bedroom.regions))
# res = minimize(optimize_regions, positions, args = (large_bedroom), method = 'Nelder-Mead', bounds=bounds)
# for i in range(len(large_bedroom.regions)):
#     large_bedroom.regions[i].x, large_bedroom.regions[i].y = res.x[2*(large_bedroom.regions[i].index):2*(large_bedroom.regions[i].index) + 2]
# create_moving_object(large_bedroom, 'bed', 2, 2, 'sleeping', 0)
# create_moving_object(large_bedroom, 'wardrobe', 1.5, 0.6, 'dressing', 1)
# create_moving_object(large_bedroom, 'sofa', 1.8, 0.8, 'sitting/reading', 2)
# create_moving_object(large_bedroom, 'closet', 2, 1, 'storage/closet', 3)
# create_moving_object(large_bedroom, 'desk', 1.5, 0.6, 'work/study', 4)
# positions = np.zeros(3*len(large_bedroom.moving_objects))
# for i in range(len(large_bedroom.moving_objects)):
#     positions[3*i] = large_bedroom.moving_objects[i].position[0]
#     positions[3*i + 1] = large_bedroom.moving_objects[i].position[1]
#     positions[3*i + 2] = large_bedroom.moving_objects[i].position[2]
#
# def optimize_primary_objects(positions, room):
#     output = 0
#     output += ind_next_to_wall(positions, room, 0, 'back')  # bed
#     output += ind_accessible(positions, room, 0, ['left', 'right', 'front'])  # bed
#     output += ind_in_region(positions, room, 0, 'sleeping')  # bed
#     output += ind_next_to_wall(positions, room, 1, 'back')  # wardrobe
#     output += ind_accessible(positions, room, 1, ['front'])  # wardrobe
#     output += ind_in_region(positions, room, 1, 'dressing')  # wardrobe
#     output += ind_next_to_wall(positions, room, 2, 'back')  # sofa
#     output += ind_accessible(positions, room, 2, ['front'])  # sofa
#     output += ind_in_region(positions, room, 2, 'sitting/reading')  # sofa
#     output += ind_next_to_wall(positions, room, 3, 'back')  # closet
#     output += ind_accessible(positions, room, 3, ['front'])  # closet
#     output += ind_in_region(positions, room, 3, 'storage/closet')  # closet
#     output += ind_close_to_fixed_object(positions, room, 4, 'socket')  # desk
#     output += ind_next_to_wall(positions, room, 4, 'back')  # desk
#     output += ind_accessible(positions, room, 4, ['front'])  # desk
#     output += ind_in_region(positions, room, 4, 'work/study')  # desk
#     return output
#
# bounds = Bounds([0] * 3 * len(large_bedroom.moving_objects), [large_bedroom.width, large_bedroom.length, 2*np.pi] * len(large_bedroom.moving_objects))
# nonlinear_constraint1 = NonlinearConstraint(partial(ind_no_overlap, room = large_bedroom), 0, 1e-3)
# nonlinear_constraint2 = NonlinearConstraint(partial(ind_in_bounds, room = large_bedroom), 0, 1e-3)
# cons = [nonlinear_constraint1, nonlinear_constraint2]
# options = {'maxiter': 5000}
# res = minimize(optimize_primary_objects, positions, args = (large_bedroom), method = 'SLSQP', bounds=bounds, constraints = cons, options = options)
# print(res.message)
# for i in range(len(large_bedroom.moving_objects)):
#     large_bedroom.moving_objects[i].position = res.x[3*i:3*i + 3]
# large_bedroom.draw(draw_regions= True)
# print(res.message)
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756632710371
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756659838829
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822757130173557
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.9000000000000001
# Intersection between wardrobe and desk is 0.8158748217233447
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999441206453
# Intersection between wardrobe and desk is 0.815874786106461
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999770907039
# Intersection between wardrobe and desk is 0.8158748091809125
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999776482581
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999776482579
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.899999982444985
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999856095547
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748217233448
# Intersection between closet and desk is 0.8999999999999999
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748966116074
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748091809124
# Intersection between closet and desk is 0.8999999802506062
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756687487114
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756830530585
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.38227569868467
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.9000000000000001
# Intersection between wardrobe and desk is 0.8158748217233447
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999910593032
# Intersection between wardrobe and desk is 0.8158748330451188
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999951384962
# Intersection between wardrobe and desk is 0.8158748350243987
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999776482581
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999776482579
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.89999999627471
# Intersection between wardrobe and desk is 0.8158748419858155
# Intersection between closet and desk is 0.8999999969462524
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748217233448
# Intersection between closet and desk is 0.8999999999999999
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748509265121
# Intersection between closet and desk is 0.8999999999999997
# Intersection between bed and door is 1.3822756948238986
# Intersection between wardrobe and closet is 0.8999999999999999
# Intersection between wardrobe and desk is 0.8158748350243988
# Intersection between closet and desk is 0.8999999958090482
# Intersection between bed and door is 1.7498762273202306
# Intersection between wardrobe and sofa is 0.3250564293660797
# Intersection between wardrobe and closet is 0.24021201578591794
# Intersection between sofa and closet is 0.3875170879385065
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.4557957701393969
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.4557957838176798
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.4557958001937223
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033617935114
# Intersection between wardrobe and desk is 0.5841093877368893
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033316508172
# Intersection between wardrobe and desk is 0.5841093819034094
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033413490275
# Intersection between wardrobe and desk is 0.5841093932311963
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006532953462
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033194870625
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006390900177
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033496297569
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006535826732
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033448824106
# Intersection between wardrobe and desk is 0.5841093905657851
# Intersection between closet and desk is 0.8778006543113476
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.58410939339467
# Intersection between closet and desk is 0.8778006675006701
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093992281609
# Intersection between closet and desk is 0.8778006530080188
# Intersection between bed and door is 1.455795796214584
# Intersection between wardrobe and closet is 0.8286033406402872
# Intersection between wardrobe and desk is 0.5841093864599958
# Intersection between closet and desk is 0.8778006496016995
# Intersection between bed and door is 1.244905393319146
# Intersection between wardrobe and closet is 0.05035285828651357
# Intersection between closet and desk is 0.1206946921417059
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.361403615859679
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036262333489
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036401287075
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811753602507
# Intersection between wardrobe and desk is 0.01699223096288501
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001810352845637
# Intersection between wardrobe and desk is 0.016992225394716627
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811404473129
# Intersection between wardrobe and desk is 0.016992229276437683
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.62463246275398
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001810434459386
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.6246324559034051
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811835216237
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.6246324566577389
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001810597078525
# Intersection between wardrobe and desk is 0.016992227712207195
# Intersection between closet and desk is 0.6246324615517831
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992224461529634
# Intersection between closet and desk is 0.6246324696045545
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992230029697863
# Intersection between closet and desk is 0.6246324688502211
# Intersection between bed and door is 1.3614036387283144
# Intersection between wardrobe and closet is 0.11001811094030936
# Intersection between wardrobe and desk is 0.016992229088520015
# Intersection between closet and desk is 0.6246324633475083
# Intersection between bed and door is 0.6615109989108418
# Intersection between wardrobe and sofa is 0.025344925826250867
# Intersection between wardrobe and closet is 0.148878988672839
# Intersection between sofa and closet is 0.34442148811251067
# Intersection between desk and door is 0.5286356573355715
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.2987922795861788
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.2987922884173633
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792302204304
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.2701551507431795
# Intersection between wardrobe and desk is 0.003729648607404308
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015513527151336
# Intersection between wardrobe and desk is 0.0037296462210480745
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.2701551457771576
# Intersection between wardrobe and desk is 0.0037296479527071623
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388076363164
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015513403702657
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388080614514
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514950869296
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.26423879577302356
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015513759182824
# Intersection between wardrobe and desk is 0.0037296473893610174
# Intersection between closet and desk is 0.2642388133032198
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296461713175488
# Intersection between closet and desk is 0.26423880721118115
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296485576741407
# Intersection between closet and desk is 0.2642388194996094
# Intersection between bed and door is 1.298792301212151
# Intersection between wardrobe and closet is 0.27015514239010324
# Intersection between wardrobe and desk is 0.0037296485149124763
# Intersection between closet and desk is 0.2642388112353097
# Intersection between bed and desk is 0.28200566179054
# Intersection between bed and door is 0.2890309742108315
# Intersection between wardrobe and desk is 0.05267160073779677
# Intersection between sofa and closet is 0.014663251758636479
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.0008283770550193438
# Intersection between bed and door is 0.8445956721908321
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.0008283781595133983
# Intersection between bed and door is 0.8445956777044518
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.0008283765541544813
# Intersection between bed and door is 0.8445956885348758
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051542637944364
# Intersection between wardrobe and desk is 0.027140296218508227
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541409493373
# Intersection between wardrobe and desk is 0.027140291302416675
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.0905154190172467
# Intersection between wardrobe and desk is 0.02714029526954849
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.0974711319263882
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051540366690801
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.09747112733347688
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541595141786
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.09747112621606006
# Intersection between bed and desk is 0.000828376975550417
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541382699865
# Intersection between wardrobe and desk is 0.027140295024304418
# Intersection between closet and desk is 0.09747113422118181
# Intersection between bed and desk is 0.0008283768960814943
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.02714029383010055
# Intersection between closet and desk is 0.09747113651929958
# Intersection between bed and desk is 0.0008283757915883109
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140298746192257
# Intersection between closet and desk is 0.09747113763671647
# Intersection between bed and desk is 0.0008283769147964106
# Intersection between bed and door is 0.8445956887632109
# Intersection between wardrobe and closet is 0.09051541502317578
# Intersection between wardrobe and desk is 0.027140296007017874
# Intersection between closet and desk is 0.09747113078161287
# Intersection between bed and desk is 0.06747734097707218
# Intersection between bed and door is 0.09533131544146209
# Intersection between wardrobe and closet is 0.17187801624886345
# Intersection between sofa and closet is 0.23376590878848558
# Intersection between bed and desk is 0.02489980202103647
# Intersection between bed and door is 0.6438298533854823
# Intersection between wardrobe and closet is 0.11662714240256654
# Intersection between wardrobe and desk is 0.016759264146099205
# Intersection between sofa and closet is 0.0021596442321621273
# Intersection between closet and desk is 0.06532914606947743
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061921488454
# Intersection between bed and door is 0.7441146371665268
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949065475056518
# Intersection between bed and door is 0.744114642608755
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949059838767623
# Intersection between bed and door is 0.7441146524343354
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.1037579127625769
# Intersection between wardrobe and desk is 0.024757341682505648
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790067240707
# Intersection between wardrobe and desk is 0.024757336304875102
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790575025608
# Intersection between wardrobe and desk is 0.024757340902698897
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806905814663
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375789099566429
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806451699848
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790308583403
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217806442695996
# Intersection between bed and desk is 0.007949061674808975
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790063626776
# Intersection between wardrobe and desk is 0.0247573412603444
# Intersection between closet and desk is 0.08217807063052807
# Intersection between bed and desk is 0.007949061428129506
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.024757340838183216
# Intersection between closet and desk is 0.08217807359929495
# Intersection between bed and desk is 0.007949057874562335
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.024757346215813762
# Intersection between closet and desk is 0.08217807368933343
# Intersection between bed and desk is 0.007949061712436431
# Intersection between bed and door is 0.7441146528775764
# Intersection between wardrobe and closet is 0.10375790187912053
# Intersection between wardrobe and desk is 0.024757341928258323
# Intersection between closet and desk is 0.08217806779721787
# Intersection between wardrobe and closet is 0.5604522228265468
# Intersection between sofa and closet is 0.7020524580648095
# Intersection between bed and door is 0.49229668544720306
# Intersection between wardrobe and closet is 0.1706003273543712
# Intersection between wardrobe and desk is 0.11407412886365283
# Intersection between sofa and closet is 0.054571879904340495
# Intersection between closet and desk is 0.03332860433259203
# Intersection between bed and desk is 0.0007144817285038099
# Intersection between bed and door is 0.6827760427803264
# Intersection between wardrobe and closet is 0.11927912701568909
# Intersection between wardrobe and desk is 0.0421037133484706
# Intersection between sofa and closet is 0.0012093014196468178
# Intersection between closet and desk is 0.0723686525951451
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945524996797
# Intersection between bed and door is 0.7105758959149839
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008947713016616
# Intersection between bed and door is 0.7105759018057229
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008944382619563
# Intersection between bed and door is 0.7105759110093537
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216281850216536
# Intersection between wardrobe and desk is 0.03368415379242326
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280607304188
# Intersection between wardrobe and desk is 0.03368414758253444
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.1121628112553533
# Intersection between wardrobe and desk is 0.03368415300650982
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350220181106192e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350346289851032e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350337262676496e-06
# Intersection between closet and desk is 0.07700502884771764
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216279631899513
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350526604545277e-06
# Intersection between closet and desk is 0.07700502421108742
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280874811843
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350400494582197e-06
# Intersection between closet and desk is 0.07700502469850519
# Intersection between bed and desk is 0.003008945417052636
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.1121628060264136
# Intersection between wardrobe and desk is 0.03368415322288199
# Intersection between sofa and closet is 9.350369050935149e-06
# Intersection between closet and desk is 0.07700503005946918
# Intersection between bed and desk is 0.003008945309108477
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415265334093
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.077005033484348
# Intersection between bed and desk is 0.003008943121089535
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415886322988
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700503299693005
# Intersection between bed and desk is 0.003008945356332911
# Intersection between bed and door is 0.710575911637863
# Intersection between wardrobe and closet is 0.11216280741058011
# Intersection between wardrobe and desk is 0.03368415410200212
# Intersection between sofa and closet is 9.35037339219852e-06
# Intersection between closet and desk is 0.07700502746773494
# Intersection between sofa and closet is 0.23956864922535392
# Intersection between bed and door is 0.29133698967178334
# Intersection between wardrobe and closet is 0.0010500952334201634
# Intersection between wardrobe and desk is 0.01976655451406761
# Intersection between sofa and closet is 0.03581021891187591
# Intersection between closet and desk is 0.02446922851827505
# Intersection between bed and door is 0.29133698967178334
# Intersection between wardrobe and closet is 0.0010500952334201634
# Intersection between wardrobe and desk is 0.01976655451406761
# Intersection between sofa and closet is 0.03581021891187591
# Intersection between closet and desk is 0.02446922851827505
# Intersection between bed and door is 0.2913369726901055
# Intersection between wardrobe and closet is 0.0010500952334201634
# Intersection between wardrobe and desk is 0.01976655451406761
# Intersection between sofa and closet is 0.03581021891187591
# Intersection between closet and desk is 0.02446922851827505
# Intersection between bed and door is 0.2913369852071459
# ...
# Intersection between wardrobe and desk is 7.713200218578739e-05
# Intersection between sofa and closet is 1.1645697841771569e-06
# Intersection between wardrobe and desk is 6.930322193985585e-05
# Intersection between sofa and closet is 3.5595340293701768e-06
# Intersection between wardrobe and desk is 6.776670660240995e-05
# Intersection between sofa and closet is 4.274046201180001e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745591372343303e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745561892774926e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745600197815772e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.430358252090476e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.430484833792773e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.430523873059812e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.43061864311032e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.430492059496064e-06
# Intersection between wardrobe and desk is 6.745594308539889e-05
# Intersection between sofa and closet is 4.43043953364513e-06
# Intersection between wardrobe and desk is 6.745597244737996e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745626724383643e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 6.745596115597817e-05
# Intersection between sofa and closet is 4.4304884466438645e-06
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089294301270671e-05
# Intersection between wardrobe and desk is 9.089260309344085e-05
# Intersection between wardrobe and desk is 9.089304531303449e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089297680348622e-05
# Intersection between wardrobe and desk is 9.089301059428286e-05
# Intersection between wardrobe and desk is 9.089335051429913e-05
# Intersection between wardrobe and desk is 9.089299570735277e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37748889760728e-05
# Intersection between wardrobe and desk is 7.37745849632143e-05
# Intersection between wardrobe and desk is 7.377497954647382e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.37749191998211e-05
# Intersection between wardrobe and desk is 7.377494942357565e-05
# Intersection between wardrobe and desk is 7.37752534371851e-05
# Intersection between wardrobe and desk is 7.37749350990361e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357706927575475e-05
# Intersection between wardrobe and desk is 7.357676790555921e-05
# Intersection between wardrobe and desk is 7.357715888142133e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.357709929829031e-05
# Intersection between wardrobe and desk is 7.3577129320832e-05
# Intersection between wardrobe and desk is 7.357743069176772e-05
# Intersection between wardrobe and desk is 7.357711371708445e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422092804010577e-05
# Intersection between wardrobe and desk is 7.422062641053965e-05
# Intersection between wardrobe and desk is 7.422101800593383e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422095813419495e-05
# Intersection between wardrobe and desk is 7.422098822828996e-05
# Intersection between wardrobe and desk is 7.422128985858174e-05
# Intersection between wardrobe and desk is 7.422097191490024e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482101070697394e-05
# Intersection between wardrobe and desk is 7.482070921297694e-05
# Intersection between wardrobe and desk is 7.482110117885252e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482104086071162e-05
# Intersection between wardrobe and desk is 7.482107101444548e-05
# Intersection between wardrobe and desk is 7.482137250917133e-05
# Intersection between wardrobe and desk is 7.482105380713821e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511625297049136e-05
# Intersection between wardrobe and desk is 7.511595136913953e-05
# Intersection between wardrobe and desk is 7.511634372937572e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511628317338951e-05
# Intersection between wardrobe and desk is 7.511631337628417e-05
# Intersection between wardrobe and desk is 7.511661497836315e-05
# Intersection between wardrobe and desk is 7.511629582973833e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512238750146747e-05
# Intersection between wardrobe and desk is 7.512208588322217e-05
# Intersection between wardrobe and desk is 7.512247829760412e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.512241771061483e-05
# Intersection between wardrobe and desk is 7.51224479197784e-05
# Intersection between wardrobe and desk is 7.512274953874107e-05
# Intersection between wardrobe and desk is 7.512243037360286e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463347304155854e-05
# Intersection between wardrobe and desk is 7.46331714740519e-05
# Intersection between wardrobe and desk is 7.463356369949653e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463350321350141e-05
# Intersection between wardrobe and desk is 7.463353338544955e-05
# Intersection between wardrobe and desk is 7.463383495368754e-05
# Intersection between wardrobe and desk is 7.463351646526612e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435118002316067e-05
# Intersection between wardrobe and desk is 7.435087838942918e-05
# Intersection between wardrobe and desk is 7.43512706381986e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435121018004747e-05
# Intersection between wardrobe and desk is 7.435124033695026e-05
# Intersection between wardrobe and desk is 7.435154197141567e-05
# Intersection between wardrobe and desk is 7.43512238342475e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435087891890221e-05
# Intersection between wardrobe and desk is 7.435057724617301e-05
# Intersection between wardrobe and desk is 7.43509695398886e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435090907804557e-05
# Intersection between wardrobe and desk is 7.435093923719451e-05
# Intersection between wardrobe and desk is 7.435124091065772e-05
# Intersection between wardrobe and desk is 7.435092275819932e-05
# Intersection between wardrobe and desk is 7.445021377677302e-05
# Intersection between wardrobe and desk is 7.438562718061288e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436639018589013e-05
# Intersection between wardrobe and desk is 7.436608851442662e-05
# Intersection between wardrobe and desk is 7.436648081700576e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436642034610918e-05
# Intersection between wardrobe and desk is 7.436645050633335e-05
# Intersection between wardrobe and desk is 7.436675217853098e-05
# Intersection between wardrobe and desk is 7.43664340058333e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443749193033813e-05
# Intersection between wardrobe and desk is 7.443719026788786e-05
# Intersection between wardrobe and desk is 7.443758258638147e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443752209689556e-05
# Intersection between wardrobe and desk is 7.443755226344868e-05
# Intersection between wardrobe and desk is 7.443785392664191e-05
# Intersection between wardrobe and desk is 7.443753566180851e-05
# Intersection between wardrobe and desk is 7.444182540402329e-05
# Intersection between wardrobe and desk is 7.443898612307866e-05
# Intersection between wardrobe and desk is 7.443826206421471e-05
# Optimization terminated successfully
# Optimization terminated successfully

# %%
print(response9)
# Out:
# large_bedroom = create_room(6, 7)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.25)
# create_fixed_object(large_bedroom, 'window', 1.5, 0.1, 'north', position = 0.75)
# create_fixed_object(large_bedroom, 'door', 1, 0.1, 'west', position = 0.2)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'west', position = 0.6)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.3)
# create_fixed_object(large_bedroom, 'socket', 0.1, 0.05, 'east', position = 0.7)
# sleeping_region = region_setup(large_bedroom, 'sleeping', 0)
# dressing_region = region_setup(large_bedroom, 'dressing', 1)
# sitting_reading_region = region_setup(large_bedroom, 'sitting/reading', 2)
# storage_closet_region = region_setup(large_bedroom, 'storage/closet', 3)
# work_study_region = region_setup(large_bedroom, 'work/study', 4)
# positions = np.zeros(2*len(large_bedroom.regions))
# for i in range(len(large_bedroom.regions)):
#     positions[2*(large_bedroom.regions[i].index)] = large_bedroom.regions[i].x
#     positions[2*(large_bedroom.regions[i].index) + 1] = large_bedroom.regions[i].y
#
# def optimize_regions(positions, room):
#     output = 0
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'sleeping', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sleeping', 'door')
#     output += reg_close_to_fixed_object(positions, room, 'dressing', 'window')
#     output += reg_close_to_reg(positions, room, 'dressing', 'storage/closet')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'window')
#     output += reg_close_to_fixed_object(positions, room, 'sitting/reading', 'socket')
#     output += reg_away_from_reg(positions, room, 'sitting/reading', 'sleeping')
#     output += reg_close_to_wall(positions, room, 'storage/closet')
#     output += reg_close_to_reg(positions, room, 'storage/closet', 'dressing')
#     output += reg_close_to_fixed_object(positions, room, 'work/study', 'socket')
#     output += reg_away_from_fixed_object(positions, room, 'work/study', 'window')
#     output += reg_away_from_reg(positions, room, 'work/study', 'sleeping')
#     output += reg_include_focal_point(positions, room, 'sitting/reading')
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 0)
#     output += reg_include_focal_point(positions, room, 'sitting/reading', window_index = 1)
#     return output
#
# bounds = Bounds([0] * 2 * len(large_bedroom.regions), [large_bedroom.width, large_bedroom.length] * len(large_bedroom.regions))
# res = minimize(optimize_regions, positions, args = (large_bedroom), method = 'Nelder-Mead', bounds=bounds)
# for i in range(len(large_bedroom.regions)):
#     large_bedroom.regions[i].x, large_bedroom.regions[i].y = res.x[2*(large_bedroom.regions[i].index):2*(large_bedroom.regions[i].index) + 2]
# create_moving_object(large_bedroom, 'bed', 2, 2, 'sleeping', 0)
# create_moving_object(large_bedroom, 'wardrobe', 1.5, 0.6, 'dressing', 1)
# create_moving_object(large_bedroom, 'sofa', 1.8, 0.8, 'sitting/reading', 2)
# create_moving_object(large_bedroom, 'closet', 2, 1, 'storage/closet', 3)
# create_moving_object(large_bedroom, 'desk', 1.5, 0.6, 'work/study', 4)
# positions = np.zeros(3*len(large_bedroom.moving_objects))
# for i in range(len(large_bedroom.moving_objects)):
#     positions[3*i] = large_bedroom.moving_objects[i].position[0]
#     positions[3*i + 1] = large_bedroom.moving_objects[i].position[1]
#     positions[3*i + 2] = large_bedroom.moving_objects[i].position[2]
#
# def optimize_primary_objects(positions, room):
#     output = 0
#     output += ind_next_to_wall(positions, room, 0, 'back')  # bed
#     output += ind_accessible(positions, room, 0, ['left', 'right', 'front'])  # bed
#     output += ind_in_region(positions, room, 0, 'sleeping')  # bed
#     output += ind_next_to_wall(positions, room, 1, 'back')  # wardrobe
#     output += ind_accessible(positions, room, 1, ['front'])  # wardrobe
#     output += ind_in_region(positions, room, 1, 'dressing')  # wardrobe
#     output += ind_next_to_wall(positions, room, 2, 'back')  # sofa
#     output += ind_accessible(positions, room, 2, ['front'])  # sofa
#     output += ind_in_region(positions, room, 2, 'sitting/reading')  # sofa
#     output += ind_next_to_wall(positions, room, 3, 'back')  # closet
#     output += ind_accessible(positions, room, 3, ['front'])  # closet
#     output += ind_in_region(positions, room, 3, 'storage/closet')  # closet
#     output += ind_close_to_fixed_object(positions, room, 4, 'socket')  # desk
#     output += ind_next_to_wall(positions, room, 4, 'back')  # desk
#     output += ind_accessible(positions, room, 4, ['front'])  # desk
#     output += ind_in_region(positions, room, 4, 'work/study')  # desk
#     return output
#
# bounds = Bounds([0] * 3 * len(large_bedroom.moving_objects), [large_bedroom.width, large_bedroom.length, 2*np.pi] * len(large_bedroom.moving_objects))
# nonlinear_constraint1 = NonlinearConstraint(partial(ind_no_overlap, room = large_bedroom), 0, 1e-3)
# nonlinear_constraint2 = NonlinearConstraint(partial(ind_in_bounds, room = large_bedroom), 0, 1e-3)
# cons = [nonlinear_constraint1, nonlinear_constraint2]
# options = {'maxiter': 5000}
# res = minimize(optimize_primary_objects, positions, args = (large_bedroom), method = 'SLSQP', bounds=bounds, constraints = cons, options = options)
# print(res.message)
# for i in range(len(large_bedroom.moving_objects)):
#     large_bedroom.moving_objects[i].position = res.x[3*i:3*i + 3]
# large_bedroom.draw(draw_regions= True)
# print(res.message)

# %%
def p_perpendicular_aligned(positions, room, object1_index, object2_index, center_object_index = None):
    """ The function p_perpendicular_aligned ensures that two objects are aligned in a room perpendicularly. 
        If center is given, the objects will be aligned about that point. For example, 
        a sofa and chair might be aligned perpendicularly about a coffee table or a side table. Or a chair at the head of the table 
        might be aligned perpendicularly with the chairs closest to it on the sides of the table. 

        
        Args:

        positions: list of floats, x, y, theta values for all objects in the room
        room: rectangular Room object
        object1_index: int, index of object1 in the room
        object2_index: int, index of object2 in the room
        center_object_index: int, index of object in room.moving_objects to be used as the pivot for the alignment (e.g. a coffee table or a table)
    """

    val = 0.0
    obj1, obj2 = room.moving_objects[object1_index], room.moving_objects[object2_index]
    x1, y1, theta1 = positions[3*object1_index:3*object1_index + 3]
    x2, y2, theta2 = positions[3*object2_index:3*object2_index + 3]

    cs1 = np.array(corners(x1, y1, theta1, obj1.width, obj1.length))# TL, TR, BR, BL
    cs2 = np.array(corners(x2, y2, theta2, obj2.width, obj2.length))

    mid_front1 = (cs1[2, :] + cs1[3, :])/2
    mid_front2 = (cs2[2, :] + cs2[3, :])/2

    dir1 = (cs1[3, :] - cs1[0, :])/np.linalg.norm(cs1[3, :] - cs1[0, :])
    dir2 = (cs2[3, :] - cs2[0, :])/np.linalg.norm(cs2[3, :] - cs2[0, :])

    ### Find t1, and t2 (intersection line lengths - want there to be a right angled triangle between each object)
    BA = mid_front2 - mid_front1
    t1 = np.dot(np.array([dir2[1], -dir2[0]]), BA) / np.dot(np.array([dir2[1], -dir2[0]]), dir1)
    t2 = np.dot(np.array([dir1[1], -dir1[0]]), BA) / np.dot(np.array([dir2[1], -dir2[0]]), dir1)
    
    if not center_object_index:
        val += (np.linalg.norm(BA) - np.sqrt((t1**2 + t2**2)))**2 
        val += min(0.0, t1)**2 + min(0.0, t2)**2 # t1 and t2 should be bigger than 0 
        val += min(0.0, np.sqrt((0.8*obj1.width)**2 + (0.8*obj2.width)**2) - np.sqrt(t1**2+ t2**2))**2 # t1 and t2 should not be too big

    else: 
        center_obj = room.moving_objects[center_object_index]
        x3, y3, theta3 = positions[3*center_object_index:3*center_object_index + 3]
        val += (np.linalg.norm(BA) - np.sqrt((t1**2 + t2**2)))**2 ## mid_front1, mid_front2, and intersection point should make a right angled triangle 
        val += min(0.0, t1 * t2)**2 # t1 and t2 should either both be positive or both be negative 
        C = np.array([x1, y1]) + t1 * dir1
        val += (C[0] - x3)**2 + (C[1] - y3)**2 # C should be the center of the center object

        print(C, (C[0] - x3)**2 + (C[1] - y3)**2, min(0.0, t1 * t2)**2, (np.linalg.norm(BA) - np.sqrt((t1**2 + t2**2)))**2)
        val += min(0.0, np.sqrt((center_obj.width)**2 + (center_obj.width)**2) - np.sqrt(t1**2+ t2**2))**2 # t1 and t2 should not be too big
    return val

# %%
def p_facing(positions, room, object1_index, object2_index, both = False):
    """ The function facing ensures that object1 is facing object2 in a room.
        If both is True, then object2 will also be facing object1.
        
        Args:
        positions: list of floats, x, y, theta values for all objects in the room
        room: rectangular Room object
        object1_index: int, index of object1 in the room
        object2_index: int, index of object2 in the room
    """
    val = 0.0

    object1, object2 = room.moving_objects[object1_index], room.moving_objects[object2_index]
    x1, y1, theta1 = positions[3*object1_index:3*object1_index + 3]
    x2, y2, theta2 = positions[3*object2_index:3*object2_index + 3]

    cs1 = np.array(corners(x1, y1, theta1, object1.width, object1.length))# TL, TR, BR, BL
    tl1, tr1, br1, bl1 = cs1
    dir1 = np.array([bl1[0] - tl1[0], bl1[1] - tl1[1]])
    dir1 /= np.linalg.norm(dir1)

    distances = np.linalg.norm(cs1 - np.array([x2, y2]), axis = 1) 
    ## want front right to be closer than back right, and front left to be closer than back left 
    val += min(0.0, distances[0] - distances[3])**2 + min(0.0, distances[1] - distances[2])**2
    ## Line 1 goes from front left corner onward, line 2 goes from front right corner 
    ## distance of object2 from line1
    dist1 = abs((bl1[1] - tl1[1])*x2 - (bl1[0] - tl1[0])*y2 + bl1[0]*tl1[1] - bl1[1]*tl1[0])/np.sqrt((bl1[0] - tl1[0])**2 + (bl1[1] - tl1[1])**2)
    ## distance of object2 from line2
    dist2 = abs((br1[1] - tr1[1])*x2 - (br1[0] - tr1[0])*y2 + br1[0]*tr1[1] - br1[1]*tr1[0])/np.sqrt((br1[0] - tr1[0])**2 + (br1[1] - tr1[1])**2)
    ## distance between the two lines is width, therefore want dist1 + dist2 = width 
    val += (dist1 + dist2 - object1.width)**2
    if both: 
        val += p_facing(positions, room, object2_index, object1_index)
        cs2 = np.array(corners(x2, y2, theta2, object2.width, object2.length))# TL, TR, BR, BL
        dir2 = np.array([cs2[3][0] - cs2[0][0], cs2[3][1] - cs2[0][1]])
        dir2 /= np.linalg.norm(dir2)

        val += (np.dot(dir1, dir2) + 1)**2
    return val 


def p_surround(positions, room, central_object_index, object_indices):
    """ The function p_surroudn ensures that central_object is surrounded by all the objects in object_indices.
        This would be used for chairs around a dining table.

        Args:
        positions: list of floats, x, y, theta values for all objects in the room
        room: rectangular Room object
        central_object_index: int, Object object
        object_indices: list of ints, indices of Object objects
    """

    val = 0

    center_x, center_y = positions[3*central_object_index:3*central_object_index + 2]

    pos = np.array(positions).reshape(-1, 3)
    pos = pos[object_indices, :]

    center_of_mass = np.mean(pos[:, :2], axis = 0)
    val += 2 * ((center_of_mass[0] - center_x)**2 + (center_of_mass[1] - center_y)**2)# center of mass of all the objects
    for i in range(len(object_indices)):
        val += p_facing(positions, room, object_indices[i], central_object_index)
        #val += p_next_to(positions, room, object_indices[i], central_object_index)#, side1 = 'front')
    
    ## also want them all to be roughly the same distance from the object
    distances = np.linalg.norm(pos[:, :2] - center_of_mass, axis = 1)
    average_distance = np.mean(distances)
    val += np.sum((distances - average_distance)**2)

    return val
