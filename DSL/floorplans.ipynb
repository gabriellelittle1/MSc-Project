# %%
from Class_Structures import * 
from Setup_Functions import *

# %%
## 01 4 x 5 Bedroom 
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

room.moving_objects = [Object('bed', 1.5, 2.0, index = 0, position = np.array([2.99908829, 2.25479268, 1.5695796]))]
room.moving_objects.append(Object('wardrobe', 1.2, 0.6, index = 1, position = np.array([3.42901209, 4.21707574, 2.12461495])))
room.moving_objects.append(Object('desk', 1.2, 0.6, index = 2, position = np.array([0.30000861, 2.81002244, 4.71240767])))
room.moving_objects.append(Object('nightstand', 0.5, 0.4, index = 3, position = np.array([3.79991191, 1.25175276, 7.85434872])))
room.moving_objects.append(Object('nightstand', 0.5, 0.4,index = 4, position = np.array([3.80008485, 3.25413099, 1.57114411])))
room.moving_objects.append(Object('dresser', 1.0, 0.5, index = 5,position = np.array([1.30172319, 4.75, 3.14159263])))
room.moving_objects.append(Object('desk chair', 0.6, 0.6, index = 6,position = np.array([0.91412479, 2.95398787, 1.74974214])))

room.tertiary_objects = [Object('lamp', 0.3, 0.3, index = 0,position = np.array([3.80412864, 1.23225814, 7.85095846]))]
room.tertiary_objects.append(Object('lamp', 0.3, 0.3, index = 1,position = np.array([3.78080645, 3.28990829, 1.55808384])))
room.tertiary_objects.append(Object('painting', 1.0, 0.1,index = 2, position = np.array([3.95018539, 4.03000554, 1.57090923])))
room.tertiary_objects.append(Object('mirror', 1.2, 0.1, index = 3,position = np.array([0.0517405, 4.41183166, 4.71020655])))
room.tertiary_objects.append(Object('organizer', 0.4, 0.2, index = 4,position = np.array([0.12629494, 2.96523696, 4.59031376])))
room.tertiary_objects.append(Object('monitor', 0.5, 0.2, index = 5,position = np.array([0.3809275, 2.66377354, 4.76536102])))
room.tertiary_objects.append(Object('chandelier', 0.8, 0.8, index = 6,position = np.array([1.95436299, 2.49507894, 4.70553326])))
room.tertiary_objects.append(Object('rug', 2.0, 3.0, index = 7,position = np.array([2.11805036, 2.10440163, 97.37731695])))
                             
room.draw(level = 1, arrows = True)

# %%
## fantasy writer 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.25)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.75)
create_fixed_object(room, 'door', 0.9, 0.1, 'east', position = 0.5)
create_fixed_object(room, 'socket', 0.05, 0.05, 'west', position = 0.2)
create_fixed_object(room, 'socket', 0.05, 0.05, 'south', position = 0.7)
create_fixed_object(room, 'socket', 0.05, 0.05, 'east', position = 0.2)

room.moving_objects = [Object('desk', 2, 1, index = 0, position = np.array([2.49377523, 0.52754578, 6.25528297]))]
room.moving_objects.append(Object('armchair', 1.0, 0.8, index = 1, position = np.array([1.80797788, 4.57850556, 3.18450962])))
room.moving_objects.append(Object('bookshelf', 2, 0.3, index = 2, position = np.array([0.13669401, 3.88046608, 4.69426186])))
room.moving_objects.append(Object('desk chair', 0.6, 0.6, index = 3, position = np.array([2.6102624, 1.37329247, 3.1731128])))
room.moving_objects.append(Object('small filing cabinet', 0.4, 0.5, index = 4, position = np.array([3.68619674, 0.238762, 6.25532212])))
room.moving_objects.append(Object('side table', 0.5, 0.5, index = 5, position = np.array([3.65247773, 4.46015406, 2.95532382])))
room.moving_objects.append(Object('additional bookcase', 1, 0.3, index = 6, position = np.array([0.15000001, 2.37795721, 4.712389])))

room.tertiary_objects = [Object('laptop', 0.4, 0.3, index = 0, position = np.array([2.48172721, 0.52915251, 6.27386633]))]
room.tertiary_objects.append(Object('desk_lamp', 0.2, 0.2, index = 1, position = np.array([1.99077105, 0.29368739, 3.1438683])))
room.tertiary_objects.append(Object('corkboard', 1.0, 0.1, index = 2, position = np.array([3.94909992, 0.49007021, 1.56664429])))
room.tertiary_objects.append(Object('quote', 0.5, 0.1, index = 3, position = np.array([3.84847143, 0.33896023, 1.56664515])))
room.tertiary_objects.append(Object('table_lamp', 0.2, 0.2, index = 4, position = np.array([3.62984617, 4.57118948, 3.13255407])))
room.tertiary_objects.append(Object('plant', 0.2, 0.2, index = 5, position = np.array([3.65479072, 4.36665443, 3.1316734])))
room.tertiary_objects.append(Object('artwork', 1.0, 0.1, index = 6, position = np.array([3.94417861, 4.50977826, 1.57505653])))
room.tertiary_objects.append(Object('bookends', 0.2, 0.2, index = 7, position = np.array([0.10131225, 3.88551063, 4.70799929])))
room.tertiary_objects.append(Object('globe', 0.3, 0.3, index = 8, position = np.array([0.1551974, 2.39056181, 4.71084047])))
room.tertiary_objects.append(Object('rug', 2.0, 3.0, index = 9, position = np.array([1.90050023, 1.49935473, 163.36424821])))
room.tertiary_objects.append(Object('chandelier', 1.0, 1.0, index = 10, position = np.array([2.00898848, 2.50559756, 9.42407544])))

room.draw(level = 1, arrows = True)

# %%
## 03 A small home gym 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'east', position = 0.1)
create_fixed_object(room, 'window', 1, 0.1, 'east', position = 0.9)
create_fixed_object(room, 'door', 0.8, 0.1, 'west', position = 0.1)
create_fixed_object(room, 'socket', 0.05, 0.05, 'south', position = 0.2)
create_fixed_object(room, 'socket', 0.05, 0.05, 'north', position = 0.9)
create_fixed_object(room, 'socket', 0.05, 0.05, 'west', position = 0.7)

room.moving_objects = [Object("Sofa", 2, 1, "sitting", 0, (3.5, 2.5, np.pi/2))]
room.moving_objects += [Object("Coffee Table", 1, 0.6, "sitting", 0, (2, 2.5, np.pi/2))]
room.moving_objects += [Object("TV Stand", 2, 0.6, "sitting", 0, (0.3, 2.5, 3*np.pi/2))]
room.moving_objects += [Object("Armchair", 1, 1, "sitting", 0, (2.5, 4.2, (6/7)*np.pi))]

room.tertiary_objects = [Object("TV", 1.4, 0.1, "sitting", 0, (0.05, 2.5, 3*np.pi/2))]
room.tertiary_objects += [Object("painting", 1.4, 0.1, "sitting", 0, (3.95, 2.5, np.pi/2))]


room.draw(arrows = True, level = 2)

# %%
## 04 A sewing room 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.2)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.8)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.5)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.7)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.5)

room.draw()

# %%
## 05 A bedroom for a vampire 
room = create_room(4, 5)
create_fixed_object(room, 'door', 1, 0.1, 'west', 0.5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.8)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', 0.3)
create_fixed_object(room, 'socket', 0.1, 0.1, 'south', 0.5)

room.moving_objects = [Object('coffin', 1, 2, index = 0, position = np.array([2.64056028, 1.03243119, -0.06663686]))]
room.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([1.44863605, 4.69560708, 3.14739794]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([3.60144767, 3.72089473, 1.56861517]))]
room.moving_objects += [Object('nightstand', 0.5, 0.4, index = 3, position = np.array([3.34944697, 0.20000034, 6.28318397]))]
room.moving_objects += [Object('dresser', 1.2, 0.5, index = 4, position = np.array([2.7983399, 4.75349544, 3.14741092]))]
room.moving_objects += [Object('bookshelf', 1, 0.3, index = 5, position = np.array([3.84998809, 2.32001459, 7.85400451]))]
room.moving_objects += [Object('small side table', 0.5, 0.5, index = 6, position = np.array([3.75001106, 3.07001385, 7.85402901]))]

room.tertiary_objects = [Object('table lamp', 0.3, 0.3, index = 0, position = np.array([3.34944765, 0.19999994, 6.28318532]))]
room.tertiary_objects += [Object('painting', 1, 0.1, index = 1, position = np.array([3.94629972, 0.4901993, 1.56656632]))]
room.tertiary_objects += [Object('mirror', 1.2, 0.1, index = 2, position = np.array([0.05387012, 4.41179108, 4.71016141]))]
room.tertiary_objects += [Object('trinket', 0.4, 0.2, index = 3, position = np.array([1.8227596, 4.8477783, 6.28318482]))]
room.tertiary_objects += [Object('reading lamp', 0.3, 0.3, index = 4, position = np.array([3.7500111, 3.07001344, 7.853991]))]
room.tertiary_objects += [Object('painting', 0.8, 0.1, index = 5, position = np.array([3.95011142, 3.7200227, 1.57079632]))]
room.tertiary_objects += [Object('clock', 0.3, 0.3, index = 6, position = np.array([3.84994259, 2.32001433, 7.8539855]))]
room.tertiary_objects += [Object('chandelier', 1.2, 1.2, index = 7, position = np.array([2.00000045, 2.50000023, 3.14159262]))]
room.tertiary_objects += [Object('rug', 2, 3, index = 8, position = np.array([2.64055951, 1.49953289, 56.54866776]))]

room.draw(level = 1, arrows = True)

# %%
## 06 boho dining 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.4)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.7)
create_fixed_object(room, 'door', 0.8, 0.1, 'east', position = 0.1)
create_fixed_object(room, 'socket', 0.2, 0.1, 'south', position = 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', position = 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', position = 0.6)

room.moving_objects = [Object('dining table', 1.5, 2, index = 0, position = np.array([2.51042458, 2.79741786, 1.5705776]))]
room.moving_objects += [Object('large indoor plant', 0.5, 0.5, index = 1, position = np.array([0.24587333, 4.35695157, 3.22656595]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([0.39613517, 0.39557378, -0.00175959]))]
room.moving_objects += [Object('dining chair', 0.5, 0.5, index = 3, position = np.array([1.24871249, 2.85140877, 10.82262946]))]
room.moving_objects += [Object('dining chair', 0.5, 0.5, index = 4, position = np.array([2.81082143, 3.90405269, 3.11708849]))]
room.moving_objects += [Object('dining chair', 0.5, 0.5, index = 5, position = np.array([2.92346272, 1.77237575, 6.36016765]))]
room.moving_objects += [Object('dining chair', 0.5, 0.5, index = 6, position = np.array([2.09813872, 1.78053305, -0.06530327]))]
room.moving_objects += [Object('plant stand', 0.4, 0.4, index = 7, position = np.array([0.78465421, 4.8248074, 4.67919163]))]
room.moving_objects += [Object('small bookshelf', 0.8, 0.3, index = 8, position = np.array([1.19594595, 0.15059729, -1.45925281e-04]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 9, position = np.array([0.55073905, 1.32857237, 2.90803306]))]

room.tertiary_objects = [Object('chandelier', 1, 1, index = 0, position = np.array([2.51042753, 2.79741783, 37.69911181]))]
room.tertiary_objects += [Object('table runner', 0.3, 2, index = 1, position = np.array([2.51042541, 2.79742004, 1.57075282]))]
room.tertiary_objects += [Object('wall art', 0.8, 0.1, index = 2, position = np.array([3.94797448, 2.79830116, 1.57079722]))]
room.tertiary_objects += [Object('hanging planters', 0.3, 0.3, index = 3, position = np.array([0.24587546, 4.35695156, 9.42477787]))]
room.tertiary_objects += [Object('plant pot', 0.3, 0.3, index = 4, position = np.array([3.81529686, 4.03787266, 9.42477797]))]
room.tertiary_objects += [Object('reading lamp', 0.2, 0.2, index = 5, position = np.array([0.55073886, 1.32857235, 3.09466059]))]
room.tertiary_objects += [Object('book', 0.2, 0.3, index = 6, position = np.array([1.19594819, 0.15054735, -2.91493389e-5]))]
room.tertiary_objects += [Object('wall sconce', 0.2, 0.1, index = 7, position = np.array([ 3.95431482e-01,  4.99827922e-02, -7.31534263e-09]))]
room.tertiary_objects += [Object('area rug', 2, 3, index = 8, position = np.array([2.50001042, 2.79741902, 7.85398162]))]

room.draw(level = 1, arrows = True)

# %%
## 07 A small home gym 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.2)
create_fixed_object(room, 'window', 1.5, 0.1, 'east', position = 0.5)
create_fixed_object(room, 'door', 1, 0.1, 'south', position = 0.1)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.25)
create_fixed_object(room, 'socket', 0.1, 0.1, 'south', position = 0.8)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', position = 0.3)

room.moving_objects = [Object('treadmill', 0.8, 1.6, index = 0, position = np.array([0.85919535, 1.89873744, 4.89419385]))]
room.moving_objects += [Object('adjustable dumbbell set', 0.5, 0.3, index = 1, position = np.array([3.86560726, 4.76316772, 1.56898601]))]
room.moving_objects += [Object('yoga ball', 0.5, 0.5, index = 2, position = np.array([2.07649724, 2.81570967, 4.64717497]))]
room.moving_objects += [Object('stationary bike', 0.5, 1, index = 3, position = np.array([3.22750631, 0.23288754, 1.57100398]))]
room.moving_objects += [Object('resistance bands set', 0.6, 0.6, index = 4, position = np.array([1.86387369, 4.69721885, -3.14796367]))]
room.moving_objects += [Object('kettlebell set', 0.6, 0.3, index = 5, position = np.array([3.84972604, 3.71668495, 1.57077282]))]
room.moving_objects += [Object('yoga mat', 0.6, 1.8, index = 6, position = np.array([0.93343135, 4.05000015, 3.13403096]))]
room.moving_objects += [Object('foam roller', 0.15, 0.5, index = 7, position = np.array([1.30844153, 4.04591741, 6.27574151]))]

room.tertiary_objects = [Object('tv', 0.8, 0.1, index = 0, position = np.array([0.04999996, 1.79951857, 4.71239799]))]
room.tertiary_objects += [Object('poster', 0.6, 0.1, index = 1, position = np.array([3.70016, 4.94926013, 3.1415897]))]
room.tertiary_objects += [Object('mirror', 1, 0.1, index = 2, position = np.array([0.05267035, 4.05060104, 4.71237929]))]
room.tertiary_objects += [Object('speaker', 0.1, 0.1, index = 3, position = np.array([0.61457627, 4.54241564, 4.71238794]))]
room.tertiary_objects += [Object('clock', 0.3, 0.1, index = 4, position = np.array([3.22755969, 0.05061338, 2.82690924e-06]))]
room.tertiary_objects += [Object('light', 1, 0.1, index = 5, position = np.array([2.00000749, 2.50007253, 10.99557771]))]
room.tertiary_objects += [Object('hooks', 1, 0.1, index = 6, position = np.array([0.04990127, 0.99032271, 4.71258645]))]

room.draw(level = 1, arrows = True)

# %%
## 08 A sewing room

room = create_room(4, 7)
create_fixed_object(room, 'window', 1.2, 0.1, 'north', position = 0.4)
create_fixed_object(room, 'window', 1.4, 0.1, 'east', position = 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'south', position = 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', position = 0.3)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', position = 0.7)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', position = 0.8)

room.moving_objects = [Object('cutting table', 1.5, 1, index = 0, position = np.array([2.99075341, 3.31773745, 1.54964673]))]
room.moving_objects += [Object('sewing machine table', 1.2, 0.6, index = 1, position = np.array([0.30119544, 2.25568633, -1.57109678]))]
room.moving_objects += [Object('shelving unit', 2, 0.5, index = 2, position = np.array([0.25006724, 4.79370572, 4.71232162]))]
room.moving_objects += [Object('rolling cart', 0.7, 0.4, index = 3, position = np.array([3.80000006, 6.25066944, 7.85398182]))]
room.moving_objects += [Object('desk chair', 0.5, 0.5, index = 4, position = np.array([1.85363142, 2.14523939, 3.08928058]))]
room.moving_objects += [Object('ironing board', 1.3, 0.4, index = 5, position = np.array([3.23404976, 0.64803524, 1.58058381]))]
room.moving_objects += [Object('additional shelving unit', 1, 0.5, index = 6, position = np.array([2.09370388, 6.54311003, 2.64850105]))]
room.moving_objects += [Object('storage cabinet', 1, 0.6, index = 7, position = np.array([0.29896231, 6.43108834, 4.71221232]))]

room.tertiary_objects = [Object('cutting_mat', 1.5, 1, index = 0, position = np.array([2.81080073, 3.32733139, 1.575291]))]
room.tertiary_objects += [Object('task_lamp', 0.2, 0.2, index = 1, position = np.array([3.40924656, 3.67817396, 1.57545812]))]
room.tertiary_objects += [Object('pin_cushion', 0.1, 0.1, index = 2, position = np.array([0.46221043, 2.25239478, -1.56997463]))]
room.tertiary_objects += [Object('thread_holder', 0.2, 0.1, index = 3, position = np.array([0.1495997, 2.55684215, 9.42482157]))]
room.tertiary_objects += [Object('organizer_bin', 0.3, 0.2, index = 4, position = np.array([0.31211299, 2.25755778, -1.57139832]))]
room.tertiary_objects += [Object('inspiration_board', 1.2, 0.1, index = 5, position = np.array([0.04999269, 2.25571858, 4.71238274]))]
room.tertiary_objects += [Object('baskets', 0.4, 0.3, index = 6, position = np.array([0.23902903, 4.57008292, 4.71318406]))]
room.tertiary_objects += [Object('fabric_boxes', 0.5, 0.4, index = 7, position = np.array([0.26194875, 5.02419118, 4.70764713]))]
room.tertiary_objects += [Object('wall_hooks', 0.5, 0.1, index = 8, position = np.array([0.04959886, 6.42964432, 4.71481522]))]
room.tertiary_objects += [Object('pendant_light', 0.5, 0.5, index = 9, position = np.array([2.00033212, 3.50016263, 14.13712296]))]
room.tertiary_objects += [Object('clock', 0.3, 0.1, index = 10, position = np.array([0.05000398, 3.85740197, 4.71238728]))]

room.draw(level = 1, arrows = True)

# %%
## 55_1

room = create_room(5, 5)
create_fixed_object(room, 'window', 1.2, 0.1, 'north', 0.2)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.7)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'south', 0.1)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.9)

room.moving_objects = [Object('bed', 1.6, 2, index = 0, position = np.array([3.9999877, 2.32318509, 7.85397096]))]
room.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([0.30007141, 1.10201888, 4.71234282]))]
room.moving_objects += [Object('desk', 1.2, 0.6, index = 2, position = np.array([0.91992235, 4.69988938, 3.14160925]))]
room.moving_objects += [Object('nightstand', 0.5, 0.4, index = 3, position = np.array([4.79999947, 3.37318435, 1.57072396]))]
room.moving_objects += [Object('dresser', 1, 0.5, index = 4, position = np.array([3.42236931, 4.75007748, 3.14165091]))]
room.moving_objects += [Object('floor lamp', 0.4, 0.4, index = 5, position = np.array([4.69165902, 0.30632343, 7.06204969]))]
room.moving_objects += [Object('shoe rack', 0.8, 0.3, index = 6, position = np.array([1.20671848, 0.15070311, 0.00032743]))]
room.moving_objects += [Object('storage bench', 1.2, 0.4, index = 7, position = np.array([2.20677292, 0.19993694, 6.28315955]))]
room.moving_objects += [Object('desk chair', 0.5, 0.5, index = 8, position = np.array([1.83210677, 3.29776518, 6.6579669]))]
room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 9, position = np.array([2.40673586, 4.84989404, 3.14214222]))]

room.tertiary_objects = [Object('painting', 1.2, 0.1, index = 0, position = np.array([4.95007612, 2.32317453, 1.57079632]))]
room.tertiary_objects += [Object('lamp', 0.3, 0.3, index = 1, position = np.array([3.80412864, 1.23225814, 7.85095846]))]
room.tertiary_objects += [Object('jewelry_box', 0.3, 0.2, index = 2, position = np.array([3.42236947, 4.75007709, 3.14160447]))]
room.tertiary_objects += [Object('computer', 0.4, 0.25, index = 3, position = np.array([0.91992457, 4.69989135, 3.14159592]))]
room.tertiary_objects += [Object('clock', 0.5, 0.1, index = 4, position = np.array([0.45999986, 4.9500899, 3.14159265]))]
room.tertiary_objects += [Object('rug', 2, 1.5, index = 5, position = np.array([2.99998792, 2.32319615, 1.57079417]))]
room.tertiary_objects += [Object('chandelier', 0.8, 0.8, index = 6, position = np.array([2.50000028, 2.5, 9.42477832]))]

room.draw(level = 1, arrows = True, key = True)

# %%
## 10 
room = create_room(5, 5)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.3)
create_fixed_object(room, 'window', 1.5, 0.1, 'south', position = 0.7)
create_fixed_object(room, 'door', 1, 0.1, 'east', position = 0.1)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.2)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.8)
create_fixed_object(room, 'socket', 0.1, 0.1, 'north', position = 0.9)
create_fixed_object(room, 'socket', 0.1, 0.1, 'south', position = 0.4)

room.moving_objects = [Object('bed', 1.6, 2, index = 0, position = np.array([0.99951853, 2.00140775, 4.71241964]))]
room.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([4.70010967, 2.71404377, 1.57077462]))]
room.moving_objects += [Object('dressing table', 1.2, 0.5, index = 2, position = np.array([3.80543227, 4.75044203, 3.14104234]))]
room.moving_objects += [Object('nightstand', 0.5, 0.4, index = 3, position = np.array([0.19787029, 0.934155, 4.65732474]))]
room.moving_objects += [Object('nightstand', 0.5, 0.4, index = 4, position = np.array([0.19425696, 3.05987935, -1.49141215]))]
room.moving_objects += [Object('floor lamp', 0.3, 0.3, index = 5, position = np.array([0.51085736, 0.3559098, -0.06074634]))]
room.moving_objects += [Object('storage bench', 1.2, 0.4, index = 6, position = np.array([3.19683548, 2.67299232, 1.57676766]))]
room.moving_objects += [Object('dressing stool', 0.4, 0.4, index = 7, position = np.array([3.82522355, 4.29523936, 0.09980002]))]
room.moving_objects += [Object('full-length mirror', 0.5, 0.3, index = 8, position = np.array([2.95540438, 4.85, 3.14159281]))]

room.tertiary_objects = [Object('painting', 1, 0.1, index = 0, position = np.array([0.04998007, 2.00137749, 4.71238898]))]
room.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 1, position = np.array([3.62984617, 4.57118948, 3.13255407]))]
room.tertiary_objects += [Object('vase', 0.2, 0.2, index = 2, position = np.array([3.65479072, 4.36665443, 3.1316734]))]
room.tertiary_objects += [Object('wall_clock', 0.5, 0.1, index = 3, position = np.array([3.94417861, 4.50977826, 1.57505653]))]
room.tertiary_objects += [Object('photo_frame', 0.3, 0.1, index = 4, position = np.array([0.10131225, 3.88551063, 4.70799929]))]
room.tertiary_objects += [Object('tray', 0.4, 0.3, index = 5, position = np.array([0.1551974, 2.39056181, 4.71084047]))]
room.tertiary_objects += [Object('cushions', 0.5, 0.5, index = 6, position = np.array([1.90050023, 1.49935473, 163.36424821]))]
room.tertiary_objects += [Object('reading lamp', 0.2, 0.2, index = 7, position = np.array([3.19683548, 2.67298134, 1.57198953]))]
room.tertiary_objects += [Object('mirror', 1, 0.1, index = 8, position = np.array([4.94588722, 4.39492818, 1.5707461]))]

room.draw(level = 0, arrows = True, key = True)

# %%
## 10 
room = create_room(5, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', position = 0.2)
create_fixed_object(room, 'window', 1, 0.1, 'north', position = 0.8)
create_fixed_object(room, 'door', 0.9, 0.1, 'east', position = 0.6)
create_fixed_object(room, 'socket', 0.1, 0.1, 'south', position = 0.1)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.3)
create_fixed_object(room, 'socket', 0.1, 0.1, 'north', position = 0.9)

room.moving_objects= [Object('bed', 1.6, 2, index = 0, position = np.array([1.96033009, 1.00100521, 6.28142752]))]
room.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([3.06471792, 4.70028026, 3.14198651]))]
room.moving_objects += [Object('chair', 0.6, 0.6, index = 2, position = np.array([4.71272753, 4.56288207, 7.85622451]))]
room.moving_objects += [Object('nightstand 1', 0.5, 0.4, index = 3, position = np.array([0.31143409, 0.20390269, 6.26674797]))]
room.moving_objects += [Object('nightstand 2', 0.5, 0.4, index = 4, position = np.array([3.45724684, 0.19660541, 0.00176172]))]
room.moving_objects += [Object('dresser', 1.2, 0.5, index = 5, position = np.array([1.71456859, 4.75000031, 3.1415936]))]
room.moving_objects += [Object('shoe rack', 0.8, 0.3, index = 6, position = np.array([0.15000021, 3.21199904, 4.71238962]))]
room.moving_objects += [Object('desk', 1.2, 0.6, index = 7, position = np.array([4.29251855, 4.06704115, 8.70732913]))]
room.moving_objects += [Object('desk chair', 0.6, 0.6, index = 8, position = np.array([3.79002235, 3.42589937, -0.53663362]))]

room.tertiary_objects = [Object('lamp', 0.3, 0.3, index = 0, position = np.array([0.31143447, 0.20390213, 6.27989712]))]
room.tertiary_objects += [Object('clock', 0.15, 0.1, index = 1, position = np.array([3.4572461, 0.19660386, 0.00035218]))]
room.tertiary_objects += [Object('painting', 1, 0.1, index = 2, position = np.array([4.94404285, 0.49020854, 1.56765279]))]
room.tertiary_objects += [Object('rug', 2.5, 2.5, index = 3, position = np.array([1.962088, 2.00100262, 6.28283331]))]
room.tertiary_objects += [Object('mirror', 1.5, 0.1, index = 4, position = np.array([2.49843226, 4.95007591, 3.14159264]))]
room.tertiary_objects += [Object('desk lamp', 0.2, 0.2, index = 5, position = np.array([4.2925177, 4.06703964, 9.27412467]))]
room.tertiary_objects += [Object('photo', 0.3, 0.1, index = 6, position = np.array([1.71456727, 4.75000088, 3.14159264]))]
room.tertiary_objects += [Object('plant', 0.2, 0.2, index = 7, position = np.array([0.14999969, 3.21199951, 4.71238907]))]
room.tertiary_objects += [Object('bowl', 0.3, 0.3, index = 8, position = np.array([4.165091, 2.10999458, 7.85401723]))]
room.tertiary_objects += [Object('wall_clock', 0.5, 0.1, index = 9, position = np.array([4.9500903, 4.29308679, 1.57079632]))]

room.draw(level = 1, arrows = True, key = True)

# %%
## 10 
bedroom = create_room(5, 5)
create_fixed_object(bedroom, 'window', 1.5, 0.1, 'north', position = 0.25)
create_fixed_object(bedroom, 'window', 1.5, 0.1, 'north', position = 0.75)
create_fixed_object(bedroom, 'door', 0.9, 0.1, 'east', position = 0.2)
create_fixed_object(bedroom, 'socket', 0.1, 0.1, 'west', position = 0.2)
create_fixed_object(bedroom, 'socket', 0.1, 0.1, 'west', position = 0.8)
create_fixed_object(bedroom, 'socket', 0.1, 0.1, 'south', position = 0.4)
create_fixed_object(bedroom, 'socket', 0.1, 0.1, 'north', position = 0.5)

bedroom.moving_objects = [Object('bed', 1.6, 2, index = 0, position = np.array([1.00000021, 2.69549, 4.7123889]))]
bedroom.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([4.69999983, 3.62631126, 1.57079653]))]
bedroom.moving_objects += [Object('desk', 1.2, 0.6, index = 2, position = np.array([3.29939806, 0.300000126, 5.1959109e-07]))]
bedroom.moving_objects += [Object('nightstand', 0.5, 0.5, index = 3, position = np.array([0.2503417, 4.74902266, 4.77189427]))]
bedroom.moving_objects += [Object('nightstand', 0.5, 0.5, index = 4, position = np.array([0.25000147, 1.61831291, -1.56985768]))]
bedroom.moving_objects += [Object('dresser', 1.2, 0.5, index = 5, position = np.array([2.46237376, 4.75030155, 3.14176859]))]
bedroom.moving_objects += [Object('shoe rack', 0.8, 0.3, index = 6, position = np.array([4.02590396, 4.83178311, 9.38649468]))]
bedroom.moving_objects += [Object('storage ottoman', 1, 0.5, index = 7, position = np.array([2.84439369, 3.83572416, 0.14122721]))]
bedroom.moving_objects += [Object('desk chair', 0.5, 0.5, index = 8, position = np.array([3.29638169, 0.8500065, 9.42483315]))]
bedroom.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 9, position = np.array([0.3972737, 0.14699637, 6.27926233]))]

bedroom.tertiary_objects = [Object('painting', 1.2, 0.1, index = 0, position = np.array([0.04999996, 2.69549, 4.7123889]))]
bedroom.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 1, position = np.array([0.45106749, 4.72290358, 4.72020123]))]
bedroom.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 2, position = np.array([ 0.25613002,  1.62172075, -1.56688067]))]
bedroom.tertiary_objects += [Object('bedside tray', 0.3, 0.2, index = 3, position = np.array([ 0.14980765,  4.88743299, 28.27699483]))]
bedroom.tertiary_objects += [Object('wall mirror', 1, 0.1, index = 4, position = np.array([0.0525496,  4.50984162, 4.71072162]))]
bedroom.tertiary_objects += [Object('decorative bowl', 0.3, 0.3, index = 5, position = np.array([2.46039227, 4.75100757, 3.1460039 ]))]
bedroom.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 6, position = np.array([ 3.35369668,  0.14942242, 28.27001844]))]
bedroom.tertiary_objects += [Object('computer monitor', 0.5, 0.2, index = 7, position = np.array([ 3.01221693,  0.40157978, -0.00705673]))]
bedroom.tertiary_objects += [Object('wall clock', 0.4, 0.1, index = 8, position = np.array([4.94723882,2.07844613, 1.56817563]))]
bedroom.tertiary_objects += [Object('cork board', 1, 0.1, index = 9, position = np.array([0.05076643, 0.49024745, 4.71127651]))]


bedroom.draw(level = 1, arrows = True, key = True)

# %%
## 10 
room = create_room(5, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'north', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.7)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.8)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.3)
create_fixed_object(room, 'socket', 0.15, 0.1, 'south', 0.1)

room.moving_objects += [Object('bed', 1.6, 2, index = 0, position = np.array([3.00999728, 3.99983284, 9.42475024]))]
room.moving_objects += [Object('wardrobe', 1.5, 0.6, index = 1, position = np.array([3.32136132, 3.00037215e-01, 7.10278374e-04]))]
room.moving_objects += [Object('desk', 1.2, 0.6, index = 2, position = np.array([7.94823373e-01, 3.02350871e-01, 3.72806257e-04]))]
room.moving_objects += [Object('nightstand 1', 0.5, 0.5, index = 3, position = np.array([4.477003, 4.18435145, 6.52370856]))]
room.moving_objects += [Object('nightstand 2', 0.5, 0.5, index = 4, position = np.array([4.69538141, 3.48895149, 2.94592779]))]
room.moving_objects += [Object('dresser', 1, 0.5, index = 5, position = np.array([4.74999766, 1.09922305, 1.57077249]))]
room.moving_objects += [Object('desk chair', 0.6, 0.6, index = 6, position = np.array([0.80548895, 0.90883821, 3.10545732]))]
room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 7, position = np.array([1.79821815e+00, 1.49999977e-01, 1.07322291e-07]))]

room.tertiary_objects = [Object('painting', 1.2, 0.1, index = 0, position = np.array([3.01003155, 4.9500777, 3.14159267]))]
room.tertiary_objects += [Object('lamp1', 0.3, 0.3, index = 1, position = np.array([4.4769659, 4.18438327, 6.33151854]))]
room.tertiary_objects += [Object('lamp2', 0.3, 0.3, index = 2, position = np.array([4.69532433, 3.48899801, 3.1023606]))]
room.tertiary_objects += [Object('monitor', 0.5, 0.2, index = 3, position = np.array([1.12039289, 0.3052222, 0.00667554]))]
room.tertiary_objects += [Object('clock', 0.2, 0.1, index = 4, position = np.array([4.7500293, 1.09926767, 1.57081058]))]
room.tertiary_objects += [Object('plant', 0.3, 0.3, index = 5, position = np.array([0.72142991, 0.15154028, 28.2814017]))]
room.tertiary_objects += [Object('mirror', 0.8, 0.1, index = 6, position = np.array([4.95008713, 1.0992156, 1.57079639]))]
room.tertiary_objects += [Object('wallclock', 0.4, 0.1, index = 7, position = np.array([0.05015832, 0.19609567, 4.71138962]))]

room.draw(level = 1, arrows = True, key = True)

# %%
home_office = create_room(5, 3)
create_fixed_object(home_office, 'window', 1, 0.1, 'south', position = 0.5)
create_fixed_object(home_office, 'door', 0.9, 0.1, 'west', position = 0.3)
create_fixed_object(home_office, 'socket', 0.2, 0.1, 'north', position = 0.2)
create_fixed_object(home_office, 'socket', 0.2, 0.1, 'north', position = 0.8)
create_fixed_object(home_office, 'socket', 0.2, 0.1, 'east', position = 0.5)

home_office.moving_objects += [Object('desk', 1.5, 0.75, index = 0, position = np.array([2.80134566, 2.62482696, 3.14210979]))]
home_office.moving_objects += [Object('bookshelf', 1, 0.3, index = 1, position = np.array([3.42591965, 1.50399362, 7.91156292e-04]))]
home_office.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([1.5520182, 0.40020485, -1.18203524e-04]))]
home_office.moving_objects += [Object('desk chair', 0.5, 0.5, index = 3, position = np.array([2.74639668, 1.98231512, -0.22243861]))]
home_office.moving_objects += [Object('filing cabinet', 0.4, 0.6, index = 4, position = np.array([0.30000005, 2.73749082, 4.71239165]))]
home_office.moving_objects += [Object('storage cabinet', 1, 0.4, index = 5, position = np.array([4.50314576, 0.19999979, 6.28318497]))]
home_office.moving_objects += [Object('side table', 0.5, 0.5, index = 6, position = np.array([2.20266938, 0.69600377, 3.13979077]))]
home_office.moving_objects += [Object('floor lamp', 0.4, 0.4, index = 7, position = np.array([1.31613231, 1.559317, 2.94053803]))]

home_office.tertiary_objects = [Object('computer', 0.5, 0.4, index = 0, position = np.array([2.81549872, 2.41200354, 3.14053059]))]
home_office.tertiary_objects += [Object('desk lamp', 0.2, 0.2, index = 1, position = np.array([2.66228422, 2.71221862, 3.1408804]))]
home_office.tertiary_objects += [Object('mouse pad', 0.3, 0.25, index = 2, position = np.array([2.92489847, 2.73730849, 3.14322375]))]
home_office.tertiary_objects += [Object('wall clock', 0.4, 0.1, index = 3, position = np.array([2.80335047, 2.95010945, 3.1415598]))]
home_office.tertiary_objects += [Object('decorative box', 0.4, 0.3, index = 4, position = np.array([3.42561859, 1.53417408, -3.24272777e-03]))]
home_office.tertiary_objects += [Object('picture frame', 0.3, 0.1, index = 5, position = np.array([4.50321933, 0.19978646, 6.28347115]))]
home_office.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 6, position = np.array([2.32905148, 0.71754975, 3.14459052]))]
home_office.tertiary_objects += [Object('throw pillow', 0.4, 0.4, index = 7, position = np.array([1.5522302, 0.3997575, 3.22812103e-04]))]
home_office.tertiary_objects += [Object('house plant', 0.2, 0.2, index = 8, position = np.array([2.07694814, 0.70137478, 3.14424648]))]
home_office.tertiary_objects += [Object('wall art', 0.6, 0.1, index = 9, position = np.array([1.54903231, 0.04996947, 9.67931513e-07]))]
home_office.tertiary_objects += [Object('rug', 2, 1.5, index = 10, position = np.array([1.8541374, 1.00287334, 7.85965525]))]
home_office.tertiary_objects += [Object('chandelier', 1, 1, index = 11, position = np.array([2.4999847, 1.50045626, 3.14168377]))]

home_office.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(5, 3)
create_fixed_object(room, 'door', 0.9, 0.1, 'north', position = 0.1)
create_fixed_object(room, 'window', 1, 0.1, 'south', position = 0.5)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.2)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.8)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', position = 0.2)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', position = 0.8)

room.moving_objects += [Object('desk', 1.5, 0.75, index = 0, position = np.array([3.43068655, 2.625, 3.14159266]))]
room.moving_objects += [Object('bookshelf', 1, 0.3, index = 1, position = np.array([4.85000015, 0.48781005, 1.5707959]))]
room.moving_objects += [Object('armchair', 0.9, 0.9, index = 2, position = np.array([0.45000024, 0.44405379, 4.71238863]))]
room.moving_objects += [Object('desk chair', 0.5, 0.5, index = 3, position = np.array([3.42091585, 1.99239439, 31.49811148]))]
room.moving_objects += [Object('filing cabinet', 0.4, 0.5, index = 4, position = np.array([4.73638484, 2.03517018, 7.82312129]))]
room.moving_objects += [Object('storage box', 0.4, 0.4, index = 5, position = np.array([3.48274309, 0.19999997, 6.28318507]))]
room.moving_objects += [Object('storage box', 0.4, 0.4, index = 6, position = np.array([3.082742, 0.19999971, 12.56636955]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 7, position = np.array([0.27017313, 1.15575788, -9.45851392]))]

room.tertiary_objects += [Object('monitor', 0.6, 0.25, index = 0, position = np.array([3.4182063, 2.65231147, 3.13739401]))]
room.tertiary_objects += [Object('desk lamp', 0.2, 0.2, index = 1, position = np.array([3.81873085, 2.81168991, 10.99761069]))]
room.tertiary_objects += [Object('wall clock', 0.3, 0.1, index = 2, position = np.array([3.43091646, 2.94931084, 3.1415838]))]
room.tertiary_objects += [Object('artwork', 0.6, 0.1, index = 3, position = np.array([4.95000004, 0.99726657, 1.57079624]))]
room.tertiary_objects += [Object('label holder', 0.1, 0.1, index = 4, position = np.array([4.73725856, 2.03550922, 7.84779795]))]
room.tertiary_objects += [Object('blanket', 1, 1.2, index = 5, position = np.array([0.80745418, 0.89541394, 4.68837074]))]
room.tertiary_objects += [Object('table lamp', 0.2, 0.2, index = 6, position = np.array([0.10383378, 1.13993076, -9.42577957]))]
room.tertiary_objects += [Object('cushions', 0.4, 0.4, index = 7, position = np.array([0.42724867, 0.20267761, 4.69679047]))]
room.tertiary_objects += [Object('poster', 0.8, 0.1, index = 8, position = np.array([0.05017626, 0.44552907, 4.71237551]))]
room.tertiary_objects += [Object('pendant light', 0.5, 0.5, index = 9, position = np.array([2.50027612, 1.49975254, 3.14163546]))]
room.tertiary_objects += [Object('area rug', 1.5, 2, index = 10, position = np.array([3.4213961, 1.99209011, 4.7122586]))]
room.tertiary_objects += [Object('desk organizer', 0.3, 0.25, index = 11, position = np.array([3.05602336, 2.40344088, 219.90988532]))]


room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(5, 3)
create_fixed_object(room, 'window', 1, 0.1, 'east', position = 0.5)
create_fixed_object(room, 'window', 1, 0.1, 'west', position = 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'north', position = 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', position = 0.8)
create_fixed_object(room, 'socket', 0.15, 0.1, 'south', position = 0.3)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', position = 0.7)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', position = 0.2)

room.moving_objects += [Object('desk', 1.5, 0.75, index = 0, position = np.array([ 1.29584569,  0.34984078, 12.56584741]))]
room.moving_objects += [Object('bookshelf', 1, 0.3, index = 1, position = np.array([3.01892783, 2.85021321, 3.1417608]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([3.9222286, 1.64811844, 1.01562376]))]
room.moving_objects += [Object('desk chair', 0.6, 0.6, index = 3, position = np.array([ 2.89346686,  0.29999998, 12.56637061]))]
room.moving_objects += [Object('filing cabinet', 0.4, 0.5, index = 4, position = np.array([0.19899028, 0.31405361, 6.28722161]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 5, position = np.array([3.37646953, 1.14484874, 4.5720392]))]
room.moving_objects += [Object('floor lamp', 0.3, 0.3, index = 6, position = np.array([2.30108358, 1.07575203, 6.32303502]))]

room.tertiary_objects += [Object('computer', 0.4, 0.3, index = 0, position = np.array([ 1.29597928,  0.34962008, 12.56626474]))]
room.tertiary_objects += [Object('desk lamp', 0.2, 0.2, index = 1, position = np.array([3.37642437, 1.14483968, 4.6842553]))]
room.tertiary_objects += [Object('wall calendar', 0.5, 0.1, index = 2, position = np.array([1.29566313e+00, 4.99716628e-02, 2.42232457e-07]))]
room.tertiary_objects += [Object('decorative box', 0.3, 0.3, index = 3, position = np.array([0.19916079, 0.31405478, 6.28398011]))]
room.tertiary_objects += [Object('small plant', 0.2, 0.2, index = 4, position = np.array([3.01893404, 2.8509432, 3.14162752]))]
room.tertiary_objects += [Object('throw pillow', 0.5, 0.5, index = 5, position = np.array([3.92243811, 1.64800737, 1.4566141]))]
room.tertiary_objects += [Object('wall art', 0.6, 0.1, index = 6, position = np.array([4.94637865, 2.3500038, 1.57072035]))]
room.tertiary_objects += [Object('table lamp', 0.25, 0.25, index = 7, position = np.array([2.30108358, 1.07575203, 6.32303502]))]
room.tertiary_objects += [Object('area rug', 2, 1.5, index = 8, position = np.array([ 3.92147807,  1.64790626, 12.56641035]))]
room.tertiary_objects += [Object('ceiling light', 0.5, 0.5, index = 9, position = np.array([2.50001189, 1.50001154, 6.28319538]))]

room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(5, 3)
create_fixed_object(room, 'window', 1.5, 0.1, 'south', position = 0.4)
create_fixed_object(room, 'window', 1.5, 0.1, 'south', position = 0.7)
create_fixed_object(room, 'door', 0.9, 0.1, 'east', position = 0.1)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', position = 0.2)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', position = 0.8)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', position = 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', position = 0.7)

room.moving_objects += [Object('desk', 1.5, 0.75, index = 0, position = np.array([2.8999191, 2.62499999, 3.14159269]))]
room.moving_objects += [Object('bookshelf', 1, 0.3, index = 1, position = np.array([4.87177858e-01, 1.49999466e-01, 1.19242886e-06]))]  
room.moving_objects += [Object('chair', 0.75, 0.75, index = 2, position = np.array([2.90557864, 1.84998101, 12.57612957]))]
room.moving_objects += [Object('desk chair', 0.6, 0.6, index = 3, position = np.array([2.21050851, 1.90932109, -0.2391524]))]
room.moving_objects += [Object('filing cabinet', 0.4, 0.6, index = 4, position = np.array([0.30000007, 2.41740293, 4.7123896]))]
room.moving_objects += [Object('small coffee table', 0.5, 0.5, index = 5, position = np.array([3.89995186, 2.74998239, 3.14152351]))]

room.tertiary_objects += [Object('computer', 0.5, 0.4, index = 0, position = np.array([2.91927625, 2.68877876, 3.14155508]))]
room.tertiary_objects += [Object('lamp', 0.15, 0.15, index = 1, position = np.array([3.21056599, 2.76258115, 9.42537299]))]
room.tertiary_objects += [Object('monitor', 0.5, 0.2, index = 2, position = np.array([3.22669178, 2.48874662, 3.14147267]))]
room.tertiary_objects += [Object('organizer', 0.3, 0.2, index = 3, position = np.array([0.32338205, 2.51884472, 4.71060183]))]
room.tertiary_objects += [Object('bookends', 0.1, 0.1, index = 4, position = np.array([ 4.47253058e-01,  2.06189143e-01, -1.95600184e-05]))]
room.tertiary_objects += [Object('bookends', 0.1, 0.1, index = 5, position = np.array([ 4.86952299e-01,  1.06186869e-01, -3.47562783e-05]))]
room.tertiary_objects += [Object('plant', 0.3, 0.3, index = 6, position = np.array([4.02100891, 2.72539988, 3.14363884]))]
room.tertiary_objects += [Object('frame', 0.2, 0.1, index = 7, position = np.array([3.76694866, 2.70136587, 3.13568884]))]
room.tertiary_objects += [Object('clock', 0.3, 0.1, index = 8, position = np.array([2.9017624, 2.95013475, 3.1415963]))]
room.tertiary_objects += [Object('painting', 0.4, 0.1, index = 9, position = np.array([4.93846837, 1.51040892, 1.56244223]))]
room.tertiary_objects += [Object('rug', 2.5, 1.5, index = 10, position = np.array([ 2.97670445,  1.7508359, 20.42038373]))]

room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(5, 3)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.5)
create_fixed_object(room, 'window', 1, 0.1, 'west', 0.5)
create_fixed_object(room, 'door', 0.8, 0.1, 'south', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.25)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.75)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.25)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.75)

room.moving_objects += [Object('desk', 1.5, 0.8, index = 0, position = np.array([3.37333622, 0.39999973, 6.28318525]))]
room.moving_objects += [Object('bookshelf', 1.2, 0.4, index = 1, position = np.array([4.04059202, 2.79999977, 3.14159347]))]
room.moving_objects += [Object('armchair', 0.9, 0.9, index = 2, position = np.array([ 0.43529148,  2.45433945, -1.56086823]))]
room.moving_objects += [Object('desk chair', 0.6, 0.6, index = 3, position = np.array([ 3.39578331,  1.1192851, -2.96193642]))]
room.moving_objects += [Object('filing cabinet', 0.4, 0.5, index = 4, position = np.array([4.74925551, 0.99800162, 1.56713912]))]
room.moving_objects += [Object('storage cabinet', 1, 0.5, index = 5, position = np.array([2.93345183, 2.57702518, 3.10572217]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 6, position = np.array([0.51868099, 1.75512742, 3.15153889]))]

room.tertiary_objects += [Object('monitor', 0.6, 0.4, index = 0, position = np.array([3.3913584, 0.4476504, 6.2828746]))]
room.tertiary_objects += [Object('lamp_desk', 0.2, 0.2, index = 1, position = np.array([3.78741834, 0.15237061, 1.5710181]))]
room.tertiary_objects += [Object('plant_desk', 0.3, 0.3, index = 2, position = np.array([2.94139821, 0.60035006, 9.42430665]))]
room.tertiary_objects += [Object('organizer', 0.3, 0.2, index = 3, position = np.array([4.74922935, 0.99700533, 1.57005336]))]
room.tertiary_objects += [Object('frame', 0.3, 0.1, index = 4, position = np.array([4.04072797, 2.80011757, 3.1416073]))]
room.tertiary_objects += [Object('calendar', 0.5, 0.1, index = 5, position = np.array([3.30001516, 2.95013887, 3.14129514]))]
room.tertiary_objects += [Object('lamp_table', 0.3, 0.3, index = 6, position = np.array([0.63755587, 1.87440819, 3.14358074]))]
room.tertiary_objects += [Object('plant_small', 0.2, 0.2, index = 7, position = np.array([0.39991906, 1.63606237, 3.14352745]))]
room.tertiary_objects += [Object('art', 0.8, 0.1, index = 8, position = np.array([0.05000192, 2.45000717, 4.7122634]))]
room.tertiary_objects += [Object('rug', 2, 1.5, index = 9, position = np.array([0.99943569, 2.25020468, 3.1415926]))]
 
room.draw(level= 1, arrows = True, key = True)

# %%
room = create_room(4, 6)
create_fixed_object(room, 'window', 1, 0.1, 'south', position = 0.5)
create_fixed_object(room, 'window', 1, 0.1, 'north', position = 0.2)
create_fixed_object(room, 'door', 1, 0.1, 'east', position = 0.1)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', position = 0.4)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.6)

room.moving_objects += [Object('sofa', 2, 1, index = 0, position = np.array([3.49999996, 3.12986111, 1.57079636]))]
room.moving_objects += [Object('tv stand', 1.5, 0.5, index = 1, position = np.array([0.25000001, 3.88400603, 4.71238898]))]
room.moving_objects += [Object('bookshelf', 1, 0.3, index = 2, position = np.array([0.1500001, 0.49083308, 4.71238897]))]
room.moving_objects += [Object('coffee table', 1, 0.5, index = 3, position = np.array([1.75099917, 3.04597815, 4.71164007]))]
room.moving_objects += [Object('entertainment console', 1.5, 0.4, index = 4, position = np.array([0.19999972, 2.38400512, -1.5707965]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 5, position = np.array([2.30029387, 1.48206155, 6.19984508]))]
room.moving_objects += [Object('small side table', 0.5, 0.5, index = 6, position = np.array([2.32487547, 0.82712898, 9.34325059]))]

room.tertiary_objects += [Object('rug', 2, 3, index = 0, position = np.array([ 1.86341481,  3.17155737, -0.04371158]))]
room.tertiary_objects += [Object('lamp', 0.3, 0.3, index = 1, position = np.array([2.43994321, 0.92481289, 12.56511231]))]
room.tertiary_objects += [Object('tv', 1.2, 0.1, index = 2, position = np.array([0.27051281, 3.89118949, 4.70872743]))]
room.tertiary_objects += [Object('tray', 0.4, 0.4, index = 3, position = np.array([1.72777539, 3.03605744, 4.71309567]))]
room.tertiary_objects += [Object('painting', 1.2, 0.1, index = 4, position = np.array([3.95006008, 3.12986037, 1.57079632]))]
room.tertiary_objects += [Object('vase', 0.2, 0.2, index = 5, position = np.array([0.20000001, 2.38401177, -1.57079711]))]
room.tertiary_objects += [Object('chandelier', 1, 1, index = 6, position = np.array([1.99999756, 3.00000017, 1.570794]))]
room.tertiary_objects += [Object('clock', 0.5, 0.1, index = 7, position = np.array([0.04998908, 0.49083354, 4.71238897]))]

room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(4, 6)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.5)
create_fixed_object(room, 'window', 1, 0.1, 'east', 0.7)
create_fixed_object(room, 'door', 0.9, 0.1, 'south', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.2)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.8)
room.moving_objects += [Object('sofa', 2, 1, index = 0, position = np.array([0.5000203, 3.31082462, -1.57071242]))]
room.moving_objects += [Object('tv stand', 1.5, 0.5, index = 1, position = np.array([3.74969756, 5.25493041, 7.85420788]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([3.49998887, 1.54392261, 1.57077306]))]
room.moving_objects += [Object('coffee table', 1.2, 0.6, index = 3, position = np.array([2.45762453, 3.40877834, 4.49888966]))]
room.moving_objects += [Object('floor lamp', 0.5, 0.5, index = 4, position = np.array([0.6563937, 1.62474194, 4.78654425]))]
room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 5, position = np.array([0.65848779, 5.84999995, 9.42477786]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 6, position = np.array([3.58020965, 0.3338153, 6.89458032]))]
room.moving_objects += [Object('bookcase', 0.8, 0.3, index = 7, position = np.array([3.81891707, 2.57196257, 1.45043873]))]
room.moving_objects += [Object('floor lamp', 0.5, 0.5, index = 8, position = np.array([2.27471143, 0.50318764, 4.79546975]))]

room.tertiary_objects = [Object('rug', 2, 3, index = 0, position = [ 2.45358596,  3.41965791, 12.55912094])]
room.tertiary_objects += [Object('cushion1', 0.5, 0.5, index = 1, position = [ 0.75665003,  3.30576619, -1.56149635])]
room.tertiary_objects += [Object('cushion2', 0.5, 0.5, index = 2, position = [ 0.25653648,  3.3156266,  -1.56149549])]
room.tertiary_objects += [Object('lamp', 0.3, 0.3, index = 3, position = [3.5903792,  0.44337901, 7.64879122])]
room.tertiary_objects += [Object('tv', 1.2, 0.1, index = 4, position = [3.949847,   5.25387563, 1.57068574])]
room.tertiary_objects += [Object('painting', 1, 0.1, index = 5, position = [0.0500299,  3.31035653, 4.71241754])]
room.tertiary_objects += [Object('vase', 0.2, 0.2, index = 6, position = [2.38386484, 3.2639476, 4.67633286])]
room.tertiary_objects += [Object('tray', 0.4, 0.3, index = 7, position = [2.46719744, 3.5978474, 4.66745585])]
room.tertiary_objects += [Object('clock', 0.8, 0.1, index = 8, position = [0.05064265, 5.60888787, 4.71047417])]
room.tertiary_objects += [Object('coaster1', 0.1, 0.1, index = 9, position = [2.53256622, 3.36425451, 4.66136552])]
room.tertiary_objects += [Object('coaster2', 0.1, 0.1, index = 10, position = [3.54992271, 0.23539442, 6.40407356])]
room.tertiary_objects += [Object('sculpture', 0.2, 0.2, index = 11, position = [0.64078041, 5.82806468, 9.42628051])]

room.draw(level = 1, arrows = True, key = True)

# %%
living_room = create_room(4, 6)
create_fixed_object(living_room, 'window', 1, 0.1, 'north', position = 0.25)
create_fixed_object(living_room, 'window', 1, 0.1, 'north', position = 0.75)
create_fixed_object(living_room, 'door', 0.9, 0.1, 'south', position = 0.5)
create_fixed_object(living_room, 'socket', 0.15, 0.1, 'east', position = 0.3)
create_fixed_object(living_room, 'socket', 0.15, 0.1, 'west', position = 0.7)
create_fixed_object(living_room, 'socket', 0.15, 0.1, 'north', position = 0.1)
create_fixed_object(living_room, 'socket', 0.15, 0.1, 'south', position = 0.8)

living_room.moving_objects += [Object('sofa', 2, 0.9, index = 0, position = np.array([0.45000018, 2.66999479, 4.71238883]))]
living_room.moving_objects += [Object('tv stand', 1.5, 0.4, index = 1, position = np.array([3.80000006, 2.07999629, 1.57079641]))]
living_room.moving_objects += [Object('armchair', 0.9, 0.9, index = 2, position = np.array([3.54999967, 4.79266898, 1.57079582]))]
living_room.moving_objects += [Object('coffee table', 1.2, 0.6, index = 3, position = np.array([1.52088749, 4.27960647, 4.67090127]))]
living_room.moving_objects += [Object('ottoman', 0.6, 0.6, index = 4, position = np.array([2.28508254, 3.3264205, -1.48058888]))]
living_room.moving_objects += [Object('tv', 1.2, 0.05, index = 5, position = np.array([4.02500375, 2.18075622, 17.2787658]))]
living_room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 6, position = np.array([3.57150856, 0.14969631, 0.00110602]))]
living_room.moving_objects += [Object('side table', 0.5, 0.5, index = 7, position = np.array([2.69046387, 4.02743595, -2.8711042]))]
living_room.moving_objects += [Object('floor lamp', 0.4, 0.4, index = 8, position = np.array([3.29101588, 3.63379302, 0.13284797]))]


living_room.tertiary_objects = [Object('painting', 1.2, 0.1, index = 0, position = [0.0499361, 2.71390051, 4.71236905])]
living_room.tertiary_objects += [Object('mirror', 1, 0.1, index = 1, position = [0.04996614, 1.79324795, 4.71248697])]
living_room.tertiary_objects += [Object('chandelier', 1, 1, index = 2, position = [2.00216912, 2.99903768, 75.3997618])]
living_room.tertiary_objects += [Object('table lamp', 0.3, 0.3, index = 3, position = [2.68927733, 4.02124926, -3.0874015])]
living_room.tertiary_objects += [Object('decorative_bowl', 0.4, 0.4, index = 4, position = [1.51852632, 4.28159738, 4.70421256])]
living_room.tertiary_objects += [Object('framed_photo', 0.25, 0.1, index = 5, position = [3.79987539, 2.07735878, 1.57093784])]
living_room.tertiary_objects += [Object('ornamental_sculpture', 0.3, 0.3, index = 6, position = [3.57162747, 0.16863721, 0.00067063])]
living_room.tertiary_objects += [Object('area_rug', 3, 2, index = 7, position = [1.52630672, 4.2811603, 175.92604876])]
 
living_room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(4, 6)
create_fixed_object(room, 'window', 1.5, 0.1, 'north', position = 0.25)
create_fixed_object(room, 'window', 1.5, 0.1, 'south', position = 0.75)
create_fixed_object(room, 'door', 1, 0.1, 'east', position = 0.5)
create_fixed_object(room, 'socket', 0.1, 0.1, 'north', position = 0.5)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.3)
create_fixed_object(room, 'socket', 0.1, 0.1, 'east', position = 0.2)

room.moving_objects += [Object('sofa', 2.5, 1, index = 0, position = np.array([0.50075364, 3.22849463, 4.71299005]))]
room.moving_objects += [Object('armchair', 1, 1, index = 1, position = np.array([2.73727355, 5.22491474, 3.32046579]))]
room.moving_objects += [Object('desk', 1.5, 0.7, index = 2, position = np.array([2.48991077, 0.34965246, 6.28362329]))]
room.moving_objects += [Object('coffee table', 1, 0.5, index = 3, position = np.array([2.50000585, 3.55759842, 3.14149149]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 4, position = np.array([2.85468941, 4.48392588, 6.46183045]))]
room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 5, position = np.array([0.94479388, 5.79489256, 0.00000177]))]
room.moving_objects += [Object('desk chair', 0.5, 0.5, index = 6, position = np.array([1.42045771, 1.65124918, 10.30765716]))]
room.moving_objects += [Object('filing cabinet', 0.4, 0.4, index = 7, position = np.array([1.50336241, 0.93053686, 1.62487478]))]

room.tertiary_objects = [Object('rug', 2, 3, index = 0, position = [2.43528477, 4.67910308, 7.92238618] )]
room.tertiary_objects += [Object('table_lamp', 0.3, 0.3, index = 1, position = [2.77365037, 4.3671426, 3.14299998])]
room.tertiary_objects += [Object('wall_art', 1.5, 0.1, index = 2, position = [2.92519243, 5.95010576, 3.14168803])]
room.tertiary_objects += [Object('reading_lamp', 0.3, 0.3, index = 3, position = [2.44654882, 5.42634253, 7.85402591])]
room.tertiary_objects += [Object('desk_lamp', 0.2, 0.2, index = 4, position = [2.11496937, 0.1744539, 14.13721624])]
room.tertiary_objects += [Object('monitor', 0.5, 0.3, index = 5, position = [2.48965466, 0.34967649, 6.28331983])]
room.tertiary_objects += [Object('chandelier', 1, 1, index = 6, position = [1.99994204, 2.99995366, 196.34957559])]
room.tertiary_objects += [Object('clock', 0.5, 0.1, index = 7, position = [0.05104334, 5.75490026, 4.71055542])]
room.tertiary_objects += [Object('mirror', 1, 0.1, index = 8, position = [0.05000012, 4.29993108, 4.71240351])]
room.tertiary_objects += [Object('painting', 1.2, 0.1, index = 9, position = [0.04997586, 3.19992887, 4.71240844])]

room.draw(level = 1, arrows = True, key = True)

# %%
room = create_room(4, 6)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', position = 0.3)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', position = 0.7)
create_fixed_object(room, 'door', 0.9, 0.1, 'east', position = 0.2)
create_fixed_object(room, 'socket', 0.1, 0.1, 'north', position = 0.5)
create_fixed_object(room, 'socket', 0.1, 0.1, 'west', position = 0.8)

room.moving_objects = [Object('sofa', 2.5, 1, index = 0, position = np.array([3.49980703, 3.38449083, 7.85414495]))]
room.moving_objects += [Object('tv stand', 1.5, 0.4, index = 1, position = np.array([0.19997568, 3.5210955, 4.71242139]))]
room.moving_objects += [Object('armchair', 0.8, 0.8, index = 2, position = np.array([1.43144223, 2.19970979, 1.00614658]))]
room.moving_objects += [Object('coffee table', 1, 0.6, index = 3, position = np.array([2.29606182, 4.15937594, 7.83330112]))]
room.moving_objects += [Object('side table', 0.5, 0.5, index = 4, position = np.array([ 3.74973773,  4.8847813, 20.41953798]))]
room.moving_objects += [Object('floor lamp', 0.4, 0.4, index = 5, position = np.array([2.22175476, 3.44730994, 4.70491037]))]
room.moving_objects += [Object('bookshelf', 0.8, 0.3, index = 6, position = np.array([0.79208712, 2.24030645, 7.66875383]))]

room.tertiary_objects = [Object('table_lamp', 0.3, 0.3, index = 0, position = [3.7497377, 4.88478187, 20.42018939])]
room.tertiary_objects += [Object('decorative_tray', 0.5, 0.3, index = 1, position = [2.29606182, 4.15937593, 7.84984537])]
room.tertiary_objects += [Object('flat_screen_tv', 1.2, 0.1, index = 2, position = [0.04997294, 3.5210892, 4.71238897])]
room.tertiary_objects += [Object('soundbar', 1, 0.1, index = 3, position = [0.19997521, 3.5210955, 4.71239545])]
room.tertiary_objects += [Object('small_table_lamp', 0.2, 0.2, index = 4, position = [1.43144223, 2.19970978, 1.45455135])]
room.tertiary_objects += [Object('framed_picture', 0.6, 0.1, index = 5, position = [0.05051473, 2.19965265, 4.71238893])]
room.tertiary_objects += [Object('chandelier', 1, 1, index = 6, position = [  2.00000249,   2.99999788, 102.10176156])]
room.tertiary_objects += [Object('area_rug', 2, 1.5, index = 7, position = [2.29606174, 4.15937609, 3.14159263])]

room.draw(level = 1, arrows = True, key = True)

# %%
## ATISS living room 
room = create_room(8, 4)

room.moving_objects = [Object('dining table', 1.8, 1, index = 0, position = (7, 2, 0))]
room.moving_objects += [Object('sofa', 2.5, 1.2, index = 1, position = (2.2, 3.4, np.pi))]

room.moving_objects += [Object('dining chair', 0.7, 0.7, index = 2, position = (7.4, 2.3, np.pi))]
room.moving_objects += [Object('dining chair', 0.7, 0.7, index = 3, position = (6.6, 2.4, np.pi))]

room.moving_objects += [Object('dining chair', 0.7, 0.7, index = 4, position = (7.46, 1, 0))]
room.moving_objects += [Object('dining chair', 0.7, 0.7, index = 5, position = (6.6, 1, 0))]

room.moving_objects += [Object('end table', 0.7, 0.7, index = 6, position = (0.5, 3.4, np.pi))]
room.moving_objects += [Object('end table', 0.7, 0.7, index = 7, position = (3.9, 3.4, np.pi))]

room.moving_objects += [Object('coffee table', 1.5, 1, index = 8, position = (2.2, 2, 0))]
room.moving_objects += [Object('tv stand', 2.5, 0.6, index = 9, position = (2.2, 0.6, 0))]

room.moving_objects += [Object('armchair', 1.2, 0.8, index = 8, position = (0.5, 2, 3*np.pi/2))]
room.moving_objects += [Object('stool', 1, 0.7, index = 9, position = (3.9, 2, np.pi/2))]

room.tertiary_objects = [Object('pendant_light', 0.4, 0.4, index = 0, position = (7, 2, np.pi/4))]
room.tertiary_objects += [Object('chandelier', 1.1, 1.1, index = 0, position = (2.2, 2, 0))]
room.tertiary_objects += [Object('ornaments', 0.8, 0.4, index = 0, position = (2.9, 0.6, 0))]
room.draw()

# %%
for obj in room.moving_objects + room.tertiary_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# dining table 1.8 1 (7, 2, 0)
#
# sofa 2.5 1.2 (2.2, 3.4, 3.141592653589793)
#
# dining chair 0.7 0.7 (7.4, 2.3, 3.141592653589793)
#
# dining chair 0.7 0.7 (6.6, 2.4, 3.141592653589793)
#
# dining chair 0.7 0.7 (7.46, 1, 0)
#
# dining chair 0.7 0.7 (6.6, 1, 0)
#
# end table 0.7 0.7 (0.5, 3.4, 3.141592653589793)
#
# end table 0.7 0.7 (3.9, 3.4, 3.141592653589793)
#
# coffee table 1.5 1 (2.2, 2, 0)
#
# tv stand 2.5 0.6 (2.2, 0.6, 0)
#
# armchair 1.2 0.8 (0.5, 2, 4.71238898038469)
#
# stool 1 0.7 (3.9, 2, 1.5707963267948966)
#
# pendant_light 0.4 0.4 (7, 2, 0.7853981633974483)
#
# chandelier 1.1 1.1 (2.2, 2, 0)
#
# ornaments 0.8 0.4 (2.9, 0.6, 0)

# %%
## ATISS bedroom

num = 3/4

room = create_room(num*4, num*5.4)

room.moving_objects = [Object('wardrobe', num*8/3, num*2/3, index = 0, position = [num*1.35, num*5.05, np.pi])]
room.moving_objects += [Object('bed', num*8/3, num*7/3, index = 1, position = [num*1.2, num*3, 3*np.pi/2])]
room.moving_objects += [Object('vanity', num*1, num*1.2/3, index = 2, position = [num*0.2, num*2.5/3, 3*np.pi/2])]
room.moving_objects += [Object('stool', num*1/3, num*1.2/3, index = 3, position = [num*0.7, num*2.5/3, np.pi/2])]
room.moving_objects += [Object('cabinet', num*2/3, num*1.2/3, index = 4, position = [num*3.8, num*11/3, np.pi/2])]
room.moving_objects += [Object('nightstand', num*2/3, num*1.2/3, index = 4, position = [num*3.8, num*8/3, np.pi/2])]

room.tertiary_objects = [Object('flowers', num*0.2, num*0.2, index = 0, position= (num*0.25, num*0.5, 0))]
room.tertiary_objects += [Object('shelf', num*2/3, num*1.2/3, index = 1, position = (num*3.8, num*9/3, np.pi/2))]
room.tertiary_objects += [Object('pendant light', num*0.5, num*0.5, index = 2, position = [num*1.5, num*3, 0])]

print(f"room width: {num*4}, room length: {num*5.4}")
print(f"bed width: {num*8/3}, bed length: {num*7/3}")
room.draw()
# Out:
# room width: 3.0, room length: 4.050000000000001
# bed width: 2.0, bed length: 1.75

# %%
for obj in room.moving_objects + room.tertiary_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# wardrobe 2.0 0.5 [1.0125000000000002, 3.7874999999999996, 3.141592653589793]
#
# bed 2.0 1.75 [0.8999999999999999, 2.25, 4.71238898038469]
#
# vanity 0.75 0.3 [0.15000000000000002, 0.625, 4.71238898038469]
#
# stool 0.25 0.3 [0.5249999999999999, 0.625, 1.5707963267948966]
#
# cabinet 0.5 0.3 [2.8499999999999996, 2.75, 1.5707963267948966]
#
# nightstand 0.5 0.3 [2.8499999999999996, 2.0, 1.5707963267948966]
#
# flowers 0.15000000000000002 0.15000000000000002 (0.1875, 0.375, 0)
#
# shelf 0.5 0.3 (2.8499999999999996, 2.25, 1.5707963267948966)
#
# pendant light 0.375 0.375 [1.125, 2.25, 0]

# %%
## ATISS bedroom 4.3 x 6

num = 3/4
room = create_room(num*4.3,num* 6)
room.moving_objects = [Object('bed', num*2.9, num*3.2, index = 0, position = (num*1.6,num* 2.6, 3*np.pi/2))]
room.moving_objects += [Object('wardrobe', num*1.4,num* 0.7, index = 1, position = (num*2, num*5.6, np.pi))]
room.moving_objects += [Object('wardrobe', num*1.3, num*0.8, index = 2, position = (num*0.65, num*5.6, np.pi))]
room.moving_objects += [Object('nightstand', num*0.9, num*0.5, index = 3, position = (num*0.25, num*4.5, 3*np.pi/2))]
room.moving_objects += [Object('nightstand', num*0.9,num* 0.5, index = 4, position = (num*0.25,num* 0.45, 3*np.pi/2))]
room.moving_objects += [Object('armchair',num* 1,num* 1, index = 5, position = (num*3.6, num*0.7, np.pi/4))]

room.tertiary_objects = [Object('ceiling light',num* 1,num* 1.1, index = 0, position= (num*2.25,num* 2.9, 0))]
room.tertiary_objects += [Object('table lamp', num*0.2,num* 0.2, index = 1, position =( num*0.25, num*4.5, 3*np.pi/2))]
room.tertiary_objects += [Object('wall lamp', num*0.2,num* 0.2, index = 1, position =(num*0.1, num*1, 3*np.pi/2))]

print(f"room width: {num*4.3}, room length: {num*6}")
print(f"bed width: {num*2.9}, bed length: {num*3.2}")
room.draw()
# Out:
# room width: 3.2249999999999996, room length: 4.5
# bed width: 2.175, bed length: 2.4000000000000004

# %%
for obj in room.moving_objects + room.tertiary_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# bed 2.175 2.4000000000000004 (1.2000000000000002, 1.9500000000000002, 4.71238898038469)
#
# wardrobe 1.0499999999999998 0.5249999999999999 (1.5, 4.199999999999999, 3.141592653589793)
#
# wardrobe 0.9750000000000001 0.6000000000000001 (0.48750000000000004, 4.199999999999999, 3.141592653589793)
#
# nightstand 0.675 0.375 (0.1875, 3.375, 4.71238898038469)
#
# nightstand 0.675 0.375 (0.1875, 0.3375, 4.71238898038469)
#
# armchair 0.75 0.75 (2.7, 0.5249999999999999, 0.7853981633974483)
#
# ceiling light 0.75 0.8250000000000001 (1.6875, 2.175, 0)
#
# table lamp 0.15000000000000002 0.15000000000000002 (0.1875, 3.375, 4.71238898038469)
#
# wall lamp 0.15000000000000002 0.15000000000000002 (0.07500000000000001, 0.75, 4.71238898038469)

# %%
## LayoutGPT bedroom 3x4 

ppm = 341/4

room = create_room(256/ppm, 341/ppm)
room.moving_objects = [Object('double bed', 190/ppm, 167/ppm, index = 0, position = (130/ppm, 170/ppm, np.deg2rad(90) + np.pi/2))]
room.moving_objects += [Object('nightstand', 32/ppm, 45/ppm, index = 1, position = (255/ppm, 75/ppm, np.deg2rad(90)+ np.pi/2))]
room.moving_objects += [Object('wardrobe', 47/ppm, 167/ppm, index = 2, position = (120/ppm, 290/ppm, np.deg2rad(180)+ np.pi/2))]
room.moving_objects += [Object('pendant lamp', 70/ppm, 70/ppm, index = 3, position = (125/ppm, 160/ppm, np.deg2rad(90)+ np.pi/2))]

room.draw()
plt.show()

# ppm = 341/4

# room = create_room(256/ppm, 341/ppm)
# room.moving_objects = [Object('double bed', 190/ppm, 200/ppm, index = 0, position = (120/ppm, 100/ppm, 0+ np.pi/2))]
# room.moving_objects += [Object('wardrobe', 56/ppm, 205/ppm, index = 1, position = (20/ppm, 130/ppm, np.deg2rad(90)+ np.pi/2))]
# room.moving_objects += [Object('nightstand', 36/ppm, 54/ppm, index = 2, position = (290/ppm, 20/ppm, np.deg2rad(0)+ np.pi/2))]
# room.moving_objects += [Object('nightstand', 36/ppm, 54/ppm, index = 3, position = (290/ppm, 220/ppm, np.deg2rad(0)+ np.pi/2))]
# room.moving_objects += [Object('pendant lamp', 60/ppm, 60/ppm, index = 4, position = (140/ppm, 140/ppm, np.deg2rad(0)+ np.pi/2))]
# room.moving_objects += [Object('dressing_table', 40/ppm, 80/ppm, index = 5, position = (20/ppm, 20/ppm, np.deg2rad(0)+ np.pi/2))]
# room.moving_objects += [Object('dressing_chair', 35/ppm, 35/ppm, index = 6, position = (60/ppm, 40/ppm, np.deg2rad(0)+ np.pi/2))]
# room.draw()
# plt.show()

# ppm = 341/4

# room = create_room(256/ppm, 341/ppm)
# room.moving_objects = [Object('wardrobe', 52/ppm, 80/ppm, index = 0, position = (172/ppm, 28/ppm, np.deg2rad(180)))]
# room.moving_objects += [Object('single bed', 90/ppm, 190/ppm, index = 1, position = (130/ppm, 180/ppm, 0))]
# room.moving_objects += [Object('nightstand', 40/ppm, 40/ppm, index = 2, position = (70/ppm, 220/ppm, 0))]
# room.moving_objects += [Object('nightstand', 40/ppm, 40/ppm, index = 3, position = (240/ppm, 220/ppm, 0))]
# room.moving_objects += [Object('ceiling lamp', 30/ppm, 30/ppm, index = 4, position = (150/ppm, 150/ppm, 0))]
# room.draw()
# plt.show()

# %%
for obj in room.moving_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# double bed 2.228739002932551 1.9589442815249267 (1.5249266862170088, 1.9941348973607038, 3.141592653589793)
#
# nightstand 0.375366568914956 0.5278592375366569 (2.9912023460410557, 0.8797653958944281, 3.141592653589793)
#
# wardrobe 0.5513196480938416 1.9589442815249267 (1.4076246334310851, 3.401759530791789, 4.71238898038469)
#
# pendant lamp 0.8211143695014663 0.8211143695014663 (1.466275659824047, 1.8768328445747802, 3.141592653589793)

# %%
print(10.5*3.2249999999999996/11)
print(18*3.2249999999999996/11)
# Out:
# 3.0784090909090907
# 5.277272727272727

# %%
## LayoutGPT living room 8x4
# num = 512 / 8
# room = create_room(512/ppm, 256/ppm)
# room.moving_objects = [Object('multi_seat_sofa', 58/num, 130/num, index = 0, position = (32/num, 289/num, 0 + np.pi/2))]
# room.moving_objects += [Object('corner_side_table', 40/num, 40/num, index = 1, position = (10/num, 69/num, 0+ np.pi/2))]
# room.moving_objects += [Object('corner_side_table', 40/num, 40/num, index = 2, position = (10/num, 240/num, 0+ np.pi/2))]
# room.moving_objects += [Object('dining_table', 60/num, 110/num, index = 3, position = (150/num, 60/num, 0+ np.pi/2))]
# room.moving_objects += [Object('dining_chair', 32/num, 32/num, index = 4, position = (113/num, 20/num, 0+ np.pi/2))]
# room.moving_objects += [Object('dining_chair', 32/num, 32/num, index = 5, position = (186/num, 20/num, 0+ np.pi/2))]
# room.moving_objects += [Object('dining_chair', 32/num, 32/num, index = 6, position = (113/num, 100/num, np.pi+ np.pi/2))]
# room.moving_objects += [Object('dining_chair', 32/num, 32/num, index = 7, position = (186/num, 100/num, np.pi+ np.pi/2))]
# room.moving_objects += [Object('tv_stand', 40/num, 132/num, index = 8, position = (230/num, 150/num, np.pi/2+ np.pi/2))]
# room.moving_objects += [Object('pendant_lamp', 20/num, 20/num, index = 9, position = (150/num, 60/num, 0+ np.pi/2))]
# room.moving_objects += [Object('pendant_lamp', 20/num, 20/num, index = 10, position = (80/num, 250/num, 0+ np.pi/2))]
# room.draw()

# room.draw()
# plt.show()

# ## LayoutGPT living room 8x4

num = 512 / 8
room = create_room(256/ppm, 512/ppm)
room.moving_objects = [Object('pendant_lamp', 36/num, 36/num, index = 0, position = (117/num, 166/num, 0 - np.pi/2))]
room.moving_objects += [Object('tv_stand', 29/num, 127/num, index = 1, position = (18/num, 241/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('coffee_table', 26/num, 45/num, index = 2, position = (112/num, 200/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('corner_side_table', 37/num, 37/num, index = 3, position = (29/num, 300/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('corner_side_table', 37/num, 37/num, index = 4, position = (25/num, 111/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('loveseat_sofa', 60/num, 141/num, index = 5, position = (32/num, 204/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('armchair', 45/num, 52/num, index = 6, position = (112/num, 304/num, np.pi - np.pi/2))]
room.moving_objects += [Object('dining_chair', 36/num, 37/num, index = 7, position = (126/num, 19/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('dining_chair', 36/num, 37/num, index = 8, position = (125/num, 59/num, np.pi/2 - np.pi/2))]
room.moving_objects += [Object('dining_chair', 36/num, 37/num, index = 9, position = (212/num, 21/num, np.deg2rad(91) - np.pi/2))]
room.moving_objects += [Object('dining_chair', 36/num, 37/num, index = 10, position = (212/num, 60/num, np.deg2rad(91) - np.pi/2))]
room.moving_objects += [Object('dining_table', 57/num, 103/num, index = 11, position = (169/num, 53/num, np.pi/2 - np.pi/2))]

room.draw()
plt.show()

# %%
for obj in room.moving_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# pendant_lamp 0.5625 0.5625 (1.828125, 2.59375, -1.5707963267948966)
#
# tv_stand 0.453125 1.984375 (0.28125, 3.765625, 0.0)
#
# coffee_table 0.40625 0.703125 (1.75, 3.125, 0.0)
#
# corner_side_table 0.578125 0.578125 (0.453125, 4.6875, 0.0)
#
# corner_side_table 0.578125 0.578125 (0.390625, 1.734375, 0.0)
#
# loveseat_sofa 0.9375 2.203125 (0.5, 3.1875, 0.0)
#
# armchair 0.703125 0.8125 (1.75, 4.75, 1.5707963267948966)
#
# dining_chair 0.5625 0.578125 (1.96875, 0.296875, 0.0)
#
# dining_chair 0.5625 0.578125 (1.953125, 0.921875, 0.0)
#
# dining_chair 0.5625 0.578125 (3.3125, 0.328125, 0.01745329251994332)
#
# dining_chair 0.5625 0.578125 (3.3125, 0.9375, 0.01745329251994332)
#
# dining_table 0.890625 1.609375 (2.640625, 0.828125, 0.0)

# %%
for obj in room.moving_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# multi-seat sofa 2.21875 1.0 (0.59375, 3.0625, 1.5707963267948966)
#
# armchair 1.15625 0.96875 (2.125, 4.78125, 3.141592653589793)
#
# coffee table 1.328125 1.328125 (2.171875, 2.90625, 1.5707963267948966)
#
# corner_side_table 0.59375 0.59375 (0.5625, 4.765625, 3.141592653589793)
#
# loveseat sofa 2.6875 1.0625 (2.109375, 1.203125, 0)
#
# corner_side_table 0.59375 0.59375 (0.484375, 1.203125, 3.141592653589793)
#
# tv stand 2.0 0.390625 (4.046875, 2.65625, 1.5707963267948966)
#
# pendant lamp 0.890625 0.875 (2.140625, 2.96875, 3.141592653589793)

# %%
## LayoutGPT bedroom 2

ppm = 357 / 4.5
# room = create_room(256/ppm, 357/ppm)
# room.moving_objects = [Object('double bed', 170/ppm, 150/ppm, index = 0, position = (150/ppm, 160/ppm, np.deg2rad(90)))]
# room.moving_objects += [Object('nightstand', 30/ppm, 40/ppm, index = 1, position = (210/ppm, 210/ppm, np.deg2rad(90)))]
# room.moving_objects += [Object('nightstand', 30/ppm, 40/ppm, index = 2, position = (210/ppm, 110/ppm, np.deg2rad(90)))]
# room.moving_objects += [Object('wardrobe', 100/ppm, 200/ppm, index = 3, position = (70/ppm, 60/ppm, np.deg2rad(180)))]
# room.moving_objects += [Object('pendant lamp', 30/ppm, 30/ppm, index = 4, position = (110/ppm, 130/ppm, np.deg2rad(90)))]
# room.draw()
# plt.show()

# room = create_room(256/ppm, 357/ppm)
# room.moving_objects = [Object('double bed', 178/ppm, 166/ppm, index = 0, position = (96/ppm, 119/ppm, np.deg2rad(0)))]
# room.moving_objects += [Object('nightstand', 28/ppm, 40/ppm, index = 1, position = (17/ppm, 71/ppm, np.deg2rad(90)))]
# room.moving_objects += [Object('nightstand', 28/ppm, 40/ppm, index = 2, position = (320/ppm, 71/ppm, np.deg2rad(90)))]
# room.moving_objects += [Object('pendant lamp', 50/ppm, 50/ppm, index = 3, position = (175/ppm, 125/ppm, np.deg2rad(180)))]
# room.moving_objects += [Object('wardrobe', 45/ppm, 357/ppm, index = 4, position = (0/ppm, 0/ppm, np.deg2rad(90)))]

# room.draw()
# plt.show()

room = create_room(256/ppm, 357/ppm)
room.moving_objects = [Object('double bed', 154/ppm, 175/ppm, index = 0, position = (160/ppm, 234/ppm, np.deg2rad(90)))]
room.moving_objects += [Object('wardrobe', 60/ppm, 180/ppm, index = 1, position = (96/ppm, 25/ppm, np.deg2rad(0)))]
room.moving_objects += [Object('nightstand', 40/ppm, 40/ppm, index = 2, position = (228/ppm, 112/ppm, np.deg2rad(90)))]
room.moving_objects += [Object('nightstand', 40/ppm, 40/ppm, index = 3, position = (225/ppm, 348/ppm, np.deg2rad(90)))]
room.moving_objects += [Object('pendant lamp', 65/ppm, 65/ppm, index = 4, position = (120/ppm, 220/ppm, np.deg2rad(0)))]
room.draw()
plt.show()

# %%
for obj in room.moving_objects: 
    print(obj.name, obj.width, obj.length, obj.position)
    print(" ")
# Out:
# double bed 1.9411764705882355 2.2058823529411766 (2.0168067226890756, 2.9495798319327733, 1.5707963267948966)
#
# wardrobe 0.7563025210084034 2.26890756302521 (1.2100840336134455, 0.3151260504201681, 0.0)
#
# nightstand 0.5042016806722689 0.5042016806722689 (2.8739495798319328, 1.411764705882353, 1.5707963267948966)
#
# nightstand 0.5042016806722689 0.5042016806722689 (2.8361344537815127, 4.38655462184874, 1.5707963267948966)
#
# pendant lamp 0.8193277310924371 0.8193277310924371 (1.512605042016807, 2.7731092436974794, 0.0)
