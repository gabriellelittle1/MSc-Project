# %%
from Class_Structures import * 
from Setup_Functions import * 
s = 2.7

# %%
# A (Romy )
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.20)

room.moving_objects = [Object('bed', 4/s, 6.8/s, index = 0, position = (2/s, 5 - 3.4/s, np.pi))]
room.moving_objects += [Object('bedside table', 1.4/s, 1.4/s, index = 1, position = (4.7/s, 5 - 0.7/s, np.pi))]
room.moving_objects += [Object('desk', 4.9/s, 1, index = 2, position = (3.5, 7.7/s, np.pi/2))]
room.moving_objects += [Object('desk chair', 1.4/s, 1.4/s, index = 3, position = (7.4/s, 6.8/s, 3*np.pi/2))]
room.moving_objects += [Object('wardrobe', 1, 1, index = 4, position = (3.5, 0.5, np.pi/2))]
room.moving_objects += [Object('chest of drawers', 3.3/s, 1, index = 5, position = (3.5, 11.8/s, np.pi/2))]
room.moving_objects += [Object('paper bin', 1.5/s, 1.5/s, index = 6, position = (4 - 1/s, 3.9/s, np.pi/2))]
room.draw(arrows = True, key = True)

# %%
# B Remy  
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

room.moving_objects = [Object('bed', 2, 1, index = 0, position = (3, 4.5, np.pi))]
room.moving_objects += [Object('bedside table', 1.5/s, 1.7/s, index = 1, position = (1.5, 4.6, 3*np.pi/2))]
room.moving_objects += [Object('desk', 2, 0.5, index = 2, position = (3.75, 1, np.pi/2))]
room.moving_objects += [Object('chair', 1.2/s, 1/s, index = 3, position = (3.1, 1, 3*np.pi/2))]
room.moving_objects += [Object('cupboard', 2, 0.9/s, index = 4, position = (0.45/s, 4, 3*np.pi/2))]
room.moving_objects += [Object('bookshelf', 1, 1.1/s, index = 5, position = (1 + 1.1/(2*s), 2.5, 3*np.pi/2))]
room.moving_objects += [Object('lamp', 1.1/s, 0.9/s, index = 6, position = (2.75, 2.1, 0))]

room.tertiary_objects = [Object('monitor', 1.8/s, 0.4/s, index = 0, position = (3.9, 1, np.pi/2))]
room.tertiary_objects += [Object('bedside lamp', 0.4/s, 0.4/s, index = 1, position = (1.7, 4.75, 3*np.pi/2))]
room.tertiary_objects += [Object('white board', 2.3/s, 0.5/s, index = 2, position = (2.9, 0.25/s, 0))]
room.tertiary_objects += [Object('poster', 2.8/s, 0.5/s, index = 3, position = (0.25/s, 2, 3*np.pi/2))]
room.tertiary_objects += [Object('rug', 3.8/s, 1.9/s, index = 4, position = (3, 3.5, np.pi))]
room.draw(arrows = True, key = True)

# %%
# C Josh
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

room.moving_objects = [Object('bed', 4.2/s, 5.3/s, index = 0, position = (4.2/(2*s), 4.9 - 5.3/(2*s), np.pi))]
room.moving_objects += [Object('bedside table', 1.3/s, 1.1/s, index = 1, position = (4.9/s, 4.9 - 1.1/(2*s), np.pi))]
room.moving_objects += [Object('desk', 4.5/s, 2.7/s, index = 2, position = (3.5, 2.9, np.pi/2))]
room.moving_objects += [Object('desk chair', 1.2/s, 1/s, index = 3, position = (2.6, 2.9, 3*np.pi/2))]
room.moving_objects += [Object('wardrobe', 4.1/s, 2.3/s, index = 4, position = (4 - 2.05/s, 2.3/(2*s), 0))]

room.tertiary_objects = [Object('lamp', 0.4/s, 0.4/s, index = 0, position = (4.9/s - 0.1, 4.65, np.pi/2))]
room.tertiary_objects += [Object('computer', 1.8/s, 0.3/s, index = 1, position = (10/s, 6.8/s, np.deg2rad(70)))]
room.tertiary_objects += [Object('poster', 3/s, 0.3/s, index = 2, position = (3, 5 - 0.15/s, np.pi))]
room.tertiary_objects += [Object('rug', 4.8/s, 6.5/s, index = 3, position = (1.9, 7.3/s, 0))]
room.draw(key = True, arrows = True)

# %%
for obj in room.moving_objects + room.tertiary_objects:
    print(obj.name, obj.width, obj.length, obj.position)
# Out:
# bed 1.5555555555555556 1.9629629629629628 (0.7777777777777778, 3.918518518518519, 3.141592653589793)
# bedside table 0.48148148148148145 0.40740740740740744 (1.8148148148148149, 4.696296296296296, 3.141592653589793)
# desk 1.6666666666666665 1.0 (3.5, 2.9, 1.5707963267948966)
# desk chair 0.4444444444444444 0.37037037037037035 (2.6, 2.9, 4.71238898038469)
# wardrobe 1.5185185185185184 0.8518518518518517 (3.240740740740741, 0.4259259259259259, 0)
# lamp 0.14814814814814814 0.14814814814814814 (1.7148148148148148, 4.65, 1.5707963267948966)
# computer 0.6666666666666666 0.1111111111111111 (3.7037037037037033, 2.518518518518518, 1.2217304763960306)
# poster 1.111111111111111 0.1111111111111111 (3, 4.944444444444445, 3.141592653589793)
# rug 1.7777777777777777 2.4074074074074074 (1.9, 2.7037037037037033, 0)

# %%
# D Niladri 
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

room.moving_objects = [Object('bed', 5/s, 3, index = 0, position = (2.1, 3.5, np.pi))]
room.moving_objects += [Object('side table', 2/s, 2/s, index = 1, position = (0.5, 4.37, np.pi))]
room.moving_objects += [Object('side table', 2/s, 2/s, index = 2, position = (3.5, 4.37, np.pi))]
room.moving_objects += [Object('dressing table', 3.1/s, 1.7/s, index = 3, position = (4 - 3.1/(2*s), 1.7/(2*s), 0))]
room.moving_objects += [Object('chair', 1.5/s, 1/s, index = 4, position = (3 + 1.5/(2*s), 1, np.pi))]
room.moving_objects += [Object('mirror', 1.1/s, 0.7/s, index = 5, position = (3.95, 1.7, np.pi/2))]
room.moving_objects += [Object('sliding wardrobe', 4.7/s, 2.25/s, index = 6, position = (2.25/(2*s), 2.7, 3*np.pi/2))]

room.tertiary_objects = [Object('table lamp', 0.7/s, 0.7/s, index = 0, position = (0.5, 4.75, np.pi))]
room.tertiary_objects += [Object('table lamp', 0.7/s, 0.7/s, index = 1, position = (3.5, 4.75, np.pi))]
room.tertiary_objects += [Object('rug', 5.47/s, 1.3/s, index = 2, position = (2, 1.65, np.pi))]
room.draw(arrows = True, key = True)

# %%
# E Malini
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

room.moving_objects = [Object('bed', 4.4/s, 6.4/s, position = (4 - 2.2/s, 3.2/s, 0), index = 0)]
room.moving_objects += [Object('nightstand', 1.7/s, 1.3/s, position = (2, 0.5 - 0.65/s, 0), index = 1)]
room.moving_objects += [Object('desk with shelves', 4.2/s, 2.7/s, position = (2.1/s, 5 - 1.35/s, np.pi), index = 2)]
room.moving_objects += [Object('wardrobe', 5.4/s, 2.7/s, position = (4 - 2.7/s, 4.5, np.pi), index = 3)]
room.moving_objects += [Object('chair', 1.3/s, 0.8/s, position = (1 - 0.65/s, 4 - 0.4/s, 0), index = 4)]
room.moving_objects += [Object('laundry basket', 1.15/s, 1/s, position = (2 - 0.6/s, 5 - 0.5/s, np.pi), index = 5)]
room.moving_objects += [Object('dust bin', 0.9/s, 0.6/s, position = (0.45, 0.25 - 0.3/s, 0), index = 6)]
room.moving_objects += [Object('plant', 1.3/s, 1.1/s, position = (3.95 - 0.65/s, 3.05 + 0.55/s, np.pi/2), index = 7)]

room.tertiary_objects = [Object('picture frame', 2.6/s, 0.4/s, position = (0.2/s,3 - 1.3/s, 3*np.pi/2), index = 0)]
room.tertiary_objects += [Object('lamp', 0.9/s, 0.7/s, position = (0.45/s, 5 - 0.35/s, np.pi), index = 1)]
room.tertiary_objects += [Object('mirror', 1.5/s, 0.4/s, position = (0.2/s, 2 - 0.75/s, 3*np.pi/2), index = 2)]
room.tertiary_objects += [Object('rug', 3, 3, position = (2.5, 1.5, 0), index = 3)]

room.draw(arrows = True, key = True)

# %%
for obj in room.moving_objects + room.tertiary_objects:
    print(obj.name, obj.width, obj.length, obj.position)
# Out:
# bed 1.6296296296296298 2.3703703703703702 (3.185185185185185, 1.1851851851851851, 0)
# nightstand 0.6296296296296295 0.48148148148148145 (2, 0.2592592592592593, 0)
# desk with shelves 1.5555555555555556 1.0 (0.7777777777777778, 4.5, 3.141592653589793)
# wardrobe 2.0 1.0 (3.0, 4.5, 3.141592653589793)
# chair 0.48148148148148145 0.2962962962962963 (0.7592592592592593, 3.851851851851852, 0)
# laundry basket 0.4259259259259259 0.37037037037037035 (1.7777777777777777, 4.814814814814815, 3.141592653589793)
# dust bin 0.3333333333333333 0.2222222222222222 (0.45, 0.1388888888888889, 0)
# plant 0.48148148148148145 0.40740740740740744 (3.7092592592592593, 3.2537037037037035, 1.5707963267948966)
# picture frame 0.9629629629629629 0.14814814814814814 (0.07407407407407407, 2.5185185185185186, 4.71238898038469)
# lamp 0.3333333333333333 0.25925925925925924 (0.16666666666666666, 4.87037037037037, 3.141592653589793)
# ...

# %%
# F Niloy 
room = create_room(4, 5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'window', 1.2, 0.1, 'south', 0.4)
create_fixed_object(room, 'window', 1.2, 0.1, 'east', 0.6)
create_fixed_object(room, 'socket', 0.2, 0.1, 'north', 0.3)
create_fixed_object(room, 'socket', 0.2, 0.1, 'west', 0.5)
create_fixed_object(room, 'socket', 0.2, 0.1, 'east', 0.2)

# %%
## A  Romy 
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.3)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.9)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.7)

room.moving_objects = [Object('big desk', 6.9/s, 1, index = 0, position = (6.9/(2*s), 4.5, np.pi))]
room.moving_objects += [Object('desk chair', 2/s, 1.5/s, index = 1, position = (6.9/(2*s), 3.62, 0))]
room.moving_objects += [Object('bookshelf', 3.9/s, 0.9/s, index = 2, position = (4 - 1.95/s, 5 - 0.45/s, np.pi))]
room.moving_objects += [Object('armchair', 2.3/s, 1.9/s, index = 4, position = (3.23, 1.75, np.deg2rad(140)))]
room.moving_objects += [Object('armchair', 2.3/s, 1.9/s, index = 5, position = (3.18, 0.52, np.deg2rad(50)))]
room.moving_objects += [Object('yoga mat', 1, 2, index = 6, position = (1.5, 2, 0))]
room.moving_objects += [Object('plant', 1.5/s, 1.5/s, index = 7, position = (0.5, 2.5, 3*np.pi/2))]
room.moving_objects += [Object('plant', 1.5/s, 1.5/s, index = 8, position = (3.5, 2.85, np.pi/2))]

room.tertiary_objects = [Object('paper bin', 1.4/s, 1.4/s, index = 3, position = (0.5, 4.5, np.pi))]
room.draw(arrows = True, key = True)

# %%
for obj in room.moving_objects:
    print(obj.name, obj.width, obj.length, obj.position)
# Out:
# big desk 2.5555555555555554 1 (1.2777777777777777, 4.5, 3.141592653589793)
# desk chair 0.7407407407407407 0.5555555555555555 (1.2777777777777777, 3.62, 0)
# bookshelf 1.4444444444444444 0.3333333333333333 (3.2777777777777777, 4.833333333333333, 3.141592653589793)
# paper bin 0.5185185185185185 0.5185185185185185 (0.5, 4.5, 3.141592653589793)
# armchair 0.8518518518518517 0.7037037037037036 (3.23, 1.75, 2.443460952792061)
# armchair 0.8518518518518517 0.7037037037037036 (3.18, 0.52, 0.8726646259971648)
# yoga mat 1 2 (1.5, 2, 0)
# plant 0.5555555555555555 0.5555555555555555 (0.5, 2.5, 4.71238898038469)
# plant 0.5555555555555555 0.5555555555555555 (3.5, 2.85, 1.5707963267948966)

# %%
## B Remy
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.3)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.9)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.7)

room.moving_objects = [Object('bookshelf', 4/s, 1.9/s, index = 0, position = (2.75, 4.65, np.pi))]
room.moving_objects += [Object('bookshelf', 3.6/s + 1.9/s , 1.4/s, index = 1, position = (4 - 0.7/s, 5 - (3.6 + 1.9)/(2*s), np.pi/2))]
room.moving_objects += [Object('sofa', 1, 1, index = 2, position = (2.5, 3.5, np.pi))]
room.moving_objects += [Object('desk', 2, 2/s, index = 3, position = (4 - 1/s, 1, np.pi/2))]
room.moving_objects += [Object('table', 1.1/s, 1, index = 4, position = (0.5, 3.5, 3*np.pi/2))]
room.moving_objects += [Object('cupboard', 2.3/s, 0.4/s, index = 5, position = (0.5, 5 - 0.2/s - 0.1, np.pi))]
room.moving_objects += [Object('sofa', 1.8/s, 0.8/s, index = 6, position = (1 - 0.4/s, 2.5, np.pi/2))]
room.moving_objects += [Object('lamp', 0.7/s, 1.3/s, index = 7, position = (3.65, 2.25, np.pi/2))]
room.moving_objects += [Object('chair', 0.9/s, 0.5/s, index = 8, position = (2.2, 1.8, np.pi/2))]
room.moving_objects += [Object('chair', 0.9/s, 0.5/s, index = 9, position = (0.8, 1.8, 3*np.pi/2))]
room.moving_objects += [Object('meeting table', 1, 0.5, index = 10, position = (1.5, 2 - 0.25, np.pi))]

room.tertiary_objects = [Object('monitor', 4.2/s, 0.5/s, index = 0, position = (4 - 1/s + 0.15, 1, np.pi/2))]
room.tertiary_objects += [Object('keyboard', 1.5/s, 0.4/s, index = 1, position = (4 - 1/s - 0.15, 1, np.pi/2))]
room.tertiary_objects += [Object('projection screen', 1, 0.7/s, index = 2, position = (0.35/s, 2.5, 3*np.pi/2))]
room.tertiary_objects += [Object('painting', 3.3/s, 0.6/s, index = 3, position = (0.3/s, 5 - (1.75/s) + 0.05, 3*np.pi/2))]
room.tertiary_objects += [Object('projector', 0.5/s, 1.2/s, index = 4, position = (1, 2.5, np.pi/2))]

room.tertiary_objects += [Object('coffee machine', 0.5/s,0.7/s, index = 5, position = (0.5, 3.5, np.pi))]
room.draw(arrows = True, key = True)

# %%
for obj in room.moving_objects + room.tertiary_objects:
    print(obj.name, obj.width, obj.length, obj.position)
# Out:
# bookshelf 1.4814814814814814 0.7037037037037036 (2.75, 4.65, 3.141592653589793)
# bookshelf 2.0370370370370368 0.5185185185185185 (3.740740740740741, 3.981481481481482, 1.5707963267948966)
# sofa 1 1 (2.5, 3.5, 3.141592653589793)
# desk 2 0.7407407407407407 (3.6296296296296298, 1, 1.5707963267948966)
# table 0.40740740740740744 1 (0.5, 3.5, 4.71238898038469)
# cupboard 0.8518518518518517 0.14814814814814814 (0.5, 4.825925925925926, 3.141592653589793)
# sofa 0.6666666666666666 0.2962962962962963 (0.8518518518518519, 2.5, 1.5707963267948966)
# lamp 0.25925925925925924 0.48148148148148145 (3.65, 2.25, 1.5707963267948966)
# chair 0.3333333333333333 0.18518518518518517 (2.2, 1.8, 1.5707963267948966)
# chair 0.3333333333333333 0.18518518518518517 (0.8, 1.8, 4.71238898038469)
# meeting table 1 0.5 (1.5, 1.75, 3.141592653589793)
# monitor 1.5555555555555556 0.18518518518518517 (3.7796296296296297, 1, 1.5707963267948966)
# ...

# %%
## C Josh
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.3)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.9)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.7)

room.moving_objects = [Object('desk', 2, 3.7/s, position = (1, 5 - 3.7/(2*s), np.pi), index = 0)]
room.moving_objects += [Object('desk chair', 1.5/s, 1.3/s, position = (1, 3.39, 0), index = 1)]
room.moving_objects += [Object('high table', 3.8/s, 1.4/s, position = (2.75, 5 - 0.7/s, np.pi), index = 2)]
room.moving_objects += [Object('bookshelf', 8.8/s, 1.5/s, position = (4 - 0.75/s, 2.85, np.pi/2), index = 3)]
room.moving_objects += [Object('front table', 3.6/s, 1.8/s, position = (2, 0.9/s, 0), index = 4)]


room.tertiary_objects = [Object('rug', 2, 3, position = (2, 2.5, 0), index = 0)]
room.tertiary_objects += [Object('painting', 3.7/s, 0.3/s, position = (0.15/s, 2.4, 3*np.pi/2), index = 1)]
room.tertiary_objects += [Object('book poster', 1, 0.3/s, position = (3.5, 0.15/s, 0), index = 2)]
room.tertiary_objects += [Object('book poster', 2.2/s, 0.3/s, position = (4 - 0.15/s, 0.52, np.pi/2), index = 3)]
room.tertiary_objects += [Object('computer', 2.3/s, 0.4/s, position = (0.45, 4.7, np.deg2rad(-160)), index = 4)]
room.tertiary_objects += [Object('fantasy figurines', 1.4/s, 0.5/s, position = (2.4, 5 - 0.7/s + 0.05, np.pi), index = 5)]
room.tertiary_objects += [Object('prizes', 1/s, 0.4/s, position = (3.2, 5 - 0.7/s + 0.05, np.deg2rad(150)), index = 6)]
room.draw(arrows = True, key = True)

# %%
## D Niladri
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.3)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.9)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.7)

room.moving_objects = [Object('desk', 5/s, 2.3/s, position = (3, 2.5, np.pi/2), index = 0)]
room.moving_objects += [Object('chair', 2.5/s, 1.2/s, position = (4 - 0.6/s, 2.5, np.pi/2), index = 1)]
room.moving_objects += [Object('bookshelf', 3/s, 1.2/s, position = (4 - 1.5/s, 0.6/s, 0), index = 2)]
room.moving_objects += [Object('bookshelf', 3.5/s, 1.2/s, position = (4 - 1.75/s, 5 - 0.6/s, np.pi), index = 3)]
room.moving_objects += [Object('music system', 1/s, 1/s, position = (0.5/s, 2 - 0.5/s, 3*np.pi/2), index = 4)]
room.moving_objects += [Object('music system', 1/s, 1/s, position = (0.5/s,3.55, 3*np.pi/2), index = 5)]
room.moving_objects += [Object('cabinet', 3/s, 1.2/s, position = (0.6/s, 5 - 1.5/s, 3*np.pi/2), index = 6)]
room.moving_objects += [Object('guest chair', 0.6/s, 0.6/s, position = (2.3, 3.1, 3*np.pi/2), index = 7)]
room.moving_objects += [Object('guest chair', 0.6/s, 0.6/s, position = (2.3, 2.5, 3*np.pi/2), index = 8)]
room.moving_objects += [Object('guest chair', 0.6/s, 0.6/s, position = (2.3, 1.85, 3*np.pi/2), index = 9)]

room.tertiary_objects = [Object('table lamp', 1/s, 0.9/s, position = (2.85, 1.9, np.deg2rad(-45)), index = 0)]
room.tertiary_objects += [Object('PC', 0.7/s, 0.7/s, position = (3, 2.8, 3*np.pi/2), index = 1)]
room.tertiary_objects += [Object('fantasy figurine', 1/s, 0.9/s, position = (0.24, 4.15, 3*np.pi/2), index = 2)]
room.tertiary_objects += [Object('diary', 0.5/s, 1.5/s, position = (3.3, 2.4, 0), index = 3)]
room.tertiary_objects += [Object('tv', 2.4/s, 1.4/s, position = (0.7/s, 2.8, 3*np.pi/2), index = 4)]
room.draw(arrows = True, key = True)

# %%
## E Malini
room = create_room(4, 5)
create_fixed_object(room, 'window', 1, 0.1, 'north', 0.3)
create_fixed_object(room, 'window', 1, 0.1, 'south', 0.5)
create_fixed_object(room, 'door', 0.9, 0.1, 'west', 0.1)
create_fixed_object(room, 'socket', 0.15, 0.1, 'east', 0.2)
create_fixed_object(room, 'socket', 0.15, 0.1, 'north', 0.9)
create_fixed_object(room, 'socket', 0.15, 0.1, 'west', 0.7)

room.moving_objects = [Object('desk', 2, 1, position = (3, 4.5, np.pi), index = 0)]
room.moving_objects += [Object('bookshelf', 7/s, 2.7/s, position = (3.5, 3.5/s, np.pi/2), index = 1)]
room.moving_objects += [Object('chair', 1/s, 0.9/s, position = (2.95, 4 - 0.45/s, 0), index = 2)]
room.moving_objects += [Object('dust bin', 0.7/s, 0.9/s, position = (2 - 0.35/s, 5 - 0.45/s, np.pi), index = 3)]
room.moving_objects += [Object('comfy armchair', 1, 1, position = (0.5, 2.5, 3*np.pi/2), index = 4)]
room.moving_objects += [Object('side table', 0.6, 1.2/s, position = (0.6/s, 3 + 0.3, 3*np.pi/2), index = 5)]
room.moving_objects += [Object('large lamp', 1.3/s, 1.3/s, position = (0.65/s, 5 - 0.65/s, np.pi), index = 6)]
room.moving_objects += [Object('short shelving unit', 3.4/s, 1, position = (1.3/s + 1.7/s, 4.5, np.pi), index = 7)]
room.moving_objects += [Object('plant', 1.4/s, 0.9/s, position = (2, 0.5/s, 0), index = 8)]

room.tertiary_objects = [Object('lamp', 1/s, 1.3/s, position = (2 + 0.5/s, 5 - 0.65/s, np.pi), index = 0)]
room.tertiary_objects += [Object('rug', 2, 3, position = (2, 1.5, 0), index = 1)]
room.tertiary_objects += [Object('picture frame', 4/s, 0.3/s, position = (0.15/s, 2 + 2.05/s, 3*np.pi/2), index = 2)]
room.tertiary_objects += [Object('picture frame', 2/s, 0.2/s, position = (4 - 0.1/s, 3.1 + 1/s, np.pi/2), index = 3)]
room.tertiary_objects += [Object('coat rack', 1.7/s, 0.3/s, position = (0.15/s, 1.95 - 0.8/s, 3*np.pi/2), index = 4)]

room.draw(arrows = True, key = True)
