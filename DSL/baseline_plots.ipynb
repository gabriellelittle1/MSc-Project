# %%
from Class_Structures import * 
from Setup_Functions import *

# %%
room = create_room(5, 4)
room.draw()

# %%
### ATISS 4 x 7 dining room. 
room = create_room(4, 7)
room.moving_objects = [Object('dining table', 1.8, 1.3, index = 0, position = [3.1, 3.5, 0])]
room.moving_objects += [Object('chair', 0.6, 0.7, index = 1, position = [3.5, 4.55, np.pi])]
room.moving_objects += [Object('chair', 0.6, 0.7, index = 2, position = [2.75, 4.55, np.pi])]
room.moving_objects += [Object('chair', 0.6, 0.7, index = 3, position = [3.55, 2.5, 0])]
room.moving_objects += [Object('chair', 0.6, 0.7, index = 4, position = [2.8, 2.5, 0])]
room.moving_objects += [Object('cabinet', 0.8, 0.7, index = 5, position = [0.45, 6.5, np.pi])]
room.moving_objects += [Object('cabinet', 0.8, 0.7, index = 6, position = [1.35, 6.6, np.pi])]
room.moving_objects += [Object('cabinet', 1.6, 0.6, index = 6, position = [0.3, 2.9, 3*np.pi/2])]

room.tertiary_objects = [Object('chandelier', 1.3, 1.3, index = 0, position = [1.7, 3.75, 0])]
room.draw()

# %%
### ATISS 4 x 7 bedroom 
room = create_room(3,4)
room.moving_objects = [Object('bed', 1.6, 2, index = 0, position = [2, 1.9, np.pi/2])]
room.moving_objects += [Object('nightstand', 0.8, 0.4, index = 1, position = [2.8, 0.4, np.pi/2])]
room.moving_objects += [Object('wardrobe', 1.3, 0.7, index = 2, position = [0.35, 0.65, 3*np.pi/2])]
room.moving_objects += [Object('wardrobe', 1.3, 0.7, index = 2, position = [0.35, 4 - 0.65, 3*np.pi/2])]
room.moving_objects += [Object('bench', 1.4, 0.5, index = 2, position = [0.25, 2, 3*np.pi/2])]
room.moving_objects += [Object('armchair',  0.8, 0.6, index = 2, position = [2, 3.3, 3*np.pi/2])]
room.tertiary_objects = [Object('chandelier', 0.8, 0.8, index = 0, position = [1.5, 2, 0])]
room.draw()
