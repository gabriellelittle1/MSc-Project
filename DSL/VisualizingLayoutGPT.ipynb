# %%
from Class_Structures import *

def adjust_position(position, num): 
    return [position[0]*num, position[1]*num, position[2]]

# %%
num = 189/191

bedroom = Room(2.73*num, 2.56*num)
wardrobe = Object("wardrobe", 0.43*num, 1.47*num, region= None, index= 0, position = (1.40*num, 2.34*num, -np.pi/2))
bed = Object("double_bed", 1.42*num, 1.89*num, position = (0.72*num, 1.11*num, -np.pi/2))
nightstand = Object("nightstand", 0.3*num, 0.3*num, position = (0.1*num , 0.13*num, 0))
nightstand2 = Object("nightstand", 0.3*num, 0.3*num, position = (0.1*num, 2.13*num, 0))
pendant_lamp = Object("pendant_lamp", 0.5*num, 0.5*num, position = (0.22*num, 1*num, 0))
pendant_lamp2 = Object("pendant_lamp", 0.5*num, 0.5*num, position = (0.22*num, 2*num, 0))
dressing_table = Object("dressing_table", 0.35*num, 0.75*num, position = (1.96*num, 0.1*num, 0))
dressing_chair = Object("dressing_chair", 0.3*num, 0.3*num, position = (2.04*num, 0.85*num, 0))

bedroom.moving_objects = [wardrobe, bed, nightstand, nightstand2, pendant_lamp, pendant_lamp2, dressing_table, dressing_chair]
bedroom.draw()

# %%
print((2.73*num, 2.56*num))
print(1.42*num, 1.89*num)
print(0.43*num, 1.47*num)
# Out:
# (2.701413612565445, 2.533193717277487)
# 1.405130890052356 1.8702094240837694
# 0.4254973821989529 1.4546073298429318

# %%
num = 194/135
bedroom = Room(2.56*num, 3.5*num)
bed = Object("double_bed", 2.05*num, 1.94*num, position = (1.48*num,1.78*num,  np.pi/2+ np.pi/2))
nightstand = Object("nightstand", 0.35*num, 0.4*num, position = (2.14*num, 2.78*num, np.pi/2+ np.pi/2))
nightstand2 = Object("nightstand", 0.35*num, 0.4*num, position = (2.14*num, 0.7*num, np.pi/2+ np.pi/2))
wardrobe = Object("wardrobe", 0.5*num, 1.32*num, position = (1.32*num, 3.26*num, np.pi+ np.pi/2))
pendant_lamp = Object("pendant_lamp", 0.5*num, 0.5*num, position = (1.28*num, 1.55*num, np.pi/2+ np.pi/2))


bedroom.moving_objects = [bed, nightstand, nightstand2, wardrobe, pendant_lamp]
bedroom.draw()

# %%
## BEDROOM 1
ppm = 64 # pixels per meter
num = 100/64
bedroom = Room(5, 4)
bedroom.moving_objects += [Object("double_bed", 1.3*num, 1.38*num, position = (1.04*num, 1.51*num, np.pi/2+ np.pi/2))]
bedroom.moving_objects += [Object("wardrobe", 0.32*num, 1.38*num, position = (0.3*num, 1.89*num, 0+ np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.29*num, 0.36*num, position = (1.87*num, 0.84*num,np.pi/2+ np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.29*num, 0.36*num, position = (1.87*num, 2.22*num, np.pi/2+ np.pi/2))]
bedroom.moving_objects +=  [Object("pendant_lamp", 0.2*num, 0.2*num, position = (0.76*num, 1.38*num, 0+ np.pi/2))]
bedroom.draw()

# %%
## BEDROOM 2
ppm = 64 # pixels per meter
num = 100/64
bedroom = Room(5, 4)
bedroom.moving_objects += [Object("double_bed", 1.2*num, 1.5*num, position = (0.8*num, 1*num, 0.0+ np.pi/2))]
bedroom.moving_objects += [Object("wardrobe", 0.4*num, 0.6*num, position = (0.1*num, 0.8*num, np.pi/2+ np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.2*num, 0.2*num, position = (2.22*num, 1.3*num, 0+ np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.2*num, 0.2*num, position = (2.22*num, 1.7*num, 0+ np.pi/2))]
bedroom.moving_objects +=  [Object("pendant_lamp", 0.3*num, 0.3*num, position = (1.3*num, 0.2*num, 0+ np.pi/2))]
bedroom.draw()

# %%
## BEDROOM 3
ppm = 64 # pixels per meter
num = 100/64
bedroom = Room(5, 4)
bedroom.moving_objects += [Object("double_bed", 1.37*num, 1.40*num, position = (1.4*num, 1.02*num, np.pi))]
bedroom.moving_objects += [Object("wardrobe", 0.38*num, 0.86*num, position = (0.19*num, 1.24*num, np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.33*num, 0.33*num, position = (0.76*num, 1.68*num, np.pi))]
bedroom.moving_objects +=  [Object("nightstand", 0.33*num, 0.33*num, position = (2.35*num, 1.68*num, np.pi))]
bedroom.moving_objects +=  [Object("ceiling_lamp", 0.35*num, 0.35*num, position = (1.6*num, 0.9*num, 0))]
bedroom.moving_objects +=  [Object("chair", 0.41*num, 0.45*num, position = (0.25*num, 0.45*num,np.pi/2))]
bedroom.moving_objects += [Object("desk", 0.6*num, num, position = (0.25*num, 1.4*num, np.pi/2))]
bedroom.draw()

# %%
## Living Room 1
ppm = 256/4 # pixels per meter
num = 100/ppm
livingroom = Room(5, 4)
# livingroom.moving_objects += [Object("multi_seat_sofa", 0.68*num, 1.45*num, position = (0.34*num, 1.56*num, np.pi/2 + np.pi/2))]
# livingroom.moving_objects += [Object("coffee_table", 0.69*num, 0.81*num, position = (1.42*num, 1.52*num, np.pi/2+ np.pi/2))]
# livingroom.moving_objects +=  [Object("tv_stand", 0.24*num, 1.02*num, position = (2.55*num, 1.6*num, np.pi/2+ np.pi/2))]
# livingroom.moving_objects +=  [Object("pendant_lamp", 0.31*num, 0.31*num, position = (2.35*num, 1.68*num, np.pi+ np.pi/2))]
# livingroom.moving_objects +=  [Object("ceiling_lamp", 0.35*num, 0.35*num, position = (0.31*num, 1.49*num, 0 + np.pi/2))]
# livingroom.moving_objects +=  [Object("corner_side_table", 0.29*num, 0.29*num, position = (0.43*num, 0.39*num,np.pi/2+ np.pi/2))]
# livingroom.moving_objects += [Object("armchair", 0.43*num, 0.51*num, position = (1.22*num, 0.41*num, 0+ np.pi/2))]
livingroom.moving_objects += [Object("multi_seat_sofa", 0.68*num, 1.45*num, position = (0.34*num, 1.56*num, np.pi/2))]
livingroom.moving_objects += [Object("coffee_table", 0.69*num, 0.81*num, position = (1.42*num, 1.52*num, np.pi/2))]
livingroom.moving_objects +=  [Object("tv_stand", 0.24*num, 1.02*num, position = (2.55*num, 1.6*num, np.pi/2))]
livingroom.moving_objects +=  [Object("pendant_lamp", 0.31*num, 0.31*num, position = (2.35*num, 1.68*num, np.pi))]
livingroom.moving_objects +=  [Object("ceiling_lamp", 0.35*num, 0.35*num, position = (0.31*num, 1.49*num, 0 ))]
livingroom.moving_objects +=  [Object("corner_side_table", 0.29*num, 0.29*num, position = (0.43*num, 0.39*num,np.pi/2))]
livingroom.moving_objects += [Object("armchair", 0.43*num, 0.51*num, position = (1.22*num, 0.41*num, 0))]
livingroom.draw()

# %%
## Living Dining Room 

ppm = 64 # pixels per meter
num = 100/ppm
livingroom = Room(4, 5)

livingroom.moving_objects += [Object("dining_table", 0.58*num, 0.96*num, position = (0.45*num, 2.6*num, 0))]
livingroom.moving_objects += [Object("dining_chair", 0.38*num, 0.42*num, position = (0.2*num, 2.6*num, np.pi/2))]
livingroom.moving_objects += [Object("dining_chair", 0.38*num, 0.42*num, position = (0.2*num, 3.15*num, np.pi/2))]
livingroom.moving_objects += [Object("dining_chair", 0.38*num, 0.42*num, position = (0.75*num, 2.6*num, np.pi/2))]
livingroom.moving_objects += [Object("dining_chair", 0.38*num, 0.42*num, position = (0.75*num, 3.15*num, np.pi/2))]
livingroom.moving_objects += [Object("pendant_lamp", 0.24*num, 0.24*num, position = (0.45*num, 2.6*num, 0.0))]
livingroom.moving_objects += [Object("multi_seat_sofa", 0.7*num, 1.5*num, position = (1.8*num, 2.6*num, np.pi/2))]
livingroom.moving_objects += [Object("coffee_table", 0.48*num, 0.8*num, position = (2.1*num, 1.7*num, 0.0))]
livingroom.moving_objects += [Object("tv_stand", 0.38*num, 1.2*num, position = (2.1*num, 0.8*num, np.pi/2))]
livingroom.moving_objects += [Object("ceiling_lamp", 0.38*num, 0.38*num, position = (2.1*num, 1.7*num, 0.0))]

livingroom.draw()

# %%
## 6_55 bedroom 

ppm = 256/5.5# pixels per meter
num = 100/ppm
print(ppm, num)
bedroom = Room(6, 5.5)
# bedroom.moving_objects += [Object("double_bed", 0.96*num, 0.92*num, position = (0.78*num, 0.79*num, np.pi/2 + np.pi/2))]
# bedroom.moving_objects += [Object("nightstand", 0.18*num, 0.22*num, position = (1.08*num, 1.42*num, np.pi/2 + np.pi/2))]
# bedroom.moving_objects += [Object("nightstand", 0.18*num, 0.22*num, position = (1.08*num, 0.16*num, np.pi/2 + np.pi/2))]
# bedroom.moving_objects += [Object("wardrobe", 0.23*num, 1.09*num, position = (0.64*num, 0.23*num, 0 + np.pi/2))]
# bedroom.moving_objects += [Object("pendant_lamp", 0.16*num, 0.16*num, position = (0.64*num, 0.8*num, 0 + np.pi/2))]
bedroom.moving_objects += [Object("double_bed", 0.96*num, 0.92*num, position = (0.78*num, 0.79*num, np.pi/2))]
bedroom.moving_objects += [Object("nightstand", 0.18*num, 0.22*num, position = (1.08*num, 1.42*num, np.pi/2))]
bedroom.moving_objects += [Object("nightstand", 0.18*num, 0.22*num, position = (1.08*num, 0.16*num, np.pi/2))]
bedroom.moving_objects += [Object("wardrobe", 0.23*num, 1.09*num, position = (0.64*num, 0.23*num, 0))]
bedroom.moving_objects += [Object("pendant_lamp", 0.16*num, 0.16*num, position = (0.64*num, 0.8*num, 0))]
bedroom.draw()
# Out:
# 46.54545454545455 2.1484375

# %%
## 6_55 Living Room 
ppm = 256/5.5 # pixels per meter
num = 100/ppm
livingroom = Room(6, 5.5)
livingroom.moving_objects += [Object("multi_seat_sofa", 0.42*num, 1.04*num, position = (0.25*num, 1.44*num, np.pi/2))]
livingroom.moving_objects += [Object("armchair", 0.51*num, 0.48*num, position = (1.8*num, 1.12*num, 0))]
livingroom.moving_objects += [Object("coffee_table", 0.5*num, 0.47*num, position = (1*num, 1.44*num, 0))]
livingroom.moving_objects += [Object("tv_stand", 0.24*num, 0.99*num, position = (0.15*num, 0.93*num, np.pi/2))]
livingroom.moving_objects += [Object("pendant_lamp", 0.28*num, 0.28*num, position = (1*num, 1.43*num, 0))]
livingroom.draw()

# %%
## 6_55 Living/Dining Room 
ppm = 256/5.5 # pixels per meter
num = 100/ppm
livingdining = Room(6, 5.5)
livingdining.moving_objects += [Object("l_shaped_sofa", 0.78*num, 1.22*num, position = (0.21*num,0.64*num, np.pi/2))]
livingdining.moving_objects += [Object("coffee_table", 0.32*num, 0.6*num, position = (0.81*num, 1.12*num, np.pi/2))]
livingdining.moving_objects += [Object("tv_stand", 0.22*num, 0.89*num, position = (1.63*num, 0.3*num, 0))]
livingdining.moving_objects += [Object("pendant_lamp", 0.24*num, 0.78*num, position = (0.81*num, 0.8*num, 0))]
livingdining.moving_objects += [Object("dining_table", 0.43*num, 0.78*num, position = (0.78*num, 2.12*num, 0))]
livingdining.moving_objects += [Object("dining_chair", 0.27*num, 0.26*num, position = (0.37*num, 2.47*num, np.pi))]
livingdining.moving_objects += [Object("dining_chair", 0.27*num, 0.26*num, position = (1.19*num, 2.47*num, np.pi))]
livingdining.moving_objects += [Object("dining_chair", 0.27*num, 0.26*num, position = (0.37*num, 1.76*num, 0))]
livingdining.moving_objects += [Object("dining_chair", 0.27*num, 0.26*num, position = (1.19*num, 1.76*num, 0))]
livingdining.moving_objects += [Object("pendant_lamp", 0.24*num, 0.24*num, position = (0.78*num, 2.12*num, 0))]
livingdining.draw()

# %%
## 6_3 bedroom
ppm = 256/3
num = 100/ppm
bedroom = Room(6, 3)
bedroom.moving_objects += [Object("double_bed", 2.12*num, 2.06*num, position = (1.46*num, 1.25*num, 0.0))]
bedroom.moving_objects += [Object("wardrobe", 0.53*num, 0.98*num, position = (0.08*num, 1.4*num, np.pi/2))]
bedroom.moving_objects +=  [Object("nightstand", 0.33*num, 0.37*num, position = (0.1*num, 0.16*num, 0))]
bedroom.moving_objects +=  [Object("nightstand", 0.33*num, 0.37*num, position = (2.56*num, 0.16*num, 0))]
bedroom.moving_objects +=  [Object("pendant_lamp", 0.42*num, 0.46*num, position = (1.64*num, 1.4*num, 0))]
bedroom.moving_objects +=  [Object("dressing_table", 0.4*num, 0.96*num, position = (0.32*num, 2.52*num, 0))]
bedroom.moving_objects += [Object("dressing_chair", 0.34*num, 0.34*num, position = (0.22*num, 2.26*num, np.pi/4))]
bedroom.draw()

# %%
## 6_3 living room 
ppm = 256/3 # pixels per meter
num = 100/ppm
livingroom = Room(6, 3)
livingroom.moving_objects += [Object("multi_seat_sofa", 0.69*num, 1.62*num, position = (0.45*num, 2.7*num, np.pi))]
livingroom.moving_objects += [Object("armchair", 1.02*num, 0.96*num, position = (2.2*num, 2.96*num, np.pi))]
livingroom.moving_objects += [Object("armchair", 1.02*num, 0.74*num, position = (1.3*num, 2.96*num, np.pi))]
livingroom.moving_objects += [Object("coffee_table", 0.66*num, 1.32*num, position = (2.04*num, 1.81*num, 0))]
livingroom.moving_objects += [Object("tv_stand", 0.34*num, 1.87*num, position = (1.96*num, 0.17*num, 0))]
livingroom.moving_objects += [Object("lounge_chair", 0.57*num, 0.62*num, position = (3.11*num, 2.09*num, np.deg2rad(124)))]
livingroom.moving_objects += [Object("pendant_lamp", 0.68*num, 0.7*num, position = (1.73*num, 1.67*num, 0))]
livingroom.draw()
